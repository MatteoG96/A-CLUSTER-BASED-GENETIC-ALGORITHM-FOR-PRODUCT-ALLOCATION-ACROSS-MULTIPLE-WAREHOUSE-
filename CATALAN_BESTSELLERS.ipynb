# %% [markdown]
# # IMPORT LIBRARIES

# %%
import pandas as pd
import random
from pyomo.environ import *
import numpy as np
import time
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.sparse import coo_matrix

# %%
# 1. Build the binary order–SKU matrix R
def build_R(df, order_col='Num. Ordine', sku_col='Articolo'):
    df_unique = df[[order_col, sku_col]].drop_duplicates()
    orders = df_unique[order_col].unique()
    skus = df_unique[sku_col].unique()
    order_idx = pd.Series(np.arange(len(orders)), index=orders)
    sku_idx = pd.Series(np.arange(len(skus)), index=skus)
    rows = df_unique[order_col].map(order_idx).values
    cols = df_unique[sku_col].map(sku_idx).values
    data = np.ones(len(df_unique), dtype=int)
    R = coo_matrix((data, (rows, cols)), shape=(len(orders), len(skus)))
    return R, orders, skus

# %%
import numpy as np
from scipy.sparse import coo_matrix

def greedy_bestsellers_volume(R, k_vol, sku_vols, debug=False):
    """
    Algorithm 4: BESTSELLERS, adapted for volume constraints, with safe fallback.
    R        : sparse order×SKU matrix (COO or CSR)
    k_vol    : array of DC capacities in volume
    sku_vols : array of SKU volumes (aligned to R’s columns)
    """
    # Ensure CSR format for slicing
    R_csr = R.tocsr()
    n_orders, n_skus = R_csr.shape
    D = len(k_vol)

    # Compute co-occurrence and per-SKU sales
    C = (R_csr.T).dot(R_csr).toarray()
    sales = np.diag(C)
    sorted_sales = np.argsort(-sales)

    # Convert volume caps to cardinal caps (approx) for B
    avg_vol = np.mean(sku_vols)
    k_card = np.floor(k_vol / avg_vol).astype(int)

    # Active DCs, allocations, remaining volume & SKUs
    active = list(range(D))
    allocation = [set() for _ in range(D)]
    remaining = k_vol.copy()
    remaining_skus = set(range(n_skus))

    # Helper to compute B
    def compute_B(dcs):
        if len(dcs) < 2:
            return 0
        return int((sum(k_card[d] for d in dcs) - n_skus) // (len(dcs) - 1))

    # 1) Phase-0: seed any DC with k_card[d] < B
    B = compute_B(active)
    if debug: print("Initial B =", B)
    while True:
        small = [d for d in active if k_card[d] < B]
        if not small:
            break
        for d in small:
            to_seed = k_card[d]
            seeded = 0
            for s in sorted_sales:
                if s in remaining_skus and sku_vols[s] <= remaining[d]:
                    allocation[d].add(s)
                    remaining[d] -= sku_vols[s]
                    remaining_skus.remove(s)
                    seeded += 1
                    if seeded >= to_seed:
                        break
            active.remove(d)
            if debug:
                print(f"  DC_{d+1} seeded {seeded} SKUs (k_card < B)")
        B = compute_B(active)
        if debug: print("  Recomputed B =", B)

    # 2) Fallback: if B <= 0, call GREEDY_SEEDS on remaining
    if B <= 0:
        if debug: print("B <= 0, falling back to GREEDY_SEEDS")
        # slice R and vols to only remaining SKUs
        idx = sorted(remaining_skus)
        R_sub = R_csr[:, idx]
        vols_sub = sku_vols[idx]
        caps_sub = remaining.copy()
        alloc_sub, _ = greedy_seeds_volume(R_sub, caps_sub, vols_sub, debug=debug)
        # merge sub‐alloc back into main allocation
        for sub_dc, d in enumerate(active):
            for rel_s in alloc_sub[sub_dc]:
                s = idx[rel_s]
                allocation[d].add(s)
        return allocation, remaining

    # 3) Main branch B > 0: seed each active DC with top B SKUs
    if debug: print(f"B > 0, seeding top {B} SKUs to each DC")
    for d in sorted(active, key=lambda x: -k_vol[x]):
        seeded = 0
        for s in sorted_sales:
            if s in remaining_skus and sku_vols[s] <= remaining[d]:
                allocation[d].add(s)
                remaining[d] -= sku_vols[s]
                remaining_skus.remove(s)
                seeded += 1
                if seeded >= B:
                    break
        if debug:
            print(f"  DC_{d+1} seeded {seeded} SKUs")

    # 4) Assign rest by max average co-appearance
    if debug: print("Assigning remaining SKUs by avg co-appearance")
    for s in sorted_sales:
        if s not in remaining_skus:
            continue
        best_d, best_score = None, -np.inf
        for d in active:
            if sku_vols[s] > remaining[d]:
                continue
            alloc_list = list(allocation[d])
            score = np.mean([C[s, x] for x in alloc_list]) if alloc_list else 0.0
            if score > best_score:
                best_score, best_d = score, d
        if best_d is not None:
            allocation[best_d].add(s)
            remaining[best_d] -= sku_vols[s]
            remaining_skus.remove(s)
            if debug:
                print(f"  SKU {s} -> DC_{best_d+1} (avg coappear {best_score:.1f})")

    # 5) Fill any leftover capacity by total co-appearance
    if debug: print("Filling remaining capacity by total co-appearance")
    while remaining_skus:
        progress = False
        for d in active:
            cap = remaining[d]
            cand = [s for s in remaining_skus if sku_vols[s] <= cap]
            if not cand:
                continue
            # total co-appearance score
            if allocation[d]:
                scores = C[list(allocation[d]), :].sum(axis=0)
            else:
                scores = C.sum(axis=0)
            # pick best candidate
            best_s = max(cand, key=lambda s: scores[s])
            allocation[d].add(best_s)
            remaining[d] -= sku_vols[best_s]
            remaining_skus.remove(best_s)
            progress = True
            if debug:
                print(f"  DC_{d+1} added SKU {best_s} (score {scores[best_s]:.0f})")
        if not progress:
            if debug:
                print("  No further allocations possible.")
            break

    return allocation, remaining

# %%
import numpy as np

def greedy_seeds_volume(R, k_volume, sku_volumes, debug=False):
    """
    Volume-aware GREEDY SEEDS heuristic with guards against empty candidate sets.
    R: scipy.sparse CSR/COO order×SKU matrix
    k_volume: array of DC capacities in volume
    sku_volumes: array of SKU volumes
    """
    R_csr = R.tocsr()
    n_orders, n_skus = R_csr.shape
    n_dcs = len(k_volume)

    # Compute co-occurrence matrix
    C = (R_csr.T).dot(R_csr).toarray()
    sales = np.diag(C)
    sku_by_sales = np.argsort(-sales)
    sorted_dcs = np.argsort(-k_volume)

    allocation = [set() for _ in range(n_dcs)]
    remaining = k_volume.copy()
    allocated = set()

    # Seed DCs
    # DC 1: top selling SKU
    s0 = sku_by_sales[0]
    if remaining[sorted_dcs[0]] >= sku_volumes[s0]:
        allocation[sorted_dcs[0]].add(s0)
        remaining[sorted_dcs[0]] -= sku_volumes[s0]
        allocated.add(s0)
        if debug:
            print(f"Seed DC_{sorted_dcs[0]+1} with SKU {s0}")

    # Remaining DC seeds
    for d in sorted_dcs[1:]:
        # top decile
        top_n = max(1, int(0.1 * n_skus))
        top_decile = set(sku_by_sales[:top_n])

        # candidates: unallocated, in decile, fits volume
        cand = [s for s in sku_by_sales if s not in allocated 
                and s in top_decile 
                and sku_volumes[s] <= remaining[d]]
        if not cand:
            # fallback to any unallocated that fits
            cand = [s for s in sku_by_sales if s not in allocated and sku_volumes[s] <= remaining[d]]
        if not cand:
            if debug: print(f"No seed candidates for DC_{d+1}; skipping")
            continue
        # choose least coappearance
        scores = [sum(C[s, list(allocated)]) for s in cand] or [0]
        s_seed = cand[int(np.argmin(scores))]
        allocation[d].add(s_seed)
        remaining[d] -= sku_volumes[s_seed]
        allocated.add(s_seed)
        if debug:
            print(f"Seed DC_{d+1} with SKU {s_seed}")

    # Assign remaining SKUs by avg coappearance
    for s in sku_by_sales:
        if s in allocated: continue
        best_d, best_score = None, -np.inf
        for d in sorted_dcs:
            if sku_volumes[s] > remaining[d]:
                continue
            alloc_list = allocation[d]
            if not alloc_list:
                score = 0
            else:
                score = np.mean([C[s, x] for x in alloc_list])
            if score > best_score:
                best_score, best_d = score, d
        if best_d is not None:
            allocation[best_d].add(s)
            remaining[best_d] -= sku_volumes[s]
            allocated.add(s)
            if debug:
                print(f"Assigned SKU {s} to DC_{best_d+1} (avg coappear {best_score:.1f})")

    # Fill remaining capacity
    progress = True
    while progress:
        progress = False
        for d in sorted_dcs:
            cap = remaining[d]
            cand = [s for s in range(n_skus) if s not in allocated and sku_volumes[s] <= cap]
            if not cand:
                continue
            # total coappearance
            if allocation[d]:
                scores = C[list(allocation[d]), :].sum(axis=0)
            else:
                scores = C.sum(axis=0)
            s_best = max(cand, key=lambda s: scores[s])
            allocation[d].add(s_best)
            remaining[d] -= sku_volumes[s_best]
            allocated.add(s_best)
            progress = True
            if debug:
                print(f"DC_{d+1} added SKU {s_best} (score {scores[s_best]:.0f})")

    return allocation, remaining

# %% [markdown]
# # IMPORT DATA

# %%
# --------------------------
# Synthetic dataset generator
# --------------------------
np.random.seed(42)  # reproducibility

n_rows = 500

# Ranges / progressive labels
ordini = [f"ORD_{i}" for i in range(1, 1001)]
articoli = [f"ART_{i}" for i in range(1, 201)]
clienti = [f"CLI_{i}" for i in range(1, 101)]
percorsi = [f"PER_{i}" for i in range(1, 31)]
ecr1_vals = [f"ECR1_{i}" for i in range(1, 6)]
ecr2_vals = [f"ECR2_{i}" for i in range(1, 6)]
ecr3_vals = [f"ECR3_{i}" for i in range(1, 6)]
ecr4_vals = [f"ECR4_{i}" for i in range(1, 6)]

# Build DataFrame
df = pd.DataFrame({
    "Num. Ordine": np.random.choice(ordini, n_rows),
    "Mese-Giorno": pd.date_range("2025-01-01", periods=n_rows, freq="D").strftime("%m-%d"),
    "Articolo": np.random.choice(articoli, n_rows),
    "Pezzi evasi": np.random.randint(1, 12, n_rows),
    "Ecr1": np.random.choice(ecr1_vals, n_rows),
    "Ecr2": np.random.choice(ecr2_vals, n_rows),
    "Ecr3": np.random.choice(ecr3_vals, n_rows),
    "Ecr4": np.random.choice(ecr4_vals, n_rows),
    "Cliente": np.random.choice(clienti, n_rows),
    "Percorso": np.random.choice(percorsi, n_rows),
    "Giacenza Pezzi Volume [m3]": np.round(np.random.uniform(0.1, 10.0, n_rows), 6),
    "Volume evaso [m3]": np.round(np.random.uniform(0.001, 1.0, n_rows), 6),
})

print("✅ Synthetic dataset created:")
print(df.head())

# %% [markdown]
# # GREEDY ORDER

# %%
# 3. Execute the full pipeline

# Assume df and df_stock_vol are already loaded in the environment
R, order_ids, sku_ids = build_R(df)

# Compute SKU volumes (m3) from df_stock_vol
vol_series = df_stock_vol.set_index('ARTICOLO')['Giacenza Pezzi Volume [m3]']
median_vol = vol_series.median()
vol_series_filled = vol_series.fillna(median_vol)
sku_volumes = np.array([vol_series_filled.get(sku, median_vol) for sku in sku_ids], dtype=float)

# Define DC capacities (m3)
#capacity_A = 19800 * 0.37 #25000
#capacity_B =  12720 * 0.37 #6800

capacity_A = df.drop_duplicates(subset = 'Articolo').groupby('Ecr1')['Giacenza Pezzi Volume [m3]'].sum().sum()*0.65
capacity_B = df.drop_duplicates(subset = 'Articolo').groupby('Ecr1')['Giacenza Pezzi Volume [m3]'].sum().sum()*0.45


k_volume = np.array([capacity_A, capacity_B])

# Run heuristic with debug on
allocation, remaining_volume = greedy_bestsellers_volume(R, k_volume, sku_volumes, debug=True)
print("\nFinal remaining volumes (m3):", remaining_volume)

# 4. Map indices back to Articolo codes
alloc_map = []
for d, skus in enumerate(allocation):
    for s in skus:
        alloc_map.append({
            'Warehouse': f'DC_{d+1}', 
            'Articolo': sku_ids[s]
        })
df_allocation = pd.DataFrame(alloc_map)
# Out:
# Initial B = 1627
# B > 0, seeding top 1627 SKUs to each DC
#   DC_1 seeded 1627 SKUs
#   DC_2 seeded 1627 SKUs
# Assigning remaining SKUs by avg co-appearance
#   SKU 9030 -> DC_1 (avg coappear 8.0)
#   SKU 1010 -> DC_1 (avg coappear 7.4)
#   SKU 7731 -> DC_1 (avg coappear 8.7)
#   SKU 735 -> DC_1 (avg coappear 8.9)
#   SKU 6275 -> DC_1 (avg coappear 9.5)
#   SKU 8741 -> DC_1 (avg coappear 12.1)
#   SKU 15438 -> DC_1 (avg coappear 5.8)
#   SKU 7995 -> DC_1 (avg coappear 11.1)
#   SKU 5361 -> DC_1 (avg coappear 6.4)
#   SKU 234 -> DC_1 (avg coappear 6.7)
#   SKU 10144 -> DC_1 (avg coappear 11.6)
#   SKU 2317 -> DC_1 (avg coappear 10.7)
#   SKU 3610 -> DC_1 (avg coappear 5.9)
#   SKU 5703 -> DC_1 (avg coappear 9.2)
#   SKU 6085 -> DC_1 (avg coappear 11.2)
#   SKU 4566 -> DC_1 (avg coappear 8.1)
#   SKU 2065 -> DC_1 (avg coappear 11.6)
#   SKU 1563 -> DC_1 (avg coappear 6.0)
#   SKU 379 -> DC_1 (avg coappear 5.7)
#   SKU 9895 -> DC_1 (avg coappear 8.8)
#   SKU 3819 -> DC_1 (avg coappear 9.6)
#   SKU 7547 -> DC_1 (avg coappear 12.0)
#   SKU 8117 -> DC_1 (avg coappear 6.5)
#   SKU 3529 -> DC_1 (avg coappear 8.2)
#   SKU 3877 -> DC_1 (avg coappear 8.0)
#   SKU 3703 -> DC_1 (avg coappear 8.4)
#   SKU 1581 -> DC_1 (avg coappear 5.7)
#   SKU 5692 -> DC_1 (avg coappear 11.0)
#   SKU 9204 -> DC_1 (avg coappear 6.9)
#   SKU 8724 -> DC_1 (avg coappear 6.9)
#   SKU 13014 -> DC_1 (avg coappear 7.3)
#   SKU 7961 -> DC_1 (avg coappear 8.8)
#   SKU 9783 -> DC_1 (avg coappear 8.5)
#   SKU 10372 -> DC_1 (avg coappear 11.6)
#   SKU 8189 -> DC_1 (avg coappear 6.8)
#   SKU 4096 -> DC_1 (avg coappear 12.0)
#   SKU 15288 -> DC_1 (avg coappear 11.8)
#   SKU 8579 -> DC_1 (avg coappear 4.9)
#   SKU 5581 -> DC_1 (avg coappear 11.1)
#   SKU 8790 -> DC_1 (avg coappear 10.1)
#   SKU 6520 -> DC_1 (avg coappear 9.4)
#   SKU 5737 -> DC_1 (avg coappear 7.9)
#   SKU 7357 -> DC_1 (avg coappear 10.2)
#   SKU 8025 -> DC_1 (avg coappear 12.9)
#   SKU 927 -> DC_1 (avg coappear 10.1)
#   SKU 2927 -> DC_1 (avg coappear 10.6)
#   SKU 305 -> DC_1 (avg coappear 6.2)
#   SKU 3767 -> DC_1 (avg coappear 8.3)
#   SKU 6392 -> DC_1 (avg coappear 5.8)
#   SKU 5214 -> DC_1 (avg coappear 10.1)
#   SKU 4561 -> DC_1 (avg coappear 8.6)
#   SKU 7838 -> DC_1 (avg coappear 12.1)
#   SKU 3479 -> DC_1 (avg coappear 9.0)
#   SKU 7140 -> DC_1 (avg coappear 10.5)
#   SKU 8077 -> DC_1 (avg coappear 8.4)
#   SKU 7435 -> DC_1 (avg coappear 8.8)
#   SKU 3172 -> DC_1 (avg coappear 5.4)
#   SKU 2674 -> DC_1 (avg coappear 10.5)
#   SKU 451 -> DC_1 (avg coappear 7.3)
#   SKU 2059 -> DC_1 (avg coappear 8.7)
#   SKU 3109 -> DC_1 (avg coappear 11.1)
#   SKU 1401 -> DC_1 (avg coappear 8.6)
#   SKU 382 -> DC_1 (avg coappear 6.8)
#   SKU 3181 -> DC_1 (avg coappear 7.4)
#   SKU 15414 -> DC_1 (avg coappear 9.1)
#   SKU 1440 -> DC_1 (avg coappear 9.1)
#   SKU 8322 -> DC_1 (avg coappear 4.1)
#   SKU 6439 -> DC_1 (avg coappear 7.6)
#   SKU 1766 -> DC_1 (avg coappear 8.4)
#   SKU 7595 -> DC_1 (avg coappear 10.2)
#   SKU 1393 -> DC_1 (avg coappear 7.0)
#   SKU 8022 -> DC_1 (avg coappear 5.9)
#   SKU 1709 -> DC_1 (avg coappear 6.1)
#   SKU 910 -> DC_1 (avg coappear 8.9)
#   SKU 363 -> DC_1 (avg coappear 7.3)
#   SKU 4067 -> DC_1 (avg coappear 5.6)
#   SKU 1338 -> DC_1 (avg coappear 7.4)
#   SKU 7729 -> DC_1 (avg coappear 9.1)
#   SKU 3950 -> DC_1 (avg coappear 6.9)
#   SKU 3900 -> DC_1 (avg coappear 6.4)
#   SKU 15406 -> DC_1 (avg coappear 7.9)
#   SKU 10576 -> DC_1 (avg coappear 7.0)
#   SKU 10679 -> DC_1 (avg coappear 8.1)
#   SKU 4185 -> DC_1 (avg coappear 8.0)
#   SKU 14289 -> DC_1 (avg coappear 7.6)
#   SKU 5694 -> DC_1 (avg coappear 8.8)
#   SKU 2088 -> DC_1 (avg coappear 8.8)
#   SKU 9688 -> DC_1 (avg coappear 8.8)
#   SKU 7281 -> DC_1 (avg coappear 11.2)
#   SKU 2295 -> DC_1 (avg coappear 8.5)
#   SKU 1949 -> DC_1 (avg coappear 8.9)
#   SKU 2298 -> DC_1 (avg coappear 6.9)
#   SKU 5153 -> DC_1 (avg coappear 7.4)
#   SKU 1874 -> DC_1 (avg coappear 4.4)
#   SKU 5732 -> DC_1 (avg coappear 8.3)
#   SKU 2022 -> DC_1 (avg coappear 5.7)
#   SKU 3566 -> DC_1 (avg coappear 6.3)
#   SKU 6845 -> DC_1 (avg coappear 6.3)
#   SKU 10510 -> DC_1 (avg coappear 10.4)
#   SKU 2910 -> DC_1 (avg coappear 8.9)
#   SKU 2614 -> DC_1 (avg coappear 7.3)
#   SKU 7165 -> DC_1 (avg coappear 5.9)
#   SKU 7895 -> DC_1 (avg coappear 10.0)
#   SKU 7209 -> DC_1 (avg coappear 7.0)
#   SKU 3168 -> DC_1 (avg coappear 6.8)
#   SKU 4913 -> DC_1 (avg coappear 9.1)
#   SKU 6476 -> DC_1 (avg coappear 6.0)
#   SKU 12823 -> DC_1 (avg coappear 5.6)
#   SKU 2834 -> DC_1 (avg coappear 7.1)
#   SKU 779 -> DC_1 (avg coappear 6.1)
#   SKU 11977 -> DC_1 (avg coappear 6.4)
#   SKU 3725 -> DC_1 (avg coappear 7.5)
#   SKU 2122 -> DC_1 (avg coappear 6.7)
#   SKU 318 -> DC_1 (avg coappear 6.2)
#   SKU 584 -> DC_1 (avg coappear 9.2)
#   SKU 718 -> DC_1 (avg coappear 10.5)
#   SKU 1316 -> DC_1 (avg coappear 7.1)
#   SKU 486 -> DC_1 (avg coappear 7.5)
#   SKU 4621 -> DC_1 (avg coappear 8.0)
#   SKU 8853 -> DC_1 (avg coappear 8.1)
#   SKU 3039 -> DC_1 (avg coappear 5.5)
#   SKU 2427 -> DC_1 (avg coappear 7.1)
#   SKU 3653 -> DC_1 (avg coappear 5.3)
#   SKU 3674 -> DC_1 (avg coappear 5.8)
#   SKU 4382 -> DC_1 (avg coappear 8.0)
#   SKU 8698 -> DC_1 (avg coappear 4.7)
#   SKU 10131 -> DC_1 (avg coappear 9.9)
#   SKU 9763 -> DC_1 (avg coappear 7.4)
#   SKU 1237 -> DC_1 (avg coappear 7.2)
#   SKU 5955 -> DC_1 (avg coappear 6.9)
#   SKU 6080 -> DC_1 (avg coappear 9.2)
#   SKU 2759 -> DC_1 (avg coappear 8.2)
#   SKU 4737 -> DC_1 (avg coappear 9.5)
#   SKU 3467 -> DC_1 (avg coappear 8.6)
#   SKU 64 -> DC_1 (avg coappear 7.7)
#   SKU 7571 -> DC_1 (avg coappear 8.2)
#   SKU 7830 -> DC_1 (avg coappear 8.8)
#   SKU 3045 -> DC_1 (avg coappear 9.5)
#   SKU 3914 -> DC_1 (avg coappear 8.6)
#   SKU 9512 -> DC_1 (avg coappear 9.8)
#   SKU 7569 -> DC_1 (avg coappear 6.5)
#   SKU 1186 -> DC_1 (avg coappear 6.5)
#   SKU 6942 -> DC_1 (avg coappear 9.1)
#   SKU 9927 -> DC_1 (avg coappear 8.9)
#   SKU 823 -> DC_1 (avg coappear 6.7)
#   SKU 2502 -> DC_1 (avg coappear 8.6)
#   SKU 4368 -> DC_1 (avg coappear 8.0)
#   SKU 6435 -> DC_1 (avg coappear 6.6)
#   SKU 7181 -> DC_1 (avg coappear 6.4)
#   SKU 4167 -> DC_1 (avg coappear 7.8)
#   SKU 3837 -> DC_1 (avg coappear 10.8)
#   SKU 468 -> DC_1 (avg coappear 7.9)
#   SKU 10154 -> DC_1 (avg coappear 7.9)
#   SKU 2277 -> DC_1 (avg coappear 8.3)
#   SKU 9075 -> DC_1 (avg coappear 10.6)
#   SKU 9071 -> DC_1 (avg coappear 9.6)
#   SKU 3854 -> DC_1 (avg coappear 6.6)
#   SKU 6277 -> DC_1 (avg coappear 7.2)
#   SKU 808 -> DC_1 (avg coappear 8.6)
#   SKU 1621 -> DC_1 (avg coappear 8.1)
#   SKU 14308 -> DC_1 (avg coappear 10.8)
#   SKU 1385 -> DC_1 (avg coappear 6.7)
#   SKU 4166 -> DC_1 (avg coappear 8.6)
#   SKU 12428 -> DC_1 (avg coappear 7.8)
#   SKU 5444 -> DC_1 (avg coappear 8.4)
#   SKU 10039 -> DC_1 (avg coappear 6.0)
#   SKU 7016 -> DC_1 (avg coappear 6.1)
#   SKU 4133 -> DC_1 (avg coappear 6.2)
#   SKU 4074 -> DC_1 (avg coappear 7.6)
#   SKU 5545 -> DC_1 (avg coappear 6.8)
#   SKU 2928 -> DC_1 (avg coappear 9.0)
#   SKU 7033 -> DC_1 (avg coappear 8.2)
#   SKU 2588 -> DC_1 (avg coappear 3.9)
#   SKU 6471 -> DC_1 (avg coappear 6.9)
#   SKU 1068 -> DC_1 (avg coappear 7.7)
#   SKU 94 -> DC_1 (avg coappear 8.1)
#   SKU 86 -> DC_1 (avg coappear 8.3)
#   SKU 5300 -> DC_1 (avg coappear 5.5)
#   SKU 7431 -> DC_1 (avg coappear 6.1)
#   SKU 4661 -> DC_1 (avg coappear 6.7)
#   SKU 7208 -> DC_1 (avg coappear 5.6)
#   SKU 4508 -> DC_1 (avg coappear 8.3)
#   SKU 10867 -> DC_1 (avg coappear 7.8)
#   SKU 9044 -> DC_1 (avg coappear 6.4)
#   SKU 1682 -> DC_1 (avg coappear 5.5)
#   SKU 31 -> DC_1 (avg coappear 7.0)
#   SKU 2066 -> DC_1 (avg coappear 7.3)
#   SKU 6104 -> DC_1 (avg coappear 9.7)
#   SKU 9404 -> DC_1 (avg coappear 8.6)
#   SKU 4519 -> DC_1 (avg coappear 7.3)
#   SKU 1336 -> DC_1 (avg coappear 7.9)
#   SKU 1049 -> DC_1 (avg coappear 6.5)
#   SKU 1187 -> DC_1 (avg coappear 5.6)
#   SKU 7146 -> DC_1 (avg coappear 9.1)
#   SKU 2698 -> DC_1 (avg coappear 7.7)
#   SKU 1436 -> DC_1 (avg coappear 6.7)
#   SKU 3745 -> DC_1 (avg coappear 8.4)
#   SKU 12323 -> DC_1 (avg coappear 5.2)
#   SKU 526 -> DC_1 (avg coappear 7.8)
#   SKU 4738 -> DC_1 (avg coappear 8.8)
#   SKU 290 -> DC_1 (avg coappear 5.5)
#   SKU 5621 -> DC_1 (avg coappear 8.5)
#   SKU 1359 -> DC_1 (avg coappear 6.3)
#   SKU 13092 -> DC_1 (avg coappear 7.9)
#   SKU 3742 -> DC_1 (avg coappear 8.4)
#   SKU 1395 -> DC_1 (avg coappear 7.9)
#   SKU 1470 -> DC_1 (avg coappear 9.4)
#   SKU 6408 -> DC_1 (avg coappear 6.5)
#   SKU 3830 -> DC_1 (avg coappear 7.9)
#   SKU 13010 -> DC_1 (avg coappear 6.6)
#   SKU 3324 -> DC_1 (avg coappear 7.6)
#   SKU 12525 -> DC_1 (avg coappear 5.7)
#   SKU 4923 -> DC_1 (avg coappear 6.7)
#   SKU 1641 -> DC_1 (avg coappear 7.1)
#   SKU 992 -> DC_1 (avg coappear 8.6)
#   SKU 2971 -> DC_1 (avg coappear 8.9)
#   SKU 1992 -> DC_1 (avg coappear 5.8)
#   SKU 1914 -> DC_1 (avg coappear 6.5)
#   SKU 7462 -> DC_1 (avg coappear 8.4)
#   SKU 2026 -> DC_1 (avg coappear 7.4)
#   SKU 778 -> DC_1 (avg coappear 7.0)
#   SKU 5111 -> DC_1 (avg coappear 8.1)
#   SKU 9406 -> DC_1 (avg coappear 4.2)
#   SKU 5912 -> DC_1 (avg coappear 9.4)
#   SKU 8242 -> DC_1 (avg coappear 5.1)
#   SKU 211 -> DC_1 (avg coappear 7.6)
#   SKU 9673 -> DC_1 (avg coappear 8.2)
#   SKU 4033 -> DC_1 (avg coappear 5.6)
#   SKU 536 -> DC_1 (avg coappear 4.8)
#   SKU 6617 -> DC_1 (avg coappear 5.0)
#   SKU 3096 -> DC_1 (avg coappear 5.7)
#   SKU 7448 -> DC_1 (avg coappear 5.8)
#   SKU 12947 -> DC_1 (avg coappear 7.5)
#   SKU 1772 -> DC_1 (avg coappear 7.0)
#   SKU 13141 -> DC_1 (avg coappear 4.8)
#   SKU 14420 -> DC_1 (avg coappear 9.0)
#   SKU 13154 -> DC_1 (avg coappear 9.0)
#   SKU 1045 -> DC_1 (avg coappear 4.6)
#   SKU 15331 -> DC_1 (avg coappear 6.7)
#   SKU 4339 -> DC_1 (avg coappear 5.1)
#   SKU 306 -> DC_1 (avg coappear 5.8)
#   SKU 1127 -> DC_1 (avg coappear 4.5)
#   SKU 8530 -> DC_1 (avg coappear 7.0)
#   SKU 6843 -> DC_1 (avg coappear 10.6)
#   SKU 4826 -> DC_1 (avg coappear 6.1)
#   SKU 6484 -> DC_1 (avg coappear 7.2)
#   SKU 124 -> DC_1 (avg coappear 7.4)
#   SKU 4125 -> DC_1 (avg coappear 6.5)
#   SKU 7393 -> DC_1 (avg coappear 5.9)
#   SKU 3208 -> DC_1 (avg coappear 5.9)
#   SKU 7997 -> DC_1 (avg coappear 8.1)
#   SKU 809 -> DC_1 (avg coappear 8.2)
#   SKU 691 -> DC_1 (avg coappear 6.1)
#   SKU 2990 -> DC_1 (avg coappear 7.0)
#   SKU 8244 -> DC_1 (avg coappear 7.7)
#   SKU 11969 -> DC_1 (avg coappear 11.4)
#   SKU 4210 -> DC_1 (avg coappear 2.5)
#   SKU 9201 -> DC_1 (avg coappear 5.8)
#   SKU 6808 -> DC_1 (avg coappear 8.2)
#   SKU 7744 -> DC_1 (avg coappear 7.4)
#   SKU 13581 -> DC_1 (avg coappear 9.6)
#   SKU 14947 -> DC_1 (avg coappear 7.7)
#   SKU 120 -> DC_1 (avg coappear 8.0)
#   SKU 3068 -> DC_1 (avg coappear 6.3)
#   SKU 15170 -> DC_1 (avg coappear 4.2)
#   SKU 5490 -> DC_1 (avg coappear 6.5)
#   SKU 4050 -> DC_1 (avg coappear 8.2)
#   SKU 147 -> DC_1 (avg coappear 8.6)
#   SKU 8626 -> DC_1 (avg coappear 6.9)
#   SKU 3675 -> DC_1 (avg coappear 6.1)
#   SKU 12496 -> DC_1 (avg coappear 5.0)
#   SKU 207 -> DC_1 (avg coappear 5.3)
#   SKU 1183 -> DC_1 (avg coappear 8.3)
#   SKU 8516 -> DC_1 (avg coappear 6.8)
#   SKU 9437 -> DC_1 (avg coappear 5.7)
#   SKU 819 -> DC_1 (avg coappear 3.3)
#   SKU 3571 -> DC_1 (avg coappear 5.0)
#   SKU 4422 -> DC_1 (avg coappear 8.1)
#   SKU 1691 -> DC_1 (avg coappear 8.2)
#   SKU 13278 -> DC_1 (avg coappear 5.4)
#   SKU 9712 -> DC_1 (avg coappear 5.7)
#   SKU 9057 -> DC_1 (avg coappear 4.0)
#   SKU 6299 -> DC_1 (avg coappear 6.2)
#   SKU 4026 -> DC_1 (avg coappear 6.7)
#   SKU 13334 -> DC_1 (avg coappear 9.6)
#   SKU 1681 -> DC_1 (avg coappear 4.9)
#   SKU 14306 -> DC_1 (avg coappear 5.1)
#   SKU 2719 -> DC_1 (avg coappear 5.9)
#   SKU 14398 -> DC_1 (avg coappear 8.0)
#   SKU 9833 -> DC_1 (avg coappear 7.6)
#   SKU 5327 -> DC_1 (avg coappear 7.8)
#   SKU 7032 -> DC_1 (avg coappear 5.2)
#   SKU 6615 -> DC_1 (avg coappear 8.3)
#   SKU 860 -> DC_1 (avg coappear 5.2)
#   SKU 803 -> DC_1 (avg coappear 6.7)
#   SKU 370 -> DC_1 (avg coappear 5.0)
#   SKU 2579 -> DC_1 (avg coappear 8.2)
#   SKU 4659 -> DC_1 (avg coappear 6.3)
#   SKU 2350 -> DC_1 (avg coappear 5.1)
#   SKU 5201 -> DC_1 (avg coappear 5.6)
#   SKU 775 -> DC_1 (avg coappear 7.3)
#   SKU 14307 -> DC_1 (avg coappear 6.7)
#   SKU 11904 -> DC_1 (avg coappear 7.5)
#   SKU 4445 -> DC_1 (avg coappear 6.1)
#   SKU 2658 -> DC_1 (avg coappear 8.5)
#   SKU 12654 -> DC_1 (avg coappear 5.7)
#   SKU 8814 -> DC_1 (avg coappear 5.8)
#   SKU 6761 -> DC_1 (avg coappear 5.2)
#   SKU 2140 -> DC_1 (avg coappear 5.6)
#   SKU 1872 -> DC_1 (avg coappear 2.6)
#   SKU 9782 -> DC_1 (avg coappear 9.2)
#   SKU 9625 -> DC_1 (avg coappear 6.4)
#   SKU 6608 -> DC_1 (avg coappear 5.3)
#   SKU 8236 -> DC_1 (avg coappear 4.7)
#   SKU 6125 -> DC_1 (avg coappear 5.3)
#   SKU 6535 -> DC_1 (avg coappear 8.6)
#   SKU 12498 -> DC_1 (avg coappear 7.6)
#   SKU 1245 -> DC_1 (avg coappear 3.9)
#   SKU 1133 -> DC_1 (avg coappear 9.9)
#   SKU 4340 -> DC_1 (avg coappear 4.7)
#   SKU 11288 -> DC_1 (avg coappear 5.0)
#   SKU 5771 -> DC_1 (avg coappear 6.4)
#   SKU 9198 -> DC_1 (avg coappear 6.1)
#   SKU 3205 -> DC_1 (avg coappear 3.7)
#   SKU 4532 -> DC_1 (avg coappear 6.5)
#   SKU 10945 -> DC_1 (avg coappear 6.5)
#   SKU 6973 -> DC_1 (avg coappear 7.5)
#   SKU 398 -> DC_1 (avg coappear 5.4)
#   SKU 1417 -> DC_1 (avg coappear 8.0)
#   SKU 8492 -> DC_1 (avg coappear 6.6)
#   SKU 9142 -> DC_1 (avg coappear 4.0)
#   SKU 1163 -> DC_1 (avg coappear 5.3)
#   SKU 3276 -> DC_1 (avg coappear 6.6)
#   SKU 9299 -> DC_1 (avg coappear 7.1)
#   SKU 3127 -> DC_1 (avg coappear 4.9)
#   SKU 12368 -> DC_1 (avg coappear 8.0)
#   SKU 7420 -> DC_1 (avg coappear 7.1)
#   SKU 6803 -> DC_1 (avg coappear 7.4)
#   SKU 5419 -> DC_1 (avg coappear 9.6)
#   SKU 4242 -> DC_1 (avg coappear 6.3)
#   SKU 7871 -> DC_1 (avg coappear 5.6)
#   SKU 1309 -> DC_1 (avg coappear 6.1)
#   SKU 220 -> DC_1 (avg coappear 7.2)
#   SKU 2933 -> DC_1 (avg coappear 6.9)
#   SKU 4912 -> DC_1 (avg coappear 5.9)
#   SKU 3565 -> DC_1 (avg coappear 7.0)
#   SKU 2402 -> DC_1 (avg coappear 6.6)
#   SKU 3343 -> DC_1 (avg coappear 5.0)
#   SKU 2152 -> DC_1 (avg coappear 4.9)
#   SKU 6180 -> DC_1 (avg coappear 5.6)
#   SKU 743 -> DC_1 (avg coappear 7.0)
#   SKU 3676 -> DC_1 (avg coappear 5.6)
#   SKU 1601 -> DC_1 (avg coappear 6.6)
#   SKU 15247 -> DC_1 (avg coappear 4.6)
#   SKU 12944 -> DC_1 (avg coappear 4.9)
#   SKU 7785 -> DC_1 (avg coappear 7.6)
#   SKU 2879 -> DC_1 (avg coappear 6.1)
#   SKU 4904 -> DC_1 (avg coappear 4.9)
#   SKU 3723 -> DC_1 (avg coappear 7.4)
#   SKU 442 -> DC_1 (avg coappear 6.7)
#   SKU 7238 -> DC_1 (avg coappear 6.3)
#   SKU 7493 -> DC_1 (avg coappear 5.1)
#   SKU 2337 -> DC_1 (avg coappear 7.9)
#   SKU 10249 -> DC_1 (avg coappear 5.8)
#   SKU 4719 -> DC_1 (avg coappear 5.9)
#   SKU 5598 -> DC_1 (avg coappear 8.2)
#   SKU 11611 -> DC_1 (avg coappear 9.8)
#   SKU 7277 -> DC_1 (avg coappear 6.9)
#   SKU 12575 -> DC_1 (avg coappear 11.2)
#   SKU 10514 -> DC_1 (avg coappear 8.4)
#   SKU 3827 -> DC_1 (avg coappear 8.8)
#   SKU 2704 -> DC_1 (avg coappear 6.0)
#   SKU 9192 -> DC_1 (avg coappear 5.2)
#   SKU 5971 -> DC_1 (avg coappear 6.2)
#   SKU 2736 -> DC_1 (avg coappear 2.1)
#   SKU 3417 -> DC_1 (avg coappear 4.2)
#   SKU 1052 -> DC_1 (avg coappear 5.8)
#   SKU 2248 -> DC_1 (avg coappear 7.0)
#   SKU 1066 -> DC_1 (avg coappear 5.1)
#   SKU 1189 -> DC_1 (avg coappear 4.8)
#   SKU 6970 -> DC_1 (avg coappear 3.5)
#   SKU 4406 -> DC_1 (avg coappear 5.9)
#   SKU 9871 -> DC_1 (avg coappear 6.3)
#   SKU 6393 -> DC_1 (avg coappear 5.7)
#   SKU 8686 -> DC_1 (avg coappear 4.0)
#   SKU 6485 -> DC_1 (avg coappear 8.3)
#   SKU 6976 -> DC_1 (avg coappear 5.2)
#   SKU 12950 -> DC_1 (avg coappear 7.7)
#   SKU 6779 -> DC_1 (avg coappear 6.3)
#   SKU 1264 -> DC_1 (avg coappear 6.0)
#   SKU 7384 -> DC_1 (avg coappear 6.9)
#   SKU 3832 -> DC_1 (avg coappear 5.9)
#   SKU 5394 -> DC_1 (avg coappear 4.5)
#   SKU 7358 -> DC_1 (avg coappear 6.7)
#   SKU 11374 -> DC_1 (avg coappear 5.7)
#   SKU 13363 -> DC_1 (avg coappear 2.2)
#   SKU 2085 -> DC_1 (avg coappear 5.0)
#   SKU 6388 -> DC_1 (avg coappear 8.2)
#   SKU 5435 -> DC_1 (avg coappear 6.3)
#   SKU 8805 -> DC_1 (avg coappear 7.4)
#   SKU 5483 -> DC_1 (avg coappear 3.5)
#   SKU 15301 -> DC_1 (avg coappear 6.7)
#   SKU 7530 -> DC_1 (avg coappear 2.4)
#   SKU 10566 -> DC_1 (avg coappear 7.7)
#   SKU 3887 -> DC_1 (avg coappear 6.1)
#   SKU 9191 -> DC_1 (avg coappear 7.1)
#   SKU 780 -> DC_1 (avg coappear 7.3)
#   SKU 1100 -> DC_1 (avg coappear 5.9)
#   SKU 2288 -> DC_1 (avg coappear 6.2)
#   SKU 2827 -> DC_1 (avg coappear 5.7)
#   SKU 4412 -> DC_1 (avg coappear 5.6)
#   SKU 2193 -> DC_1 (avg coappear 5.4)
#   SKU 6536 -> DC_1 (avg coappear 6.9)
#   SKU 2291 -> DC_1 (avg coappear 6.8)
#   SKU 3822 -> DC_1 (avg coappear 6.6)
#   SKU 12473 -> DC_1 (avg coappear 3.2)
#   SKU 10898 -> DC_1 (avg coappear 4.1)
#   SKU 1473 -> DC_1 (avg coappear 5.8)
#   SKU 3212 -> DC_1 (avg coappear 6.0)
#   SKU 5433 -> DC_1 (avg coappear 6.1)
#   SKU 177 -> DC_1 (avg coappear 5.8)
#   SKU 4275 -> DC_1 (avg coappear 4.6)
#   SKU 14317 -> DC_1 (avg coappear 5.6)
#   SKU 4495 -> DC_1 (avg coappear 4.8)
#   SKU 11924 -> DC_1 (avg coappear 7.5)
#   SKU 6475 -> DC_1 (avg coappear 6.1)
#   SKU 3390 -> DC_1 (avg coappear 6.4)
#   SKU 8845 -> DC_1 (avg coappear 5.4)
#   SKU 3230 -> DC_1 (avg coappear 7.2)
#   SKU 5057 -> DC_1 (avg coappear 6.3)
#   SKU 2271 -> DC_1 (avg coappear 4.7)
#   SKU 7925 -> DC_1 (avg coappear 5.9)
#   SKU 2504 -> DC_1 (avg coappear 5.6)
#   SKU 859 -> DC_1 (avg coappear 6.8)
#   SKU 878 -> DC_1 (avg coappear 5.4)
#   SKU 1203 -> DC_1 (avg coappear 6.3)
#   SKU 4522 -> DC_1 (avg coappear 5.8)
#   SKU 2240 -> DC_1 (avg coappear 4.9)
#   SKU 4660 -> DC_1 (avg coappear 7.1)
#   SKU 600 -> DC_1 (avg coappear 4.8)
#   SKU 9212 -> DC_1 (avg coappear 9.2)
#   SKU 10403 -> DC_1 (avg coappear 9.5)
#   SKU 10431 -> DC_1 (avg coappear 9.1)
#   SKU 917 -> DC_1 (avg coappear 7.6)
#   SKU 1917 -> DC_1 (avg coappear 6.4)
#   SKU 7048 -> DC_1 (avg coappear 5.1)
#   SKU 1452 -> DC_1 (avg coappear 3.7)
#   SKU 8631 -> DC_1 (avg coappear 6.9)
#   SKU 7471 -> DC_1 (avg coappear 6.9)
#   SKU 2428 -> DC_1 (avg coappear 5.8)
#   SKU 5307 -> DC_1 (avg coappear 5.1)
#   SKU 2150 -> DC_1 (avg coappear 6.2)
#   SKU 4111 -> DC_1 (avg coappear 6.0)
#   SKU 5379 -> DC_1 (avg coappear 5.2)
#   SKU 1213 -> DC_1 (avg coappear 5.7)
#   SKU 13140 -> DC_1 (avg coappear 7.2)
#   SKU 6532 -> DC_1 (avg coappear 4.8)
#   SKU 2984 -> DC_1 (avg coappear 5.4)
#   SKU 2800 -> DC_1 (avg coappear 6.0)
#   SKU 5813 -> DC_1 (avg coappear 4.8)
#   SKU 3111 -> DC_1 (avg coappear 5.7)
#   SKU 8196 -> DC_1 (avg coappear 3.7)
#   SKU 6105 -> DC_1 (avg coappear 6.6)
#   SKU 14805 -> DC_1 (avg coappear 4.6)
#   SKU 2332 -> DC_1 (avg coappear 6.8)
#   SKU 4373 -> DC_1 (avg coappear 5.6)
#   SKU 1850 -> DC_1 (avg coappear 2.1)
#   SKU 9430 -> DC_1 (avg coappear 7.0)
#   SKU 6067 -> DC_1 (avg coappear 6.4)
#   SKU 408 -> DC_1 (avg coappear 3.7)
#   SKU 3968 -> DC_1 (avg coappear 4.7)
#   SKU 1744 -> DC_1 (avg coappear 5.5)
#   SKU 12514 -> DC_1 (avg coappear 7.3)
#   SKU 1228 -> DC_1 (avg coappear 4.5)
#   SKU 3049 -> DC_1 (avg coappear 4.9)
#   SKU 3908 -> DC_1 (avg coappear 5.8)
#   SKU 132 -> DC_1 (avg coappear 7.2)
#   SKU 10030 -> DC_1 (avg coappear 6.7)
#   SKU 1715 -> DC_1 (avg coappear 2.7)
#   SKU 7385 -> DC_1 (avg coappear 8.0)
#   SKU 3740 -> DC_1 (avg coappear 7.0)
#   SKU 7758 -> DC_1 (avg coappear 4.9)
#   SKU 5403 -> DC_1 (avg coappear 5.0)
#   SKU 11296 -> DC_1 (avg coappear 4.6)
#   SKU 4194 -> DC_1 (avg coappear 7.5)
#   SKU 8720 -> DC_1 (avg coappear 4.4)
#   SKU 852 -> DC_1 (avg coappear 8.5)
#   SKU 2938 -> DC_1 (avg coappear 6.5)
#   SKU 8540 -> DC_1 (avg coappear 5.8)
#   SKU 5600 -> DC_1 (avg coappear 4.8)
#   SKU 9755 -> DC_1 (avg coappear 5.2)
#   SKU 4531 -> DC_1 (avg coappear 7.6)
#   SKU 7576 -> DC_1 (avg coappear 5.8)
#   SKU 5645 -> DC_1 (avg coappear 5.9)
#   SKU 1221 -> DC_1 (avg coappear 6.6)
#   SKU 4995 -> DC_1 (avg coappear 3.3)
#   SKU 10165 -> DC_1 (avg coappear 7.0)
#   SKU 2687 -> DC_1 (avg coappear 5.9)
#   SKU 7 -> DC_1 (avg coappear 5.5)
#   SKU 5897 -> DC_1 (avg coappear 4.5)
#   SKU 1655 -> DC_1 (avg coappear 5.7)
#   SKU 1745 -> DC_1 (avg coappear 3.8)
#   SKU 1480 -> DC_1 (avg coappear 0.4)
#   SKU 3477 -> DC_1 (avg coappear 5.2)
#   SKU 7227 -> DC_1 (avg coappear 5.1)
#   SKU 6270 -> DC_1 (avg coappear 6.8)
#   SKU 5772 -> DC_1 (avg coappear 6.8)
#   SKU 4895 -> DC_1 (avg coappear 3.7)
#   SKU 5889 -> DC_1 (avg coappear 4.9)
#   SKU 7062 -> DC_1 (avg coappear 4.3)
#   SKU 5478 -> DC_1 (avg coappear 6.2)
#   SKU 969 -> DC_1 (avg coappear 5.9)
#   SKU 8531 -> DC_1 (avg coappear 5.9)
#   SKU 4147 -> DC_1 (avg coappear 4.2)
#   SKU 343 -> DC_1 (avg coappear 6.4)
#   SKU 2497 -> DC_1 (avg coappear 7.4)
#   SKU 3024 -> DC_1 (avg coappear 6.8)
#   SKU 3924 -> DC_1 (avg coappear 4.9)
#   SKU 4472 -> DC_1 (avg coappear 4.3)
#   SKU 4470 -> DC_1 (avg coappear 5.6)
#   SKU 9295 -> DC_1 (avg coappear 4.9)
#   SKU 15384 -> DC_1 (avg coappear 8.1)
#   SKU 5906 -> DC_1 (avg coappear 4.3)
#   SKU 8288 -> DC_1 (avg coappear 2.1)
#   SKU 4966 -> DC_1 (avg coappear 5.3)
#   SKU 402 -> DC_1 (avg coappear 5.0)
#   SKU 1021 -> DC_1 (avg coappear 4.9)
#   SKU 4286 -> DC_1 (avg coappear 4.0)
#   SKU 7442 -> DC_1 (avg coappear 8.3)
#   SKU 1057 -> DC_1 (avg coappear 4.8)
#   SKU 5438 -> DC_1 (avg coappear 4.9)
#   SKU 4456 -> DC_1 (avg coappear 7.5)
#   SKU 14891 -> DC_1 (avg coappear 4.8)
#   SKU 7985 -> DC_1 (avg coappear 4.5)
#   SKU 3966 -> DC_1 (avg coappear 6.6)
#   SKU 5649 -> DC_1 (avg coappear 5.0)
#   SKU 2540 -> DC_1 (avg coappear 5.2)
#   SKU 4822 -> DC_1 (avg coappear 3.6)
#   SKU 1605 -> DC_1 (avg coappear 5.3)
#   SKU 901 -> DC_1 (avg coappear 6.7)
#   SKU 8354 -> DC_1 (avg coappear 5.0)
#   SKU 1106 -> DC_1 (avg coappear 6.6)
#   SKU 9081 -> DC_1 (avg coappear 3.2)
#   SKU 10065 -> DC_1 (avg coappear 7.0)
#   SKU 5705 -> DC_1 (avg coappear 4.4)
#   SKU 7970 -> DC_1 (avg coappear 4.7)
#   SKU 2790 -> DC_1 (avg coappear 8.0)
#   SKU 12444 -> DC_1 (avg coappear 5.4)
#   SKU 10689 -> DC_1 (avg coappear 4.9)
#   SKU 3560 -> DC_1 (avg coappear 6.6)
#   SKU 4014 -> DC_1 (avg coappear 5.9)
#   SKU 4402 -> DC_1 (avg coappear 8.3)
#   SKU 811 -> DC_1 (avg coappear 6.9)
#   SKU 12065 -> DC_1 (avg coappear 5.3)
#   SKU 3454 -> DC_1 (avg coappear 5.3)
#   SKU 12903 -> DC_1 (avg coappear 4.5)
#   SKU 9825 -> DC_1 (avg coappear 4.0)
#   SKU 4385 -> DC_1 (avg coappear 5.3)
#   SKU 11746 -> DC_1 (avg coappear 3.9)
#   SKU 10255 -> DC_1 (avg coappear 4.9)
#   SKU 1058 -> DC_1 (avg coappear 4.6)
#   SKU 5838 -> DC_1 (avg coappear 4.0)
#   SKU 3456 -> DC_1 (avg coappear 6.4)
#   SKU 963 -> DC_1 (avg coappear 4.0)
#   SKU 1738 -> DC_1 (avg coappear 5.1)
#   SKU 351 -> DC_1 (avg coappear 5.0)
#   SKU 4908 -> DC_1 (avg coappear 4.9)
#   SKU 6643 -> DC_1 (avg coappear 5.7)
#   SKU 4607 -> DC_1 (avg coappear 6.2)
#   SKU 2874 -> DC_1 (avg coappear 5.3)
#   SKU 15036 -> DC_1 (avg coappear 3.8)
#   SKU 5096 -> DC_1 (avg coappear 6.6)
#   SKU 1099 -> DC_1 (avg coappear 6.1)
#   SKU 6356 -> DC_1 (avg coappear 7.7)
#   SKU 5726 -> DC_1 (avg coappear 7.6)
#   SKU 6802 -> DC_1 (avg coappear 5.8)
#   SKU 2806 -> DC_1 (avg coappear 5.3)
#   SKU 2050 -> DC_1 (avg coappear 7.9)
#   SKU 549 -> DC_1 (avg coappear 5.7)
#   SKU 11949 -> DC_1 (avg coappear 6.0)
#   SKU 11246 -> DC_1 (avg coappear 4.7)
#   SKU 15320 -> DC_1 (avg coappear 1.8)
#   SKU 6837 -> DC_1 (avg coappear 4.3)
#   SKU 3915 -> DC_1 (avg coappear 5.8)
#   SKU 2139 -> DC_1 (avg coappear 4.6)
#   SKU 13618 -> DC_1 (avg coappear 5.9)
#   SKU 3071 -> DC_1 (avg coappear 5.4)
#   SKU 9884 -> DC_1 (avg coappear 5.2)
#   SKU 8711 -> DC_1 (avg coappear 8.4)
#   SKU 414 -> DC_1 (avg coappear 3.2)
#   SKU 4744 -> DC_1 (avg coappear 4.6)
#   SKU 5343 -> DC_1 (avg coappear 5.4)
#   SKU 4298 -> DC_1 (avg coappear 3.5)
#   SKU 4204 -> DC_1 (avg coappear 7.3)
#   SKU 12613 -> DC_1 (avg coappear 6.6)
#   SKU 2286 -> DC_1 (avg coappear 6.8)
#   SKU 4190 -> DC_1 (avg coappear 6.2)
#   SKU 2185 -> DC_1 (avg coappear 4.2)
#   SKU 8040 -> DC_1 (avg coappear 3.2)
#   SKU 15465 -> DC_1 (avg coappear 6.7)
#   SKU 3782 -> DC_1 (avg coappear 5.1)
#   SKU 2809 -> DC_1 (avg coappear 5.6)
#   SKU 74 -> DC_1 (avg coappear 5.8)
#   SKU 4351 -> DC_1 (avg coappear 5.0)
#   SKU 1384 -> DC_1 (avg coappear 5.4)
#   SKU 6483 -> DC_1 (avg coappear 5.8)
#   SKU 2851 -> DC_1 (avg coappear 4.2)
#   SKU 5263 -> DC_1 (avg coappear 6.4)
#   SKU 1394 -> DC_1 (avg coappear 5.3)
#   SKU 15205 -> DC_1 (avg coappear 8.2)
#   SKU 2479 -> DC_1 (avg coappear 3.3)
#   SKU 3080 -> DC_1 (avg coappear 3.2)
#   SKU 8076 -> DC_1 (avg coappear 5.6)
#   SKU 5650 -> DC_1 (avg coappear 4.2)
#   SKU 9945 -> DC_1 (avg coappear 7.1)
#   SKU 5355 -> DC_1 (avg coappear 4.6)
#   SKU 8100 -> DC_1 (avg coappear 3.2)
#   SKU 15293 -> DC_1 (avg coappear 9.0)
#   SKU 3519 -> DC_1 (avg coappear 5.7)
#   SKU 3741 -> DC_1 (avg coappear 6.3)
#   SKU 4932 -> DC_1 (avg coappear 3.7)
#   SKU 14447 -> DC_1 (avg coappear 6.3)
#   SKU 10362 -> DC_1 (avg coappear 6.8)
#   SKU 121 -> DC_1 (avg coappear 6.4)
#   SKU 11801 -> DC_1 (avg coappear 5.4)
#   SKU 6131 -> DC_1 (avg coappear 6.1)
#   SKU 3154 -> DC_1 (avg coappear 6.8)
#   SKU 5819 -> DC_1 (avg coappear 4.2)
#   SKU 3147 -> DC_1 (avg coappear 3.6)
#   SKU 8719 -> DC_1 (avg coappear 6.6)
#   SKU 3606 -> DC_1 (avg coappear 6.1)
#   SKU 8561 -> DC_1 (avg coappear 4.7)
#   SKU 2029 -> DC_1 (avg coappear 4.6)
#   SKU 3297 -> DC_1 (avg coappear 5.4)
#   SKU 2452 -> DC_1 (avg coappear 5.5)
#   SKU 3589 -> DC_1 (avg coappear 6.1)
#   SKU 4725 -> DC_1 (avg coappear 5.2)
#   SKU 9208 -> DC_1 (avg coappear 5.0)
#   SKU 3376 -> DC_1 (avg coappear 4.5)
#   SKU 518 -> DC_1 (avg coappear 5.9)
#   SKU 12449 -> DC_1 (avg coappear 3.1)
#   SKU 6307 -> DC_1 (avg coappear 4.6)
#   SKU 8509 -> DC_1 (avg coappear 4.0)
#   SKU 1330 -> DC_1 (avg coappear 3.6)
#   SKU 11745 -> DC_1 (avg coappear 3.3)
#   SKU 293 -> DC_1 (avg coappear 6.4)
#   SKU 7031 -> DC_1 (avg coappear 3.8)
#   SKU 961 -> DC_1 (avg coappear 4.5)
#   SKU 261 -> DC_1 (avg coappear 5.2)
#   SKU 2651 -> DC_1 (avg coappear 4.8)
#   SKU 10758 -> DC_1 (avg coappear 5.1)
#   SKU 8864 -> DC_1 (avg coappear 5.3)
#   SKU 5302 -> DC_1 (avg coappear 5.2)
#   SKU 2141 -> DC_1 (avg coappear 5.4)
#   SKU 650 -> DC_1 (avg coappear 5.1)
#   SKU 5574 -> DC_1 (avg coappear 4.6)
#   SKU 6031 -> DC_1 (avg coappear 5.2)
#   SKU 10895 -> DC_1 (avg coappear 3.7)
#   SKU 5922 -> DC_1 (avg coappear 4.6)
#   SKU 15063 -> DC_1 (avg coappear 6.4)
#   SKU 2054 -> DC_1 (avg coappear 4.2)
#   SKU 2477 -> DC_1 (avg coappear 4.9)
#   SKU 12532 -> DC_1 (avg coappear 7.0)
#   SKU 3840 -> DC_1 (avg coappear 6.5)
#   SKU 10573 -> DC_1 (avg coappear 3.9)
#   SKU 6856 -> DC_1 (avg coappear 5.4)
#   SKU 2657 -> DC_1 (avg coappear 7.9)
#   SKU 5606 -> DC_1 (avg coappear 4.3)
#   SKU 4005 -> DC_1 (avg coappear 4.4)
#   SKU 378 -> DC_1 (avg coappear 3.8)
#   SKU 609 -> DC_1 (avg coappear 7.2)
#   SKU 3278 -> DC_1 (avg coappear 5.7)
#   SKU 2142 -> DC_1 (avg coappear 5.3)
#   SKU 6706 -> DC_1 (avg coappear 5.6)
#   SKU 139 -> DC_1 (avg coappear 6.2)
#   SKU 8765 -> DC_1 (avg coappear 4.6)
#   SKU 7695 -> DC_1 (avg coappear 7.1)
#   SKU 6974 -> DC_1 (avg coappear 6.1)
#   SKU 10326 -> DC_1 (avg coappear 6.7)
#   SKU 13811 -> DC_1 (avg coappear 5.6)
#   SKU 2558 -> DC_1 (avg coappear 5.6)
#   SKU 1742 -> DC_1 (avg coappear 5.3)
#   SKU 2902 -> DC_1 (avg coappear 6.2)
#   SKU 2222 -> DC_1 (avg coappear 5.7)
#   SKU 4619 -> DC_1 (avg coappear 3.9)
#   SKU 868 -> DC_1 (avg coappear 4.8)
#   SKU 7946 -> DC_1 (avg coappear 6.7)
#   SKU 8 -> DC_1 (avg coappear 4.7)
#   SKU 3621 -> DC_1 (avg coappear 4.3)
#   SKU 488 -> DC_1 (avg coappear 4.4)
#   SKU 5896 -> DC_1 (avg coappear 3.3)
#   SKU 5146 -> DC_1 (avg coappear 5.7)
#   SKU 4354 -> DC_1 (avg coappear 5.9)
#   SKU 4087 -> DC_1 (avg coappear 3.8)
#   SKU 5511 -> DC_1 (avg coappear 5.9)
#   SKU 3532 -> DC_1 (avg coappear 5.6)
#   SKU 4090 -> DC_1 (avg coappear 5.6)
#   SKU 3183 -> DC_1 (avg coappear 4.0)
#   SKU 4163 -> DC_1 (avg coappear 4.5)
#   SKU 1873 -> DC_1 (avg coappear 2.2)
#   SKU 2111 -> DC_1 (avg coappear 5.8)
#   SKU 5700 -> DC_1 (avg coappear 6.3)
#   SKU 2238 -> DC_1 (avg coappear 2.5)
#   SKU 6964 -> DC_1 (avg coappear 7.0)
#   SKU 8945 -> DC_1 (avg coappear 4.2)
#   SKU 6903 -> DC_1 (avg coappear 4.1)
#   SKU 10329 -> DC_1 (avg coappear 5.5)
#   SKU 10509 -> DC_1 (avg coappear 3.7)
#   SKU 6875 -> DC_1 (avg coappear 3.9)
#   SKU 6849 -> DC_1 (avg coappear 4.8)
#   SKU 4960 -> DC_1 (avg coappear 5.3)
#   SKU 1260 -> DC_1 (avg coappear 4.8)
#   SKU 1913 -> DC_1 (avg coappear 4.5)
#   SKU 8891 -> DC_1 (avg coappear 6.0)
#   SKU 4941 -> DC_1 (avg coappear 5.9)
#   SKU 2464 -> DC_1 (avg coappear 4.8)
#   SKU 6075 -> DC_1 (avg coappear 4.4)
#   SKU 15334 -> DC_1 (avg coappear 3.3)
#   SKU 15369 -> DC_1 (avg coappear 4.8)
#   SKU 449 -> DC_1 (avg coappear 2.8)
#   SKU 6770 -> DC_1 (avg coappear 7.0)
#   SKU 6954 -> DC_1 (avg coappear 4.6)
#   SKU 3623 -> DC_1 (avg coappear 3.6)
#   SKU 6297 -> DC_1 (avg coappear 5.9)
#   SKU 12959 -> DC_1 (avg coappear 6.8)
#   SKU 5905 -> DC_1 (avg coappear 4.7)
#   SKU 3534 -> DC_1 (avg coappear 7.2)
#   SKU 61 -> DC_1 (avg coappear 5.2)
#   SKU 15302 -> DC_1 (avg coappear 3.6)
#   SKU 5410 -> DC_1 (avg coappear 4.9)
#   SKU 5646 -> DC_1 (avg coappear 5.8)
#   SKU 7865 -> DC_1 (avg coappear 6.6)
#   SKU 2696 -> DC_1 (avg coappear 4.3)
#   SKU 2302 -> DC_1 (avg coappear 5.1)
#   SKU 5830 -> DC_1 (avg coappear 4.1)
#   SKU 1675 -> DC_1 (avg coappear 5.2)
#   SKU 1311 -> DC_1 (avg coappear 4.5)
#   SKU 11232 -> DC_1 (avg coappear 3.6)
#   SKU 2239 -> DC_1 (avg coappear 4.0)
#   SKU 10155 -> DC_1 (avg coappear 7.0)
#   SKU 15347 -> DC_1 (avg coappear 2.7)
#   SKU 8084 -> DC_1 (avg coappear 5.9)
#   SKU 1600 -> DC_1 (avg coappear 5.5)
#   SKU 5055 -> DC_1 (avg coappear 3.6)
#   SKU 9082 -> DC_1 (avg coappear 2.9)
#   SKU 2335 -> DC_1 (avg coappear 5.0)
#   SKU 1514 -> DC_1 (avg coappear 2.9)
#   SKU 1094 -> DC_1 (avg coappear 4.0)
#   SKU 13227 -> DC_1 (avg coappear 4.2)
#   SKU 6967 -> DC_1 (avg coappear 1.1)
#   SKU 1400 -> DC_1 (avg coappear 4.8)
#   SKU 7363 -> DC_1 (avg coappear 7.2)
#   SKU 2223 -> DC_1 (avg coappear 5.3)
#   SKU 12562 -> DC_1 (avg coappear 3.2)
#   SKU 5235 -> DC_1 (avg coappear 5.2)
#   SKU 1122 -> DC_1 (avg coappear 5.7)
#   SKU 916 -> DC_1 (avg coappear 4.5)
#   SKU 3687 -> DC_1 (avg coappear 4.1)
#   SKU 2073 -> DC_1 (avg coappear 4.2)
#   SKU 36 -> DC_1 (avg coappear 4.8)
#   SKU 1642 -> DC_1 (avg coappear 5.0)
#   SKU 9143 -> DC_1 (avg coappear 4.0)
#   SKU 8526 -> DC_1 (avg coappear 5.1)
#   SKU 1925 -> DC_1 (avg coappear 4.3)
#   SKU 2999 -> DC_1 (avg coappear 4.1)
#   SKU 11951 -> DC_1 (avg coappear 5.5)
#   SKU 3609 -> DC_1 (avg coappear 4.4)
#   SKU 4295 -> DC_1 (avg coappear 4.8)
#   SKU 10164 -> DC_1 (avg coappear 3.0)
#   SKU 11998 -> DC_1 (avg coappear 0.3)
#   SKU 4415 -> DC_1 (avg coappear 5.5)
#   SKU 8830 -> DC_1 (avg coappear 4.5)
#   SKU 6916 -> DC_1 (avg coappear 4.6)
#   SKU 5619 -> DC_1 (avg coappear 3.7)
#   SKU 6727 -> DC_1 (avg coappear 5.5)
#   SKU 5330 -> DC_1 (avg coappear 4.8)
#   SKU 6868 -> DC_1 (avg coappear 4.5)
#   SKU 2980 -> DC_1 (avg coappear 3.7)
#   SKU 5360 -> DC_1 (avg coappear 5.9)
#   SKU 1720 -> DC_1 (avg coappear 1.8)
#   SKU 4512 -> DC_1 (avg coappear 4.2)
#   SKU 5152 -> DC_1 (avg coappear 4.8)
#   SKU 371 -> DC_1 (avg coappear 4.3)
#   SKU 8781 -> DC_1 (avg coappear 4.7)
#   SKU 3785 -> DC_1 (avg coappear 5.1)
#   SKU 6136 -> DC_1 (avg coappear 6.1)
#   SKU 11466 -> DC_1 (avg coappear 5.5)
#   SKU 10900 -> DC_1 (avg coappear 5.1)
#   SKU 5928 -> DC_1 (avg coappear 5.1)
#   SKU 4629 -> DC_1 (avg coappear 4.6)
#   SKU 10842 -> DC_1 (avg coappear 4.8)
#   SKU 5492 -> DC_1 (avg coappear 4.1)
#   SKU 3552 -> DC_1 (avg coappear 4.8)
#   SKU 7497 -> DC_1 (avg coappear 5.2)
#   SKU 2360 -> DC_1 (avg coappear 4.8)
#   SKU 8756 -> DC_1 (avg coappear 5.3)
#   SKU 3905 -> DC_1 (avg coappear 2.6)
#   SKU 897 -> DC_1 (avg coappear 5.9)
#   SKU 4083 -> DC_1 (avg coappear 5.6)
#   SKU 6195 -> DC_1 (avg coappear 5.3)
#   SKU 10163 -> DC_1 (avg coappear 3.3)
#   SKU 5223 -> DC_1 (avg coappear 3.6)
#   SKU 11956 -> DC_1 (avg coappear 3.4)
#   SKU 9218 -> DC_1 (avg coappear 5.1)
#   SKU 557 -> DC_1 (avg coappear 4.5)
#   SKU 2926 -> DC_1 (avg coappear 5.3)
#   SKU 8615 -> DC_1 (avg coappear 3.9)
#   SKU 12640 -> DC_1 (avg coappear 2.9)
#   SKU 143 -> DC_1 (avg coappear 4.6)
#   SKU 7474 -> DC_1 (avg coappear 5.5)
#   SKU 3090 -> DC_1 (avg coappear 5.0)
#   SKU 3146 -> DC_1 (avg coappear 4.6)
#   SKU 13108 -> DC_1 (avg coappear 6.6)
#   SKU 10520 -> DC_1 (avg coappear 5.2)
#   SKU 3139 -> DC_1 (avg coappear 5.8)
#   SKU 11920 -> DC_1 (avg coappear 3.6)
#   SKU 1244 -> DC_1 (avg coappear 2.6)
#   SKU 12615 -> DC_1 (avg coappear 7.9)
#   SKU 2147 -> DC_1 (avg coappear 5.2)
#   SKU 5796 -> DC_1 (avg coappear 5.5)
#   SKU 8347 -> DC_1 (avg coappear 5.3)
#   SKU 3749 -> DC_1 (avg coappear 5.2)
#   SKU 2266 -> DC_1 (avg coappear 4.4)
#   SKU 4161 -> DC_1 (avg coappear 3.5)
#   SKU 7502 -> DC_1 (avg coappear 2.5)
#   SKU 2374 -> DC_1 (avg coappear 4.2)
#   SKU 2027 -> DC_1 (avg coappear 5.3)
#   SKU 4077 -> DC_1 (avg coappear 4.9)
#   SKU 5291 -> DC_1 (avg coappear 4.4)
#   SKU 6893 -> DC_1 (avg coappear 2.9)
#   SKU 9636 -> DC_1 (avg coappear 3.4)
#   SKU 5015 -> DC_1 (avg coappear 1.7)
#   SKU 793 -> DC_1 (avg coappear 4.9)
#   SKU 15041 -> DC_1 (avg coappear 5.9)
#   SKU 10681 -> DC_1 (avg coappear 5.8)
#   SKU 1983 -> DC_1 (avg coappear 5.0)
#   SKU 2018 -> DC_1 (avg coappear 3.5)
#   SKU 4400 -> DC_1 (avg coappear 4.0)
#   SKU 1870 -> DC_1 (avg coappear 2.0)
#   SKU 4358 -> DC_1 (avg coappear 3.1)
#   SKU 10167 -> DC_1 (avg coappear 5.6)
#   SKU 2478 -> DC_1 (avg coappear 4.8)
#   SKU 3492 -> DC_1 (avg coappear 5.3)
#   SKU 7058 -> DC_1 (avg coappear 3.3)
#   SKU 3816 -> DC_1 (avg coappear 5.7)
#   SKU 5155 -> DC_1 (avg coappear 6.4)
#   SKU 6913 -> DC_1 (avg coappear 4.9)
#   SKU 235 -> DC_1 (avg coappear 4.6)
#   SKU 6441 -> DC_1 (avg coappear 4.4)
#   SKU 6968 -> DC_1 (avg coappear 1.4)
#   SKU 4574 -> DC_1 (avg coappear 4.7)
#   SKU 1212 -> DC_1 (avg coappear 5.1)
#   SKU 9778 -> DC_1 (avg coappear 7.1)
#   SKU 4297 -> DC_1 (avg coappear 3.3)
#   SKU 11309 -> DC_1 (avg coappear 4.5)
#   SKU 652 -> DC_1 (avg coappear 6.4)
#   SKU 4980 -> DC_1 (avg coappear 3.9)
#   SKU 10057 -> DC_1 (avg coappear 6.7)
#   SKU 8042 -> DC_1 (avg coappear 5.0)
#   SKU 11600 -> DC_1 (avg coappear 4.9)
#   SKU 4571 -> DC_1 (avg coappear 3.5)
#   SKU 7331 -> DC_1 (avg coappear 4.9)
#   SKU 10722 -> DC_1 (avg coappear 6.0)
#   SKU 1441 -> DC_1 (avg coappear 6.6)
#   SKU 4978 -> DC_1 (avg coappear 2.8)
#   SKU 6998 -> DC_1 (avg coappear 5.3)
#   SKU 3416 -> DC_1 (avg coappear 3.0)
#   SKU 7839 -> DC_1 (avg coappear 3.8)
#   SKU 7848 -> DC_1 (avg coappear 2.3)
#   SKU 1859 -> DC_1 (avg coappear 1.9)
#   SKU 2370 -> DC_1 (avg coappear 4.0)
#   SKU 5085 -> DC_1 (avg coappear 3.7)
#   SKU 10848 -> DC_1 (avg coappear 3.2)
#   SKU 8948 -> DC_1 (avg coappear 3.4)
#   SKU 984 -> DC_1 (avg coappear 3.9)
#   SKU 7221 -> DC_1 (avg coappear 4.9)
#   SKU 3615 -> DC_1 (avg coappear 3.8)
#   SKU 5948 -> DC_1 (avg coappear 3.1)
#   SKU 8614 -> DC_1 (avg coappear 4.1)
#   SKU 7716 -> DC_1 (avg coappear 6.7)
#   SKU 2030 -> DC_1 (avg coappear 5.0)
#   SKU 5678 -> DC_1 (avg coappear 2.9)
#   SKU 8600 -> DC_1 (avg coappear 3.6)
#   SKU 7774 -> DC_1 (avg coappear 5.0)
#   SKU 350 -> DC_1 (avg coappear 3.5)
#   SKU 9058 -> DC_1 (avg coappear 2.5)
#   SKU 906 -> DC_1 (avg coappear 3.6)
#   SKU 3813 -> DC_1 (avg coappear 4.4)
#   SKU 6637 -> DC_1 (avg coappear 3.9)
#   SKU 5428 -> DC_1 (avg coappear 4.5)
#   SKU 5387 -> DC_1 (avg coappear 3.5)
#   SKU 123 -> DC_1 (avg coappear 5.0)
#   SKU 6389 -> DC_1 (avg coappear 4.5)
#   SKU 5599 -> DC_1 (avg coappear 5.4)
#   SKU 10106 -> DC_1 (avg coappear 5.3)
#   SKU 5103 -> DC_1 (avg coappear 3.6)
#   SKU 2761 -> DC_1 (avg coappear 3.4)
#   SKU 6365 -> DC_1 (avg coappear 4.6)
#   SKU 6032 -> DC_1 (avg coappear 6.0)
#   SKU 141 -> DC_1 (avg coappear 4.1)
#   SKU 2774 -> DC_1 (avg coappear 3.8)
#   SKU 9602 -> DC_1 (avg coappear 4.6)
#   SKU 12442 -> DC_1 (avg coappear 5.3)
#   SKU 10267 -> DC_1 (avg coappear 2.5)
#   SKU 4777 -> DC_1 (avg coappear 3.8)
#   SKU 49 -> DC_1 (avg coappear 5.6)
#   SKU 326 -> DC_1 (avg coappear 4.5)
#   SKU 6306 -> DC_1 (avg coappear 4.7)
#   SKU 3700 -> DC_1 (avg coappear 4.4)
#   SKU 8383 -> DC_1 (avg coappear 3.5)
#   SKU 5818 -> DC_1 (avg coappear 5.2)
#   SKU 4338 -> DC_1 (avg coappear 3.1)
#   SKU 6049 -> DC_1 (avg coappear 4.1)
#   SKU 12324 -> DC_1 (avg coappear 5.0)
#   SKU 15365 -> DC_1 (avg coappear 5.3)
#   SKU 7545 -> DC_1 (avg coappear 3.9)
#   SKU 3258 -> DC_1 (avg coappear 3.9)
#   SKU 1180 -> DC_1 (avg coappear 5.0)
#   SKU 6738 -> DC_1 (avg coappear 3.9)
#   SKU 12825 -> DC_1 (avg coappear 3.4)
#   SKU 8874 -> DC_1 (avg coappear 4.2)
#   SKU 2009 -> DC_1 (avg coappear 5.2)
#   SKU 3507 -> DC_1 (avg coappear 4.1)
#   SKU 4937 -> DC_1 (avg coappear 3.5)
#   SKU 7528 -> DC_1 (avg coappear 5.0)
#   SKU 12607 -> DC_1 (avg coappear 2.8)
#   SKU 1656 -> DC_1 (avg coappear 4.4)
#   SKU 3310 -> DC_1 (avg coappear 4.9)
#   SKU 144 -> DC_1 (avg coappear 4.0)
#   SKU 2450 -> DC_1 (avg coappear 3.8)
#   SKU 5840 -> DC_1 (avg coappear 5.5)
#   SKU 1795 -> DC_1 (avg coappear 3.4)
#   SKU 11208 -> DC_1 (avg coappear 3.8)
#   SKU 15355 -> DC_1 (avg coappear 3.4)
#   SKU 2571 -> DC_1 (avg coappear 2.0)
#   SKU 692 -> DC_1 (avg coappear 6.8)
#   SKU 2899 -> DC_1 (avg coappear 3.7)
#   SKU 6457 -> DC_1 (avg coappear 4.9)
#   SKU 7794 -> DC_1 (avg coappear 3.9)
#   SKU 122 -> DC_1 (avg coappear 4.9)
#   SKU 8633 -> DC_1 (avg coappear 3.0)
#   SKU 3926 -> DC_1 (avg coappear 3.5)
#   SKU 4502 -> DC_1 (avg coappear 3.1)
#   SKU 6529 -> DC_1 (avg coappear 4.1)
#   SKU 2644 -> DC_1 (avg coappear 4.0)
#   SKU 6487 -> DC_1 (avg coappear 5.2)
#   SKU 5662 -> DC_1 (avg coappear 2.8)
#   SKU 11978 -> DC_1 (avg coappear 3.5)
#   SKU 6827 -> DC_1 (avg coappear 4.7)
#   SKU 2546 -> DC_1 (avg coappear 5.1)
#   SKU 1763 -> DC_1 (avg coappear 4.8)
#   SKU 4527 -> DC_1 (avg coappear 3.8)
#   SKU 9828 -> DC_1 (avg coappear 2.5)
#   SKU 3561 -> DC_1 (avg coappear 4.4)
#   SKU 1673 -> DC_1 (avg coappear 4.0)
#   SKU 5319 -> DC_1 (avg coappear 4.9)
#   SKU 475 -> DC_1 (avg coappear 4.1)
#   SKU 3617 -> DC_1 (avg coappear 3.9)
#   SKU 11939 -> DC_1 (avg coappear 1.4)
#   SKU 5871 -> DC_1 (avg coappear 3.7)
#   SKU 1192 -> DC_1 (avg coappear 5.0)
#   SKU 2067 -> DC_1 (avg coappear 2.4)
#   SKU 3713 -> DC_1 (avg coappear 4.4)
#   SKU 5411 -> DC_1 (avg coappear 3.7)
#   SKU 7781 -> DC_1 (avg coappear 3.1)
#   SKU 8116 -> DC_1 (avg coappear 3.2)
#   SKU 6477 -> DC_1 (avg coappear 4.6)
#   SKU 7470 -> DC_1 (avg coappear 4.4)
#   SKU 10003 -> DC_1 (avg coappear 2.7)
#   SKU 7984 -> DC_1 (avg coappear 5.4)
#   SKU 9949 -> DC_1 (avg coappear 5.0)
#   SKU 1717 -> DC_1 (avg coappear 3.5)
#   SKU 1595 -> DC_1 (avg coappear 4.9)
#   SKU 13175 -> DC_1 (avg coappear 0.1)
#   SKU 4956 -> DC_1 (avg coappear 5.4)
#   SKU 5698 -> DC_1 (avg coappear 4.7)
#   SKU 14389 -> DC_1 (avg coappear 5.6)
#   SKU 1031 -> DC_1 (avg coappear 3.9)
#   SKU 641 -> DC_1 (avg coappear 4.8)
#   SKU 9594 -> DC_1 (avg coappear 4.7)
#   SKU 9787 -> DC_1 (avg coappear 5.1)
#   SKU 118 -> DC_1 (avg coappear 4.9)
#   SKU 4754 -> DC_1 (avg coappear 4.7)
#   SKU 5561 -> DC_1 (avg coappear 1.7)
#   SKU 4775 -> DC_1 (avg coappear 2.9)
#   SKU 1404 -> DC_1 (avg coappear 4.1)
#   SKU 3321 -> DC_1 (avg coappear 3.7)
#   SKU 9555 -> DC_1 (avg coappear 4.5)
#   SKU 15377 -> DC_1 (avg coappear 2.3)
#   SKU 7258 -> DC_1 (avg coappear 3.9)
#   SKU 6447 -> DC_1 (avg coappear 3.9)
#   SKU 181 -> DC_1 (avg coappear 3.3)
#   SKU 3095 -> DC_1 (avg coappear 3.6)
#   SKU 8542 -> DC_1 (avg coappear 5.7)
#   SKU 7994 -> DC_1 (avg coappear 5.4)
#   SKU 5462 -> DC_1 (avg coappear 4.2)
#   SKU 2721 -> DC_1 (avg coappear 1.6)
#   SKU 13869 -> DC_1 (avg coappear 2.2)
#   SKU 2884 -> DC_1 (avg coappear 3.7)
#   SKU 7324 -> DC_1 (avg coappear 3.4)
#   SKU 4577 -> DC_1 (avg coappear 4.6)
#   SKU 2082 -> DC_1 (avg coappear 3.1)
#   SKU 5925 -> DC_1 (avg coappear 4.7)
#   SKU 4442 -> DC_1 (avg coappear 3.1)
#   SKU 8627 -> DC_1 (avg coappear 2.5)
#   SKU 11606 -> DC_1 (avg coappear 4.8)
#   SKU 4307 -> DC_1 (avg coappear 4.2)
#   SKU 1849 -> DC_1 (avg coappear 2.2)
#   SKU 4890 -> DC_1 (avg coappear 3.9)
#   SKU 6111 -> DC_1 (avg coappear 3.9)
#   SKU 1926 -> DC_1 (avg coappear 3.6)
#   SKU 1231 -> DC_1 (avg coappear 3.5)
#   SKU 2283 -> DC_1 (avg coappear 5.8)
#   SKU 10290 -> DC_1 (avg coappear 4.5)
#   SKU 2663 -> DC_1 (avg coappear 5.5)
#   SKU 76 -> DC_1 (avg coappear 2.9)
#   SKU 9090 -> DC_1 (avg coappear 2.6)
#   SKU 6458 -> DC_1 (avg coappear 3.9)
#   SKU 6651 -> DC_1 (avg coappear 2.8)
#   SKU 3708 -> DC_1 (avg coappear 5.0)
#   SKU 6491 -> DC_1 (avg coappear 4.0)
#   SKU 8848 -> DC_1 (avg coappear 2.9)
#   SKU 5879 -> DC_1 (avg coappear 3.9)
#   SKU 2454 -> DC_1 (avg coappear 3.8)
#   SKU 5800 -> DC_1 (avg coappear 4.2)
#   SKU 14440 -> DC_1 (avg coappear 3.4)
#   SKU 593 -> DC_1 (avg coappear 3.0)
#   SKU 2622 -> DC_1 (avg coappear 4.0)
#   SKU 6412 -> DC_1 (avg coappear 4.5)
#   SKU 3667 -> DC_1 (avg coappear 4.8)
#   SKU 9290 -> DC_1 (avg coappear 3.6)
#   SKU 5177 -> DC_1 (avg coappear 2.1)
#   SKU 5570 -> DC_1 (avg coappear 4.4)
#   SKU 4308 -> DC_1 (avg coappear 4.6)
#   SKU 6309 -> DC_1 (avg coappear 4.2)
#   SKU 8476 -> DC_1 (avg coappear 4.5)
#   SKU 3313 -> DC_1 (avg coappear 3.7)
#   SKU 8005 -> DC_1 (avg coappear 3.2)
#   SKU 12427 -> DC_1 (avg coappear 4.5)
#   SKU 7253 -> DC_1 (avg coappear 5.0)
#   SKU 8285 -> DC_1 (avg coappear 4.6)
#   SKU 8584 -> DC_1 (avg coappear 5.1)
#   SKU 13529 -> DC_1 (avg coappear 2.2)
#   SKU 1038 -> DC_1 (avg coappear 3.3)
#   SKU 4916 -> DC_1 (avg coappear 3.5)
#   SKU 2783 -> DC_1 (avg coappear 5.0)
#   SKU 7706 -> DC_1 (avg coappear 6.4)
#   SKU 7295 -> DC_1 (avg coappear 2.2)
#   SKU 3625 -> DC_1 (avg coappear 4.0)
#   SKU 11962 -> DC_1 (avg coappear 4.0)
#   SKU 500 -> DC_1 (avg coappear 3.7)
#   SKU 2891 -> DC_1 (avg coappear 2.8)
#   SKU 3188 -> DC_1 (avg coappear 2.6)
#   SKU 4416 -> DC_1 (avg coappear 4.7)
#   SKU 1139 -> DC_1 (avg coappear 5.7)
#   SKU 3466 -> DC_1 (avg coappear 5.1)
#   SKU 1242 -> DC_1 (avg coappear 4.0)
#   SKU 8949 -> DC_1 (avg coappear 2.9)
#   SKU 7548 -> DC_1 (avg coappear 4.2)
#   SKU 2803 -> DC_1 (avg coappear 2.0)
#   SKU 7476 -> DC_1 (avg coappear 1.8)
#   SKU 8723 -> DC_1 (avg coappear 3.3)
#   SKU 11983 -> DC_1 (avg coappear 3.2)
#   SKU 3818 -> DC_1 (avg coappear 5.3)
#   SKU 6720 -> DC_1 (avg coappear 4.9)
#   SKU 728 -> DC_1 (avg coappear 3.9)
#   SKU 214 -> DC_1 (avg coappear 2.9)
#   SKU 7605 -> DC_1 (avg coappear 3.7)
#   SKU 5846 -> DC_1 (avg coappear 5.1)
#   SKU 6332 -> DC_1 (avg coappear 5.0)
#   SKU 5204 -> DC_1 (avg coappear 2.7)
#   SKU 7489 -> DC_1 (avg coappear 2.4)
#   SKU 2977 -> DC_1 (avg coappear 5.0)
#   SKU 8782 -> DC_1 (avg coappear 4.1)
#   SKU 3009 -> DC_1 (avg coappear 4.5)
#   SKU 10215 -> DC_1 (avg coappear 5.0)
#   SKU 15431 -> DC_1 (avg coappear 1.9)
#   SKU 3091 -> DC_1 (avg coappear 3.6)
#   SKU 1597 -> DC_1 (avg coappear 4.2)
#   SKU 2006 -> DC_1 (avg coappear 2.7)
#   SKU 6933 -> DC_1 (avg coappear 4.0)
#   SKU 3083 -> DC_1 (avg coappear 5.7)
#   SKU 9011 -> DC_1 (avg coappear 4.9)
#   SKU 3261 -> DC_1 (avg coappear 3.1)
#   SKU 4023 -> DC_1 (avg coappear 3.6)
#   SKU 1699 -> DC_1 (avg coappear 1.2)
#   SKU 1844 -> DC_1 (avg coappear 2.2)
#   SKU 477 -> DC_1 (avg coappear 3.2)
#   SKU 925 -> DC_1 (avg coappear 4.7)
#   SKU 9136 -> DC_1 (avg coappear 3.5)
#   SKU 3092 -> DC_1 (avg coappear 3.9)
#   SKU 4044 -> DC_1 (avg coappear 5.6)
#   SKU 5585 -> DC_1 (avg coappear 6.0)
#   SKU 15349 -> DC_1 (avg coappear 2.2)
#   SKU 9762 -> DC_1 (avg coappear 4.5)
#   SKU 3487 -> DC_1 (avg coappear 4.6)
#   SKU 2722 -> DC_1 (avg coappear 1.8)
#   SKU 11303 -> DC_1 (avg coappear 5.2)
#   SKU 12603 -> DC_1 (avg coappear 4.6)
#   SKU 6116 -> DC_1 (avg coappear 3.4)
#   SKU 4305 -> DC_1 (avg coappear 4.2)
#   SKU 2104 -> DC_1 (avg coappear 4.4)
#   SKU 2892 -> DC_1 (avg coappear 5.4)
#   SKU 14778 -> DC_1 (avg coappear 3.7)
#   SKU 5230 -> DC_1 (avg coappear 5.2)
#   SKU 3821 -> DC_1 (avg coappear 5.2)
#   SKU 4484 -> DC_1 (avg coappear 4.0)
#   SKU 3042 -> DC_1 (avg coappear 4.2)
#   SKU 6319 -> DC_1 (avg coappear 3.0)
#   SKU 9205 -> DC_1 (avg coappear 2.8)
#   SKU 3043 -> DC_1 (avg coappear 4.3)
#   SKU 979 -> DC_1 (avg coappear 4.5)
#   SKU 10085 -> DC_1 (avg coappear 4.2)
#   SKU 1920 -> DC_1 (avg coappear 2.7)
#   SKU 12880 -> DC_1 (avg coappear 2.7)
#   SKU 1809 -> DC_1 (avg coappear 1.8)
#   SKU 2268 -> DC_1 (avg coappear 4.1)
#   SKU 3759 -> DC_1 (avg coappear 4.1)
#   SKU 4004 -> DC_1 (avg coappear 3.7)
#   SKU 13353 -> DC_1 (avg coappear 3.3)
#   SKU 11266 -> DC_1 (avg coappear 3.8)
#   SKU 7154 -> DC_1 (avg coappear 5.9)
#   SKU 362 -> DC_1 (avg coappear 3.7)
#   SKU 3823 -> DC_1 (avg coappear 3.8)
#   SKU 3292 -> DC_1 (avg coappear 4.6)
#   SKU 6007 -> DC_1 (avg coappear 4.2)
#   SKU 7329 -> DC_1 (avg coappear 4.1)
#   SKU 6036 -> DC_1 (avg coappear 3.9)
#   SKU 6059 -> DC_1 (avg coappear 2.6)
#   SKU 2438 -> DC_1 (avg coappear 2.3)
#   SKU 5858 -> DC_1 (avg coappear 3.0)
#   SKU 9225 -> DC_1 (avg coappear 2.1)
#   SKU 3129 -> DC_1 (avg coappear 3.2)
#   SKU 4993 -> DC_1 (avg coappear 3.3)
#   SKU 3909 -> DC_1 (avg coappear 4.9)
#   SKU 15725 -> DC_1 (avg coappear 0.8)
#   SKU 7641 -> DC_1 (avg coappear 3.6)
#   SKU 5789 -> DC_1 (avg coappear 2.9)
#   SKU 5779 -> DC_1 (avg coappear 3.8)
#   SKU 2429 -> DC_1 (avg coappear 3.5)
#   SKU 3901 -> DC_1 (avg coappear 4.6)
#   SKU 190 -> DC_1 (avg coappear 3.1)
#   SKU 3690 -> DC_1 (avg coappear 3.1)
#   SKU 6187 -> DC_1 (avg coappear 3.7)
#   SKU 1276 -> DC_1 (avg coappear 6.3)
#   SKU 3371 -> DC_1 (avg coappear 3.9)
#   SKU 4359 -> DC_1 (avg coappear 3.8)
#   SKU 7309 -> DC_1 (avg coappear 4.0)
#   SKU 517 -> DC_1 (avg coappear 3.6)
#   SKU 5236 -> DC_1 (avg coappear 3.2)
#   SKU 6769 -> DC_1 (avg coappear 4.4)
#   SKU 463 -> DC_1 (avg coappear 3.2)
#   SKU 4449 -> DC_1 (avg coappear 3.9)
#   SKU 7777 -> DC_1 (avg coappear 4.6)
#   SKU 2831 -> DC_1 (avg coappear 3.9)
#   SKU 1317 -> DC_1 (avg coappear 4.6)
#   SKU 4430 -> DC_1 (avg coappear 4.4)
#   SKU 10738 -> DC_1 (avg coappear 5.9)
#   SKU 5245 -> DC_1 (avg coappear 3.1)
#   SKU 2186 -> DC_1 (avg coappear 3.1)
#   SKU 1802 -> DC_1 (avg coappear 4.6)
#   SKU 2836 -> DC_1 (avg coappear 3.7)
#   SKU 5488 -> DC_1 (avg coappear 5.7)
#   SKU 4380 -> DC_1 (avg coappear 3.8)
#   SKU 2424 -> DC_1 (avg coappear 4.3)
#   SKU 15423 -> DC_1 (avg coappear 3.7)
#   SKU 2907 -> DC_1 (avg coappear 3.9)
#   SKU 4183 -> DC_1 (avg coappear 4.4)
#   SKU 13152 -> DC_1 (avg coappear 2.2)
#   SKU 3227 -> DC_1 (avg coappear 3.8)
#   SKU 6531 -> DC_1 (avg coappear 3.1)
#   SKU 407 -> DC_1 (avg coappear 2.5)
#   SKU 166 -> DC_1 (avg coappear 3.3)
#   SKU 2334 -> DC_1 (avg coappear 3.5)
#   SKU 10969 -> DC_1 (avg coappear 4.9)
#   SKU 6274 -> DC_1 (avg coappear 3.9)
#   SKU 11845 -> DC_1 (avg coappear 6.7)
#   SKU 6665 -> DC_1 (avg coappear 1.2)
#   SKU 8229 -> DC_1 (avg coappear 3.6)
#   SKU 6524 -> DC_1 (avg coappear 4.9)
#   SKU 4152 -> DC_1 (avg coappear 3.8)
#   SKU 13294 -> DC_1 (avg coappear 2.2)
#   SKU 7370 -> DC_1 (avg coappear 4.1)
#   SKU 14694 -> DC_1 (avg coappear 4.8)
#   SKU 4310 -> DC_1 (avg coappear 3.8)
#   SKU 406 -> DC_1 (avg coappear 2.4)
#   SKU 8086 -> DC_1 (avg coappear 3.3)
#   SKU 13169 -> DC_1 (avg coappear 0.1)
#   SKU 1109 -> DC_1 (avg coappear 2.6)
#   SKU 6965 -> DC_1 (avg coappear 4.7)
#   SKU 6963 -> DC_1 (avg coappear 3.6)
#   SKU 9125 -> DC_1 (avg coappear 3.0)
#   SKU 2543 -> DC_1 (avg coappear 3.5)
#   SKU 14401 -> DC_1 (avg coappear 4.8)
#   SKU 4025 -> DC_1 (avg coappear 4.7)
#   SKU 9913 -> DC_1 (avg coappear 2.7)
#   SKU 45 -> DC_1 (avg coappear 4.6)
#   SKU 1172 -> DC_1 (avg coappear 1.6)
#   SKU 3189 -> DC_1 (avg coappear 2.6)
#   SKU 4181 -> DC_1 (avg coappear 3.3)
#   SKU 2895 -> DC_1 (avg coappear 5.6)
#   SKU 2799 -> DC_1 (avg coappear 4.3)
#   SKU 2740 -> DC_1 (avg coappear 3.8)
#   SKU 11377 -> DC_1 (avg coappear 3.6)
#   SKU 15292 -> DC_1 (avg coappear 4.0)
#   SKU 10940 -> DC_1 (avg coappear 2.1)
#   SKU 6642 -> DC_1 (avg coappear 3.9)
#   SKU 1598 -> DC_1 (avg coappear 3.7)
#   SKU 6071 -> DC_1 (avg coappear 4.3)
#   SKU 13352 -> DC_1 (avg coappear 2.9)
#   SKU 7216 -> DC_1 (avg coappear 2.5)
#   SKU 3658 -> DC_1 (avg coappear 4.1)
#   SKU 2618 -> DC_1 (avg coappear 3.0)
#   SKU 9172 -> DC_1 (avg coappear 1.4)
#   SKU 10518 -> DC_1 (avg coappear 2.7)
#   SKU 7107 -> DC_1 (avg coappear 2.5)
#   SKU 758 -> DC_1 (avg coappear 3.4)
#   SKU 1422 -> DC_1 (avg coappear 4.4)
#   SKU 6163 -> DC_1 (avg coappear 3.2)
#   SKU 929 -> DC_1 (avg coappear 3.6)
#   SKU 1590 -> DC_1 (avg coappear 4.5)
#   SKU 1927 -> DC_1 (avg coappear 3.4)
#   SKU 9260 -> DC_1 (avg coappear 4.8)
#   SKU 2480 -> DC_1 (avg coappear 2.0)
#   SKU 4153 -> DC_1 (avg coappear 3.9)
#   SKU 8573 -> DC_1 (avg coappear 3.9)
#   SKU 4928 -> DC_1 (avg coappear 4.3)
#   SKU 10500 -> DC_1 (avg coappear 2.2)
#   SKU 5597 -> DC_1 (avg coappear 3.2)
#   SKU 7246 -> DC_1 (avg coappear 3.8)
#   SKU 11405 -> DC_1 (avg coappear 3.9)
#   SKU 1603 -> DC_1 (avg coappear 2.9)
#   SKU 7328 -> DC_1 (avg coappear 3.1)
#   SKU 5212 -> DC_1 (avg coappear 4.4)
#   SKU 4434 -> DC_1 (avg coappear 3.2)
#   SKU 5554 -> DC_1 (avg coappear 4.3)
#   SKU 7726 -> DC_1 (avg coappear 2.9)
#   SKU 11231 -> DC_1 (avg coappear 5.1)
#   SKU 7147 -> DC_1 (avg coappear 5.2)
#   SKU 13196 -> DC_1 (avg coappear 3.0)
#   SKU 5842 -> DC_1 (avg coappear 3.3)
#   SKU 2764 -> DC_1 (avg coappear 3.3)
#   SKU 6112 -> DC_1 (avg coappear 3.5)
#   SKU 5794 -> DC_1 (avg coappear 3.0)
#   SKU 6689 -> DC_1 (avg coappear 4.4)
#   SKU 9669 -> DC_1 (avg coappear 2.4)
#   SKU 15395 -> DC_1 (avg coappear 3.3)
#   SKU 3715 -> DC_1 (avg coappear 3.6)
#   SKU 6701 -> DC_1 (avg coappear 3.7)
#   SKU 4654 -> DC_1 (avg coappear 2.3)
#   SKU 1220 -> DC_1 (avg coappear 2.9)
#   SKU 4499 -> DC_1 (avg coappear 5.6)
#   SKU 799 -> DC_1 (avg coappear 4.0)
#   SKU 2489 -> DC_1 (avg coappear 2.8)
#   SKU 2985 -> DC_1 (avg coappear 2.9)
#   SKU 13013 -> DC_1 (avg coappear 3.4)
# ...
#   SKU 136 -> DC_2 (avg coappear 0.0)
#   SKU 15569 -> DC_2 (avg coappear 0.0)
#   SKU 13801 -> DC_2 (avg coappear 0.0)
#   SKU 14464 -> DC_2 (avg coappear 0.0)
#   SKU 14365 -> DC_2 (avg coappear 0.0)
#   SKU 14657 -> DC_2 (avg coappear 0.0)
#   SKU 14659 -> DC_2 (avg coappear 0.0)
#   SKU 14377 -> DC_2 (avg coappear 0.0)
#   SKU 15079 -> DC_1 (avg coappear 0.0)
#   SKU 12844 -> DC_2 (avg coappear 0.0)
#   SKU 12367 -> DC_2 (avg coappear 0.0)
#   SKU 12843 -> DC_2 (avg coappear 0.0)
#   SKU 14452 -> DC_2 (avg coappear 0.0)
#   SKU 14620 -> DC_2 (avg coappear 0.0)
#   SKU 15020 -> DC_2 (avg coappear 0.0)
#   SKU 14611 -> DC_2 (avg coappear 0.0)
#   SKU 14635 -> DC_2 (avg coappear 0.0)
#   SKU 14904 -> DC_2 (avg coappear 0.0)
#   SKU 16254 -> DC_2 (avg coappear 0.0)
#   SKU 16179 -> DC_2 (avg coappear 0.0)
#   SKU 14974 -> DC_2 (avg coappear 0.0)
#   SKU 14916 -> DC_2 (avg coappear 0.0)
#   SKU 14976 -> DC_2 (avg coappear 0.0)
#   SKU 16177 -> DC_2 (avg coappear 0.0)
#   SKU 16178 -> DC_2 (avg coappear 0.0)
#   SKU 13894 -> DC_2 (avg coappear 0.0)
#   SKU 14968 -> DC_2 (avg coappear 0.0)
#   SKU 15025 -> DC_2 (avg coappear 0.0)
#   SKU 13896 -> DC_2 (avg coappear 0.0)
#   SKU 13893 -> DC_2 (avg coappear 0.0)
#   SKU 16419 -> DC_2 (avg coappear 0.0)
#   SKU 15021 -> DC_2 (avg coappear 0.0)
#   SKU 13899 -> DC_2 (avg coappear 0.0)
#   SKU 16189 -> DC_2 (avg coappear 0.0)
#   SKU 14955 -> DC_2 (avg coappear 0.0)
#   SKU 13901 -> DC_2 (avg coappear 0.0)
#   SKU 16227 -> DC_2 (avg coappear 0.0)
#   SKU 16188 -> DC_2 (avg coappear 0.0)
#   SKU 14934 -> DC_2 (avg coappear 0.0)
#   SKU 15008 -> DC_2 (avg coappear 0.0)
#   SKU 15035 -> DC_2 (avg coappear 0.0)
#   SKU 16184 -> DC_2 (avg coappear 0.0)
#   SKU 14933 -> DC_2 (avg coappear 0.0)
#   SKU 16183 -> DC_2 (avg coappear 0.0)
#   SKU 15012 -> DC_2 (avg coappear 0.0)
#   SKU 16193 -> DC_2 (avg coappear 0.0)
#   SKU 16181 -> DC_2 (avg coappear 0.0)
#   SKU 14926 -> DC_2 (avg coappear 0.0)
#   SKU 15037 -> DC_2 (avg coappear 0.0)
#   SKU 15011 -> DC_2 (avg coappear 0.0)
#   SKU 15009 -> DC_2 (avg coappear 0.0)
#   SKU 14962 -> DC_2 (avg coappear 0.0)
#   SKU 14923 -> DC_2 (avg coappear 0.0)
#   SKU 15019 -> DC_2 (avg coappear 0.0)
#   SKU 16259 -> DC_2 (avg coappear 0.0)
#   SKU 15776 -> DC_2 (avg coappear 0.0)
#   SKU 14884 -> DC_2 (avg coappear 0.0)
#   SKU 14602 -> DC_2 (avg coappear 0.0)
#   SKU 16380 -> DC_2 (avg coappear 0.0)
#   SKU 14463 -> DC_2 (avg coappear 0.0)
#   SKU 14445 -> DC_2 (avg coappear 0.0)
#   SKU 14628 -> DC_2 (avg coappear 0.0)
#   SKU 5904 -> DC_2 (avg coappear 0.0)
#   SKU 16372 -> DC_2 (avg coappear 0.0)
#   SKU 16371 -> DC_2 (avg coappear 0.0)
#   SKU 14633 -> DC_2 (avg coappear 0.0)
#   SKU 14425 -> DC_2 (avg coappear 0.0)
#   SKU 16383 -> DC_2 (avg coappear 0.0)
#   SKU 16368 -> DC_2 (avg coappear 0.0)
#   SKU 16366 -> DC_2 (avg coappear 0.0)
#   SKU 16360 -> DC_2 (avg coappear 0.0)
#   SKU 16359 -> DC_2 (avg coappear 0.0)
#   SKU 14667 -> DC_2 (avg coappear 0.0)
#   SKU 14668 -> DC_2 (avg coappear 0.0)
#   SKU 16351 -> DC_1 (avg coappear 0.0)
#   SKU 14669 -> DC_2 (avg coappear 0.0)
#   SKU 14671 -> DC_2 (avg coappear 0.0)
#   SKU 14672 -> DC_2 (avg coappear 0.0)
#   SKU 14673 -> DC_2 (avg coappear 0.0)
#   SKU 16367 -> DC_2 (avg coappear 0.0)
#   SKU 16384 -> DC_2 (avg coappear 0.0)
#   SKU 16385 -> DC_2 (avg coappear 0.0)
#   SKU 16388 -> DC_2 (avg coappear 0.0)
#   SKU 16418 -> DC_2 (avg coappear 0.0)
#   SKU 16417 -> DC_2 (avg coappear 0.0)
#   SKU 16416 -> DC_2 (avg coappear 0.0)
#   SKU 16414 -> DC_2 (avg coappear 0.0)
#   SKU 16413 -> DC_2 (avg coappear 0.0)
#   SKU 16412 -> DC_2 (avg coappear 0.0)
#   SKU 16411 -> DC_2 (avg coappear 0.0)
#   SKU 16410 -> DC_2 (avg coappear 0.0)
#   SKU 16408 -> DC_2 (avg coappear 0.0)
#   SKU 16407 -> DC_2 (avg coappear 0.0)
#   SKU 16405 -> DC_2 (avg coappear 0.0)
#   SKU 16404 -> DC_2 (avg coappear 0.0)
#   SKU 16403 -> DC_2 (avg coappear 0.0)
#   SKU 14529 -> DC_2 (avg coappear 0.0)
#   SKU 16401 -> DC_2 (avg coappear 0.0)
#   SKU 16398 -> DC_2 (avg coappear 0.0)
#   SKU 16397 -> DC_2 (avg coappear 0.0)
#   SKU 16395 -> DC_2 (avg coappear 0.0)
#   SKU 14513 -> DC_2 (avg coappear 0.0)
#   SKU 16393 -> DC_2 (avg coappear 0.0)
#   SKU 14503 -> DC_2 (avg coappear 0.0)
#   SKU 16391 -> DC_2 (avg coappear 0.0)
#   SKU 14502 -> DC_2 (avg coappear 0.0)
#   SKU 14674 -> DC_2 (avg coappear 0.0)
#   SKU 14886 -> DC_2 (avg coappear 0.0)
#   SKU 14675 -> DC_2 (avg coappear 0.0)
#   SKU 16343 -> DC_2 (avg coappear 0.0)
#   SKU 14770 -> DC_2 (avg coappear 0.0)
#   SKU 14772 -> DC_2 (avg coappear 0.0)
#   SKU 8504 -> DC_2 (avg coappear 0.0)
#   SKU 14782 -> DC_2 (avg coappear 0.0)
#   SKU 14792 -> DC_2 (avg coappear 0.0)
#   SKU 16291 -> DC_2 (avg coappear 0.0)
#   SKU 14799 -> DC_2 (avg coappear 0.0)
#   SKU 14802 -> DC_2 (avg coappear 0.0)
#   SKU 14806 -> DC_2 (avg coappear 0.0)
#   SKU 14807 -> DC_2 (avg coappear 0.0)
#   SKU 14768 -> DC_2 (avg coappear 0.0)
#   SKU 14813 -> DC_2 (avg coappear 0.0)
#   SKU 14815 -> DC_2 (avg coappear 0.0)
#   SKU 14816 -> DC_2 (avg coappear 0.0)
#   SKU 14825 -> DC_2 (avg coappear 0.0)
#   SKU 8423 -> DC_2 (avg coappear 0.0)
#   SKU 8413 -> DC_2 (avg coappear 0.0)
#   SKU 14020 -> DC_2 (avg coappear 0.0)
#   SKU 14013 -> DC_2 (avg coappear 0.0)
#   SKU 16266 -> DC_2 (avg coappear 0.0)
#   SKU 14867 -> DC_2 (avg coappear 0.0)
#   SKU 13930 -> DC_2 (avg coappear 0.0)
#   SKU 14814 -> DC_2 (avg coappear 0.0)
#   SKU 16307 -> DC_2 (avg coappear 0.0)
#   SKU 14766 -> DC_2 (avg coappear 0.0)
#   SKU 14765 -> DC_2 (avg coappear 0.0)
#   SKU 14681 -> DC_2 (avg coappear 0.0)
#   SKU 14236 -> DC_2 (avg coappear 0.0)
#   SKU 16340 -> DC_2 (avg coappear 0.0)
#   SKU 14697 -> DC_2 (avg coappear 0.0)
#   SKU 14234 -> DC_2 (avg coappear 0.0)
#   SKU 14217 -> DC_2 (avg coappear 0.0)
#   SKU 14197 -> DC_2 (avg coappear 0.0)
#   SKU 16334 -> DC_2 (avg coappear 0.0)
#   SKU 16331 -> DC_2 (avg coappear 0.0)
#   SKU 16330 -> DC_2 (avg coappear 0.0)
#   SKU 16327 -> DC_2 (avg coappear 0.0)
#   SKU 14739 -> DC_2 (avg coappear 0.0)
#   SKU 16324 -> DC_2 (avg coappear 0.0)
#   SKU 14141 -> DC_2 (avg coappear 0.0)
#   SKU 14751 -> DC_2 (avg coappear 0.0)
#   SKU 16320 -> DC_2 (avg coappear 0.0)
#   SKU 14752 -> DC_2 (avg coappear 0.0)
#   SKU 16318 -> DC_2 (avg coappear 0.0)
#   SKU 14133 -> DC_2 (avg coappear 0.0)
#   SKU 16176 -> DC_2 (avg coappear 0.0)
#   SKU 16314 -> DC_2 (avg coappear 0.0)
#   SKU 16312 -> DC_2 (avg coappear 0.0)
#   SKU 14764 -> DC_2 (avg coappear 0.0)
#   SKU 16344 -> DC_2 (avg coappear 0.0)
#   SKU 16175 -> DC_2 (avg coappear 0.0)
#   SKU 15107 -> DC_2 (avg coappear 0.0)
#   SKU 16173 -> DC_2 (avg coappear 0.0)
#   SKU 13376 -> DC_2 (avg coappear 0.0)
#   SKU 13341 -> DC_2 (avg coappear 0.0)
#   SKU 13318 -> DC_2 (avg coappear 0.0)
#   SKU 13309 -> DC_2 (avg coappear 0.0)
#   SKU 10537 -> DC_2 (avg coappear 0.0)
#   SKU 13246 -> DC_2 (avg coappear 0.0)
#   SKU 13224 -> DC_2 (avg coappear 0.0)
#   SKU 13223 -> DC_2 (avg coappear 0.0)
#   SKU 13189 -> DC_2 (avg coappear 0.0)
#   SKU 13160 -> DC_2 (avg coappear 0.0)
#   SKU 13107 -> DC_2 (avg coappear 0.0)
#   SKU 13077 -> DC_2 (avg coappear 0.0)
#   SKU 13380 -> DC_2 (avg coappear 0.0)
#   SKU 13023 -> DC_2 (avg coappear 0.0)
#   SKU 12895 -> DC_2 (avg coappear 0.0)
#   SKU 12855 -> DC_2 (avg coappear 0.0)
#   SKU 12853 -> DC_2 (avg coappear 0.0)
#   SKU 12852 -> DC_2 (avg coappear 0.0)
#   SKU 12851 -> DC_2 (avg coappear 0.0)
#   SKU 12849 -> DC_2 (avg coappear 0.0)
#   SKU 12847 -> DC_2 (avg coappear 0.0)
#   SKU 12846 -> DC_2 (avg coappear 0.0)
#   SKU 10820 -> DC_2 (avg coappear 0.0)
#   SKU 15913 -> DC_2 (avg coappear 0.0)
#   SKU 15912 -> DC_2 (avg coappear 0.0)
#   SKU 15911 -> DC_2 (avg coappear 0.0)
#   SKU 1508 -> DC_2 (avg coappear 0.0)
#   SKU 13420 -> DC_2 (avg coappear 0.0)
#   SKU 13424 -> DC_2 (avg coappear 0.0)
#   SKU 15269 -> DC_2 (avg coappear 0.0)
#   SKU 15219 -> DC_2 (avg coappear 0.0)
#   SKU 15222 -> DC_2 (avg coappear 0.0)
#   SKU 7999 -> DC_2 (avg coappear 0.0)
#   SKU 15223 -> DC_2 (avg coappear 0.0)
#   SKU 15224 -> DC_2 (avg coappear 0.0)
#   SKU 15225 -> DC_2 (avg coappear 0.0)
#   SKU 15226 -> DC_2 (avg coappear 0.0)
#   SKU 15227 -> DC_2 (avg coappear 0.0)
#   SKU 15228 -> DC_2 (avg coappear 0.0)
#   SKU 15229 -> DC_2 (avg coappear 0.0)
#   SKU 10044 -> DC_2 (avg coappear 0.0)
#   SKU 13502 -> DC_2 (avg coappear 0.0)
#   SKU 13496 -> DC_2 (avg coappear 0.0)
#   SKU 15242 -> DC_2 (avg coappear 0.0)
#   SKU 13482 -> DC_2 (avg coappear 0.0)
#   SKU 15248 -> DC_2 (avg coappear 0.0)
#   SKU 10162 -> DC_2 (avg coappear 0.0)
#   SKU 15249 -> DC_2 (avg coappear 0.0)
#   SKU 15250 -> DC_2 (avg coappear 0.0)
#   SKU 15251 -> DC_2 (avg coappear 0.0)
#   SKU 15976 -> DC_2 (avg coappear 0.0)
#   SKU 15253 -> DC_2 (avg coappear 0.0)
#   SKU 15973 -> DC_2 (avg coappear 0.0)
#   SKU 15260 -> DC_2 (avg coappear 0.0)
#   SKU 15261 -> DC_2 (avg coappear 0.0)
#   SKU 15265 -> DC_2 (avg coappear 0.0)
#   SKU 15268 -> DC_2 (avg coappear 0.0)
#   SKU 12842 -> DC_2 (avg coappear 0.0)
#   SKU 15907 -> DC_2 (avg coappear 0.0)
#   SKU 12838 -> DC_2 (avg coappear 0.0)
#   SKU 15904 -> DC_2 (avg coappear 0.0)
#   SKU 12195 -> DC_2 (avg coappear 0.0)
#   SKU 15624 -> DC_2 (avg coappear 0.0)
#   SKU 15625 -> DC_2 (avg coappear 0.0)
#   SKU 15841 -> DC_2 (avg coappear 0.0)
#   SKU 12117 -> DC_2 (avg coappear 0.0)
#   SKU 12116 -> DC_2 (avg coappear 0.0)
#   SKU 15836 -> DC_2 (avg coappear 0.0)
#   SKU 15835 -> DC_2 (avg coappear 0.0)
#   SKU 15834 -> DC_2 (avg coappear 0.0)
#   SKU 12081 -> DC_2 (avg coappear 0.0)
#   SKU 11219 -> DC_2 (avg coappear 0.0)
#   SKU 15674 -> DC_2 (avg coappear 0.0)
#   SKU 15823 -> DC_2 (avg coappear 0.0)
#   SKU 15821 -> DC_2 (avg coappear 0.0)
#   SKU 15701 -> DC_2 (avg coappear 0.0)
#   SKU 15818 -> DC_2 (avg coappear 0.0)
#   SKU 15706 -> DC_2 (avg coappear 0.0)
#   SKU 15816 -> DC_2 (avg coappear 0.0)
#   SKU 15718 -> DC_2 (avg coappear 0.0)
#   SKU 15726 -> DC_2 (avg coappear 0.0)
#   SKU 15731 -> DC_2 (avg coappear 0.0)
#   SKU 15734 -> DC_2 (avg coappear 0.0)
#   SKU 11410 -> DC_2 (avg coappear 0.0)
#   SKU 11510 -> DC_2 (avg coappear 0.0)
#   SKU 11507 -> DC_1 (avg coappear 0.0)
#   SKU 11505 -> DC_1 (avg coappear 0.0)
#   SKU 15767 -> DC_2 (avg coappear 0.0)
#   SKU 12196 -> DC_2 (avg coappear 0.0)
#   SKU 15216 -> DC_2 (avg coappear 0.0)
#   SKU 12197 -> DC_2 (avg coappear 0.0)
#   SKU 15852 -> DC_2 (avg coappear 0.0)
#   SKU 15903 -> DC_2 (avg coappear 0.0)
#   SKU 15902 -> DC_2 (avg coappear 0.0)
#   SKU 12804 -> DC_2 (avg coappear 0.0)
#   SKU 15899 -> DC_2 (avg coappear 0.0)
#   SKU 12759 -> DC_2 (avg coappear 0.0)
#   SKU 15896 -> DC_2 (avg coappear 0.0)
#   SKU 15894 -> DC_2 (avg coappear 0.0)
#   SKU 15893 -> DC_2 (avg coappear 0.0)
#   SKU 15891 -> DC_2 (avg coappear 0.0)
#   SKU 15887 -> DC_2 (avg coappear 0.0)
#   SKU 15885 -> DC_2 (avg coappear 0.0)
#   SKU 15884 -> DC_2 (avg coappear 0.0)
#   SKU 12643 -> DC_2 (avg coappear 0.0)
#   SKU 15879 -> DC_2 (avg coappear 0.0)
#   SKU 15539 -> DC_2 (avg coappear 0.0)
#   SKU 12474 -> DC_2 (avg coappear 0.0)
#   SKU 15545 -> DC_2 (avg coappear 0.0)
#   SKU 15870 -> DC_2 (avg coappear 0.0)
#   SKU 15869 -> DC_2 (avg coappear 0.0)
#   SKU 15868 -> DC_2 (avg coappear 0.0)
#   SKU 15867 -> DC_2 (avg coappear 0.0)
#   SKU 15863 -> DC_2 (avg coappear 0.0)
#   SKU 15860 -> DC_2 (avg coappear 0.0)
#   SKU 15580 -> DC_2 (avg coappear 0.0)
#   SKU 15858 -> DC_2 (avg coappear 0.0)
#   SKU 12200 -> DC_2 (avg coappear 0.0)
#   SKU 12199 -> DC_2 (avg coappear 0.0)
#   SKU 12198 -> DC_2 (avg coappear 0.0)
#   SKU 16174 -> DC_2 (avg coappear 0.0)
#   SKU 15212 -> DC_2 (avg coappear 0.0)
#   SKU 15206 -> DC_2 (avg coappear 0.0)
#   SKU 15088 -> DC_2 (avg coappear 0.0)
#   SKU 15089 -> DC_2 (avg coappear 0.0)
#   SKU 16127 -> DC_2 (avg coappear 0.0)
#   SKU 16126 -> DC_2 (avg coappear 0.0)
#   SKU 16125 -> DC_2 (avg coappear 0.0)
#   SKU 16124 -> DC_2 (avg coappear 0.0)
#   SKU 16123 -> DC_2 (avg coappear 0.0)
#   SKU 15090 -> DC_2 (avg coappear 0.0)
#   SKU 16121 -> DC_2 (avg coappear 0.0)
#   SKU 15091 -> DC_2 (avg coappear 0.0)
#   SKU 15092 -> DC_2 (avg coappear 0.0)
#   SKU 15093 -> DC_2 (avg coappear 0.0)
#   SKU 15087 -> DC_2 (avg coappear 0.0)
#   SKU 16117 -> DC_2 (avg coappear 0.0)
#   SKU 15094 -> DC_2 (avg coappear 0.0)
#   SKU 15095 -> DC_2 (avg coappear 0.0)
#   SKU 8150 -> DC_2 (avg coappear 0.0)
#   SKU 8149 -> DC_2 (avg coappear 0.0)
#   SKU 16110 -> DC_2 (avg coappear 0.0)
#   SKU 16107 -> DC_2 (avg coappear 0.0)
#   SKU 16106 -> DC_2 (avg coappear 0.0)
#   SKU 15106 -> DC_2 (avg coappear 0.0)
#   SKU 15108 -> DC_2 (avg coappear 0.0)
#   SKU 15109 -> DC_2 (avg coappear 0.0)
#   SKU 15110 -> DC_2 (avg coappear 0.0)
#   SKU 15114 -> DC_2 (avg coappear 0.0)
#   SKU 16116 -> DC_2 (avg coappear 0.0)
#   SKU 16131 -> DC_2 (avg coappear 0.0)
#   SKU 16132 -> DC_2 (avg coappear 0.0)
#   SKU 15086 -> DC_2 (avg coappear 0.0)
#   SKU 15038 -> DC_2 (avg coappear 0.0)
#   SKU 16169 -> DC_2 (avg coappear 0.0)
#   SKU 16166 -> DC_2 (avg coappear 0.0)
#   SKU 16161 -> DC_2 (avg coappear 0.0)
#   SKU 16160 -> DC_2 (avg coappear 0.0)
#   SKU 16159 -> DC_2 (avg coappear 0.0)
#   SKU 16158 -> DC_2 (avg coappear 0.0)
#   SKU 15060 -> DC_2 (avg coappear 0.0)
#   SKU 16154 -> DC_2 (avg coappear 0.0)
#   SKU 15074 -> DC_2 (avg coappear 0.0)
#   SKU 16152 -> DC_2 (avg coappear 0.0)
#   SKU 16151 -> DC_2 (avg coappear 0.0)
#   SKU 16149 -> DC_2 (avg coappear 0.0)
#   SKU 15076 -> DC_2 (avg coappear 0.0)
#   SKU 15077 -> DC_2 (avg coappear 0.0)
#   SKU 16146 -> DC_2 (avg coappear 0.0)
#   SKU 15078 -> DC_2 (avg coappear 0.0)
#   SKU 16144 -> DC_2 (avg coappear 0.0)
#   SKU 16142 -> DC_2 (avg coappear 0.0)
#   SKU 16141 -> DC_2 (avg coappear 0.0)
#   SKU 15085 -> DC_2 (avg coappear 0.0)
#   SKU 16139 -> DC_2 (avg coappear 0.0)
#   SKU 16138 -> DC_2 (avg coappear 0.0)
#   SKU 16137 -> DC_2 (avg coappear 0.0)
#   SKU 16136 -> DC_2 (avg coappear 0.0)
#   SKU 16135 -> DC_2 (avg coappear 0.0)
#   SKU 16134 -> DC_2 (avg coappear 0.0)
#   SKU 15115 -> DC_2 (avg coappear 0.0)
#   SKU 15117 -> DC_2 (avg coappear 0.0)
#   SKU 15118 -> DC_2 (avg coappear 0.0)
#   SKU 15119 -> DC_2 (avg coappear 0.0)
#   SKU 15155 -> DC_2 (avg coappear 0.0)
#   SKU 16057 -> DC_2 (avg coappear 0.0)
#   SKU 15156 -> DC_2 (avg coappear 0.0)
#   SKU 16055 -> DC_2 (avg coappear 0.0)
#   SKU 16053 -> DC_2 (avg coappear 0.0)
#   SKU 16052 -> DC_2 (avg coappear 0.0)
#   SKU 15158 -> DC_2 (avg coappear 0.0)
#   SKU 15161 -> DC_2 (avg coappear 0.0)
#   SKU 16047 -> DC_2 (avg coappear 0.0)
#   SKU 16046 -> DC_2 (avg coappear 0.0)
#   SKU 16045 -> DC_2 (avg coappear 0.0)
#   SKU 15166 -> DC_2 (avg coappear 0.0)
#   SKU 16040 -> DC_2 (avg coappear 0.0)
#   SKU 15168 -> DC_2 (avg coappear 0.0)
#   SKU 16037 -> DC_2 (avg coappear 0.0)
#   SKU 15169 -> DC_2 (avg coappear 0.0)
#   SKU 15171 -> DC_2 (avg coappear 0.0)
#   SKU 16029 -> DC_2 (avg coappear 0.0)
#   SKU 15179 -> DC_2 (avg coappear 0.0)
#   SKU 15182 -> DC_2 (avg coappear 0.0)
#   SKU 15183 -> DC_2 (avg coappear 0.0)
#   SKU 16022 -> DC_2 (avg coappear 0.0)
#   SKU 15194 -> DC_2 (avg coappear 0.0)
#   SKU 15196 -> DC_2 (avg coappear 0.0)
#   SKU 16017 -> DC_2 (avg coappear 0.0)
#   SKU 15199 -> DC_2 (avg coappear 0.0)
#   SKU 9740 -> DC_2 (avg coappear 0.0)
#   SKU 15154 -> DC_2 (avg coappear 0.0)
#   SKU 15210 -> DC_2 (avg coappear 0.0)
#   SKU 16060 -> DC_2 (avg coappear 0.0)
#   SKU 15151 -> DC_2 (avg coappear 0.0)
#   SKU 15120 -> DC_2 (avg coappear 0.0)
#   SKU 15121 -> DC_2 (avg coappear 0.0)
#   SKU 15122 -> DC_2 (avg coappear 0.0)
#   SKU 16090 -> DC_2 (avg coappear 0.0)
#   SKU 15124 -> DC_2 (avg coappear 0.0)
#   SKU 15128 -> DC_2 (avg coappear 0.0)
#   SKU 16087 -> DC_2 (avg coappear 0.0)
#   SKU 15129 -> DC_2 (avg coappear 0.0)
#   SKU 16085 -> DC_2 (avg coappear 0.0)
#   SKU 15130 -> DC_2 (avg coappear 0.0)
#   SKU 15131 -> DC_2 (avg coappear 0.0)
#   SKU 15132 -> DC_2 (avg coappear 0.0)
#   SKU 15133 -> DC_2 (avg coappear 0.0)
#   SKU 15135 -> DC_2 (avg coappear 0.0)
#   SKU 15136 -> DC_2 (avg coappear 0.0)
#   SKU 15137 -> DC_2 (avg coappear 0.0)
#   SKU 16076 -> DC_2 (avg coappear 0.0)
#   SKU 15138 -> DC_2 (avg coappear 0.0)
#   SKU 16074 -> DC_2 (avg coappear 0.0)
#   SKU 15141 -> DC_2 (avg coappear 0.0)
#   SKU 15143 -> DC_2 (avg coappear 0.0)
#   SKU 15144 -> DC_2 (avg coappear 0.0)
#   SKU 13738 -> DC_2 (avg coappear 0.0)
#   SKU 15148 -> DC_2 (avg coappear 0.0)
#   SKU 16065 -> DC_2 (avg coappear 0.0)
#   SKU 15150 -> DC_2 (avg coappear 0.0)
#   SKU 16063 -> DC_2 (avg coappear 0.0)
#   SKU 15152 -> DC_2 (avg coappear 0.0)
#   SKU 16420 -> DC_1 (avg coappear 0.0)
# Filling remaining capacity by total co-appearance
#
# Final remaining volumes (m3): [1.83826613e-07 6.78677147e+02]

# %%
df_allocation
# Out:
#       Warehouse Articolo
# 0          DC_1    20918
# 1          DC_1     7199
# 2          DC_1    43556
# 3          DC_1     6420
# 4          DC_1    74657
# ...         ...      ...
# 16416      DC_2    55161
# 16417      DC_2   106664
# 16418      DC_2    75927
# 16419      DC_2   103566
# 16420      DC_2   107496
#
# [16421 rows x 2 columns]

# %% [markdown]
# # STATISTICS

# %%
df = pd.merge(df, df_allocation, on='Articolo', how='left')
df['Warehouse'] = df['Warehouse'].replace({'DC_1': 'A', 'DC_2': 'B'})
df
# Out:
#          Unnamed: 0  Num. Ordine Mese-Giorno Articolo  \
# 0                 0       738378       04-18    20918
# 1                 1       738379       04-18     3456
# 2                 2       738379       04-18     7199
# 3                 3       738379       04-18    43556
# 4                 4       738379       04-18    50045
# ...             ...          ...         ...      ...
# 2298719     2447292       791134       12-29    92720
# 2298720     2447293       791134       12-29    98819
# 2298721     2447294       791134       12-29   105877
# 2298722     2447295       791134       12-29   107171
# 2298723     2447296       791140       12-30   107904
#
#                                       Descrizione  Pezzi ordinati  \
# 0         CAREFREE COTTON SALVASLIP 44 PZ.DISTESO               6
# 1        STUDIO L.5 INVISI FIX GEL FOR.LIQ.150ml                6
# 2        STUDIO L.8 FIX&FORCE GEL IPERFOR.150 ML.               6
# 3         STUDIO L.9 INDESTRUC.GEL ESTREMO 150 ML               6
# 4        STUDIO L.5 INVISI FIX GEL CR.FOR.VAS.150               6
# ...                                           ...             ...
# 2298719     CHANTECLAIR SGRASS.600 MLx2 PZ.LIMONE               1
# 2298720    VIM GEL BAGNO 5in1 ANTICALCARE 1000 ML               1
# 2298721  CIF CREMA GREEN ACTIVE 500 ML PINK BLOOM               1
# 2298722      OMINO B.DET.IDROCAPS SALVAFIBRE 20pz               1
# 2298723  ACE LAVAT.LIQ.27 LAVx3 PZ MELAeCANNELLA                2
#
#          Pezzi evasi  Pz x CT  Pz x TH  Volume pezzo  ...               Ecr2  \
# 0                  6       24        0      1.288000  ...  Igienico Sanitari
# 1                  6        6        0      0.378000  ...            Capelli
# 2                  6        6        0      0.303750  ...            Capelli
# 3                  6        6        0      0.720000  ...            Capelli
# 4                  6        6        0      0.405000  ...            Capelli
# ...              ...      ...      ...           ...  ...                ...
# 2298719            1        6        0      3.271125  ...          Superfici
# 2298720            1       12        0      1.559250  ...              Bagno
# 2298721            1       16        0      0.728000  ...          Superfici
# 2298722            1        8        0      2.025000  ...             Bucato
# 2298723            2        1        0     10.620000  ...             Bucato
#
#                           Ecr3                         Ecr4         Canale  \
# 0                   Assorbenti     Salvaslip e Proteggislip  Piume Diretti
# 1              Styling Capelli           Gel e Cere Capelli  Piume Diretti
# 2              Styling Capelli           Gel e Cere Capelli  Piume Diretti
# 3              Styling Capelli           Gel e Cere Capelli  Piume Diretti
# 4              Styling Capelli           Gel e Cere Capelli  Piume Diretti
# ...                        ...                          ...            ...
# 2298719   Detergenti Superfici                  Sgrassatori            B2C
# 2298720  Detergenti Bagno e WC             Detergenti Bagno            B2C
# 2298721   Detergenti Superfici          Detergenti Multiuso            B2C
# 2298722       Detersivi Bucato  Detersivi Capsule Lavatrice            B2C
# 2298723       Detersivi Bucato  Detersivi Liquido Lavatrice            B2C
#
#          Cliente  PV  Percorso Giacenza Pezzi Volume [m3]  Volume evaso [m3]  \
# 0        2104490  SM        26                   3.474766           0.007728
# 1        2104490  SM        26                   0.206955           0.002268
# 2        2104490  SM        26                   0.140424           0.001823
# 3        2104490  SM        26                   0.419256           0.004320
# 4        2104490  SM        26                   0.148149           0.002430
# ...          ...  ..       ...                        ...                ...
# 2298719  2152842  UD       999                   2.330022           0.003271
# 2298720  2152842  UD       999                   0.943970           0.001559
# 2298721  2152842  UD       999                   0.743142           0.000728
# 2298722  2152842  UD       999                   0.532170           0.002025
# 2298723  2152843  PT       999                   7.441434           0.021240
#
#          Warehouse
# 0                A
# 1                B
# 2                A
# 3                A
# 4                B
# ...            ...
# 2298719          B
# 2298720          A
# 2298721          A
# 2298722          B
# 2298723          B
#
# [2298724 rows x 22 columns]

# %%
df_results = pd.DataFrame.from_dict(
    {
        'Magazzino A': [],
        'Magazzino B':[],
        
        'Codici in A':[],
        'Codici in B':[],
        
        'Stock [m3] in A':[],
        'Stock [m3] in B':[],
        
        '% Ordini completati in AB':[],
        '% Ordini completati in A':[], 
        '% Ordini completati in B':[],

        'Vol[m3] Ordini completati in A':[], 
        'Vol[m3] Ordini completati in B':[],
        'Vol[m3] Ordini completati in AB':[],
        'Vol[m3] Ordini completati in AB (A)':[],
        'Vol[m3] Ordini completati in AB (B)':[],
        
        '% Rotte completate in AB' :[],
        '% Rotte completate in A' :[],
        '% Rotte completate in B' :[],

        'Vol[m3] Rotte completati in A' :[],
        'Vol[m3] Rotte completati in B' :[],
        'Vol[m3] Rotte completati in AB' :[],
        'Vol[m3] Rotte completati in AB (A)' :[],
        'Vol[m3] Rotte completati in AB (B)' :[],

    }
)
df_results
# Out:
# Empty DataFrame
# Columns: [Magazzino A, Magazzino B, Codici in A, Codici in B, Stock [m3] in A, Stock [m3] in B, % Ordini completati in AB, % Ordini completati in A, % Ordini completati in B, Vol[m3] Ordini completati in A, Vol[m3] Ordini completati in B, Vol[m3] Ordini completati in AB, Vol[m3] Ordini completati in AB (A), Vol[m3] Ordini completati in AB (B), % Rotte completate in AB, % Rotte completate in A, % Rotte completate in B, Vol[m3] Rotte completati in A, Vol[m3] Rotte completati in B, Vol[m3] Rotte completati in AB, Vol[m3] Rotte completati in AB (A), Vol[m3] Rotte completati in AB (B)]
# Index: []
#
# [0 rows x 22 columns]

# %%
assignment_A = df.groupby('Warehouse')['Articolo'].unique().get('A', 0)
assignment_B = df.groupby('Warehouse')['Articolo'].unique().get('B', 0)

code_A = df.groupby('Warehouse')['Articolo'].nunique().get('A', 0)
code_B = df.groupby('Warehouse')['Articolo'].nunique().get('B', 0)
# print('Article division', article_division)

#Order analysis
order_grouped_df = df.groupby(['Mese-Giorno','Num. Ordine']).agg({
    'Warehouse': lambda x: list(x.unique()),  # Stores unique warehouses as lists
    'Volume evaso [m3]': 'sum'  # Sums up volume
}).reset_index()

order_movment_A = len(order_grouped_df[order_grouped_df['Warehouse'].astype(str).str.contains(r"'A'") & ~order_grouped_df['Warehouse'].astype(str).str.contains(r"'B'")]) / len(order_grouped_df) * 100
order_movment_B = len(order_grouped_df[order_grouped_df['Warehouse'].astype(str).str.contains(r"'B'") & ~order_grouped_df['Warehouse'].astype(str).str.contains(r"'A'")]) / len(order_grouped_df) * 100
order_movment_AB = len(order_grouped_df[order_grouped_df['Warehouse'].astype(str).str.contains(r"'A'") & order_grouped_df['Warehouse'].astype(str).str.contains(r"'B'")]) / len(order_grouped_df) * 100

order_vol_A = order_grouped_df[order_grouped_df['Warehouse'].astype(str).str.contains(r"'A'") & ~order_grouped_df['Warehouse'].astype(str).str.contains(r"'B'")]['Volume evaso [m3]'].sum() 
order_vol_B = order_grouped_df[order_grouped_df['Warehouse'].astype(str).str.contains(r"'B'") & ~order_grouped_df['Warehouse'].astype(str).str.contains(r"'A'")]['Volume evaso [m3]'].sum() 
order_vol_AB = order_grouped_df[order_grouped_df['Warehouse'].astype(str).str.contains(r"'A'") & order_grouped_df['Warehouse'].astype(str).str.contains(r"'B'")]['Volume evaso [m3]'].sum()

AB_order_list = list(order_grouped_df[order_grouped_df['Warehouse'].astype(str).str.contains(r"'A'") & order_grouped_df['Warehouse'].astype(str).str.contains(r"'B'")]['Num. Ordine'])
df_AB_order_volume = df.groupby(['Num. Ordine','Warehouse'])[['Volume evaso [m3]']].sum().reset_index()
df_AB_order_volume = df_AB_order_volume[df_AB_order_volume['Num. Ordine'].isin(AB_order_list)].groupby('Warehouse')['Volume evaso [m3]'].sum()

#Route analysis
route_grouped_df = df.groupby(['Mese-Giorno','Percorso']).agg({
    'Warehouse': lambda x: list(x.unique()),  # Stores unique warehouses as lists
    'Volume evaso [m3]': 'sum'  # Sums up volume
}).reset_index()

route_movment_A = len(route_grouped_df[route_grouped_df['Warehouse'].astype(str).str.contains(r"'A'") & ~route_grouped_df['Warehouse'].astype(str).str.contains(r"'B'")]) / len(route_grouped_df) * 100
route_movment_B = len(route_grouped_df[route_grouped_df['Warehouse'].astype(str).str.contains(r"'B'") & ~route_grouped_df['Warehouse'].astype(str).str.contains(r"'A'")]) / len(route_grouped_df) * 100
route_movment_AB = len(route_grouped_df[route_grouped_df['Warehouse'].astype(str).str.contains(r"'A'") & route_grouped_df['Warehouse'].astype(str).str.contains(r"'B'")]) / len(route_grouped_df) * 100

route_vol_A = route_grouped_df[route_grouped_df['Warehouse'].astype(str).str.contains(r"'A'") & ~route_grouped_df['Warehouse'].astype(str).str.contains(r"'B'")]['Volume evaso [m3]'].sum() 
route_vol_B = route_grouped_df[route_grouped_df['Warehouse'].astype(str).str.contains(r"'B'") & ~route_grouped_df['Warehouse'].astype(str).str.contains(r"'A'")]['Volume evaso [m3]'].sum() 
route_vol_AB = route_grouped_df[route_grouped_df['Warehouse'].astype(str).str.contains(r"'A'") & route_grouped_df['Warehouse'].astype(str).str.contains(r"'B'")]['Volume evaso [m3]'].sum()

# Step 1: Extract valid routes containing both 'A' and 'B' in 'Warehouse'
AB_order_list = route_grouped_df[
    route_grouped_df['Warehouse'].astype(str).str.contains(r'A') & 
    route_grouped_df['Warehouse'].astype(str).str.contains(r'B')
][['Mese-Giorno', 'Percorso']].apply(tuple, axis=1).tolist()

# Step 2: Compute total volume for each route
df_AB_route_volume = df.groupby(['Mese-Giorno', 'Percorso', 'Warehouse'])[['Volume evaso [m3]']].sum().reset_index()

# Step 3: Filter only the relevant routes and sum by Warehouse
df_AB_route_volume = df_AB_route_volume[
    df_AB_route_volume[['Mese-Giorno', 'Percorso']].apply(tuple, axis=1).isin(AB_order_list)
].groupby('Warehouse')['Volume evaso [m3]'].sum()


weighted_stock = df.groupby(['Articolo','Warehouse',])['Giacenza Pezzi Volume [m3]'].mean() * (df.groupby(['Articolo','Warehouse',])['Pezzi evasi'].sum() / df.groupby(['Articolo'])['Pezzi evasi'].sum())
stock_A = weighted_stock.groupby('Warehouse').sum().get('A', 0)
stock_B = weighted_stock.groupby('Warehouse').sum().get('B', 0)

df_results = pd.DataFrame.from_dict(
    {
        'Magazzino A': [assignment_A],
        'Magazzino B': [assignment_B],
        
        'Codici in A':[code_A],
        'Codici in B':[code_B],
        
        'Stock [m3] in A':[stock_A],
        'Stock [m3] in B':[stock_B],
        
        '% Ordini completati in AB':[order_movment_AB],
        '% Ordini completati in A':[order_movment_A],
        '% Ordini completati in B':[order_movment_B],

        '% Rotte completate in AB':[route_movment_AB],
        '% Rotte completate in A':[route_movment_A],
        '% Rotte completate in B':[route_movment_B],

        'Vol[m3] Ordini completati in A':[order_vol_A],
        'Vol[m3] Ordini completati in B':[order_vol_B],
        'Vol[m3] Ordini completati in AB':[order_vol_AB],
        'Vol[m3] Ordini completati in AB (A)':[df_AB_order_volume.get('A', 0)],
        'Vol[m3] Ordini completati in AB (B)':[df_AB_order_volume.get('B', 0)],


        'Vol[m3] Rotte completati in A':[route_vol_A],
        'Vol[m3] Rotte completati in B':[route_vol_B],
        'Vol[m3] Rotte completati in AB':[route_vol_AB],
        'Vol[m3] Rotte completati in AB (A)' :[df_AB_route_volume.get('A', 0)],
        'Vol[m3] Rotte completati in AB (B)' :[df_AB_route_volume.get('B', 0)],

        
    }
)

# %%
df_results
# Out:
#                                          Magazzino A  \
# 0  [20918, 7199, 43556, 74657, 27577, 96607, 1041...
#
#                                          Magazzino B  Codici in A  \
# 0  [3456, 50045, 27576, 96145, 85476, 90696, 1050...         3728
#
#    Codici in B  Stock [m3] in A  Stock [m3] in B  % Ordini completati in AB  \
# 0        12693      4446.333614      2393.665276                  71.142841
#
#    % Ordini completati in A  % Ordini completati in B  \
# 0                 15.543919                  13.31324
#
#    % Rotte completate in AB  ...  Vol[m3] Ordini completati in A  \
# 0                 92.041411  ...                     1829.275681
#
#    Vol[m3] Ordini completati in B  Vol[m3] Ordini completati in AB  \
# 0                      376.704195                     35127.087319
#
#    Vol[m3] Ordini completati in AB (A)  Vol[m3] Ordini completati in AB (B)  \
# 0                         27343.215762                          7783.871557
#
#    Vol[m3] Rotte completati in A  Vol[m3] Rotte completati in B  \
# 0                     249.509959                       88.65531
#
#    Vol[m3] Rotte completati in AB  Vol[m3] Rotte completati in AB (A)  \
# 0                    36994.901927                        28922.981485
#
#    Vol[m3] Rotte completati in AB (B)
# 0                         8071.920442
#
# [1 rows x 22 columns]

# %%
df_results.to_excel(r'C:\Users\Matteo.Gabellini\OneDrive - Alma Mater Studiorum Università di Bologna\DOTTORATO\1.RICERCA\0.CONFERENCE PAPER\6.ICIL\1.WAREHOUSE ALLOCATION\3.RESULTS\CATELAN_4.xlsx')
