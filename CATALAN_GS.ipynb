# %% [markdown]
# # IMPORT LIBRARIES

# %%
import pandas as pd
import random
from pyomo.environ import *
import numpy as np
import time
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.sparse import coo_matrix

# %%
# 1. Build the binary order–SKU matrix R
def build_R(df, order_col='Num. Ordine', sku_col='Articolo'):
    df_unique = df[[order_col, sku_col]].drop_duplicates()
    orders = df_unique[order_col].unique()
    skus = df_unique[sku_col].unique()
    order_idx = pd.Series(np.arange(len(orders)), index=orders)
    sku_idx = pd.Series(np.arange(len(skus)), index=skus)
    rows = df_unique[order_col].map(order_idx).values
    cols = df_unique[sku_col].map(sku_idx).values
    data = np.ones(len(df_unique), dtype=int)
    R = coo_matrix((data, (rows, cols)), shape=(len(orders), len(skus)))
    return R, orders, skus

# %%
# 3. GREEDY SEEDS WITH VOLUME heuristic
def greedy_seeds_volume(R, k_volume, sku_volumes, debug=False):
    """
    Greedy SEEDS allocation by DC seeds & coappearances, with volume constraints.
    """
    R_csr = R.tocsr()
    n_orders, n_skus = R_csr.shape
    n_dcs = len(k_volume)
    
    # Compute co-occurrence matrix and sales
    C = (R_csr.T).dot(R_csr).toarray()
    sales = np.diag(C)  # #orders per SKU
    
    # Sort SKUs by descending sales, DCs by descending capacity
    sku_by_sales = np.argsort(-sales)
    sorted_dcs    = np.argsort(-k_volume)
    
    if debug:
        print("Top 5 SKUs by sales:", sku_ids[sku_by_sales[:5]])
        print("DCs sorted by capacity:", sorted_dcs)
    
    allocation = [set() for _ in range(n_dcs)]
    remaining  = k_volume.copy()
    
    # 4. Seed largest DC with top SKU
    top_sku = sku_by_sales[0]
    top_dc  = sorted_dcs[0]
    if remaining[top_dc] >= sku_volumes[top_sku]:
        allocation[top_dc].add(top_sku)
        remaining[top_dc] -= sku_volumes[top_sku]
        if debug:
            print(f"Seed DC_{top_dc+1} with SKU {sku_ids[top_sku]}")
    
    # 5. Seed other DCs
    top_n = max(1, int(0.1 * n_skus))
    top_decile = set(sku_by_sales[:top_n])
    allocated_total = {top_sku}
    for d in sorted_dcs[1:]:
        # Candidates: unallocated & in top decile & fits capacity
        unallocated = [s for s in range(n_skus) if s not in allocated_total and sku_volumes[s] <= remaining[d]]
        cand = [s for s in unallocated if s in top_decile]
        if not cand:
            cand = unallocated
        # least coappearance with allocated_total
        scores = np.array([C[s, list(allocated_total)].sum() for s in cand])
        s_seed = cand[int(np.argmin(scores))]
        allocation[d].add(s_seed)
        remaining[d] -= sku_volumes[s_seed]
        allocated_total.add(s_seed)
        if debug:
            print(f"Seed DC_{d+1} with SKU {sku_ids[s_seed]} (least coappears)")

    # 6. Assign remaining SKUs by highest avg coappearance
    if debug:
        print("\nAssigning remaining SKUs by average coappearance")
    for s in sku_by_sales:
        if s in allocated_total: continue
        # for each DC with capacity
        best_dc, best_score = None, -np.inf
        for d in sorted_dcs:
            if sku_volumes[s] > remaining[d]: continue
            alloc_d = list(allocation[d])
            if alloc_d:
                avg = C[s, alloc_d].mean()
            else:
                avg = 0
            if avg > best_score:
                best_score, best_dc = avg, d
        if best_dc is not None:
            allocation[best_dc].add(s)
            remaining[best_dc] -= sku_volumes[s]
            allocated_total.add(s)
            if debug:
                print(f"SKU {sku_ids[s]} -> DC_{best_dc+1} (avg coappear {best_score:.1f})")

    # 7. Fill remaining capacity by highest coappearance
    if debug:
        print("\nFilling remaining capacity")
    while True:
        allocated_flag = False
        for d in sorted_dcs:
            cap = remaining[d]
            # candidates not allocated and fit
            cand = [s for s in range(n_skus) if s not in allocated_total and sku_volumes[s] <= cap]
            if not cand:
                continue
            scores = C[list(allocation[d]), :].sum(axis=0) if allocation[d] else C.sum(axis=0)
            mask = np.full(n_skus, -np.inf)
            mask[cand] = scores[cand]
            s_best = int(np.argmax(mask))
            allocation[d].add(s_best)
            remaining[d] -= sku_volumes[s_best]
            allocated_total.add(s_best)
            allocated_flag = True
            if debug:
                print(f"DC_{d+1}: added SKU {sku_ids[s_best]} (score {scores[s_best]:.0f})")
        if not allocated_flag:
            if debug:
                print("No further allocations possible.")
            break
    
    return allocation, remaining

# %% [markdown]
# # IMPORT DATA

# %%
df = pd.read_csv(r'C:\Users\Matteo.Gabellini\OneDrive - Alma Mater Studiorum Università di Bologna\DOTTORATO\1.RICERCA\0.CONFERENCE PAPER\6.ICIL\1.WAREHOUSE ALLOCATION\0.DATA\DatasetClean.csv')
df['Articolo'] = df['Articolo'].astype(str)
df
# Out:
#          Unnamed: 0  Num. Ordine Mese-Giorno Articolo  \
# 0                 0       738378       04-18    20918
# 1                 1       738379       04-18     3456
# 2                 2       738379       04-18     7199
# 3                 3       738379       04-18    43556
# 4                 4       738379       04-18    50045
# ...             ...          ...         ...      ...
# 2447292     2447292       791134       12-29    92720
# 2447293     2447293       791134       12-29    98819
# 2447294     2447294       791134       12-29   105877
# 2447295     2447295       791134       12-29   107171
# 2447296     2447296       791140       12-30   107904
#
#                                       Descrizione  Pezzi ordinati  \
# 0         CAREFREE COTTON SALVASLIP 44 PZ.DISTESO               6
# 1        STUDIO L.5 INVISI FIX GEL FOR.LIQ.150ml                6
# 2        STUDIO L.8 FIX&FORCE GEL IPERFOR.150 ML.               6
# 3         STUDIO L.9 INDESTRUC.GEL ESTREMO 150 ML               6
# 4        STUDIO L.5 INVISI FIX GEL CR.FOR.VAS.150               6
# ...                                           ...             ...
# 2447292     CHANTECLAIR SGRASS.600 MLx2 PZ.LIMONE               1
# 2447293    VIM GEL BAGNO 5in1 ANTICALCARE 1000 ML               1
# 2447294  CIF CREMA GREEN ACTIVE 500 ML PINK BLOOM               1
# 2447295      OMINO B.DET.IDROCAPS SALVAFIBRE 20pz               1
# 2447296  ACE LAVAT.LIQ.27 LAVx3 PZ MELAeCANNELLA                2
#
#          Pezzi evasi  Pz x CT  Pz x TH  Volume pezzo  Volume cartone  \
# 0                  6       24        0      1.288000        33.96900
# 1                  6        6        0      0.378000         2.66000
# 2                  6        6        0      0.303750         2.94400
# 3                  6        6        0      0.720000         2.81600
# 4                  6        6        0      0.405000         2.54375
# ...              ...      ...      ...           ...             ...
# 2447292            1        6        0      3.271125        23.04000
# 2447293            1       12        0      1.559250        25.63600
# 2447294            1       16        0      0.728000        17.02400
# 2447295            1        8        0      2.025000        20.46000
# 2447296            2        1        0     10.620000        10.62000
#
#                   Ecr1               Ecr2                   Ecr3  \
# 0         Cura Persona  Igienico Sanitari             Assorbenti
# 1         Cura Persona            Capelli        Styling Capelli
# 2         Cura Persona            Capelli        Styling Capelli
# 3         Cura Persona            Capelli        Styling Capelli
# 4         Cura Persona            Capelli        Styling Capelli
# ...                ...                ...                    ...
# 2447292  Casa e Bucato          Superfici   Detergenti Superfici
# 2447293  Casa e Bucato              Bagno  Detergenti Bagno e WC
# 2447294  Casa e Bucato          Superfici   Detergenti Superfici
# 2447295  Casa e Bucato             Bucato       Detersivi Bucato
# 2447296  Casa e Bucato             Bucato       Detersivi Bucato
#
#                                 Ecr4         Canale  Cliente  PV  Percorso
# 0           Salvaslip e Proteggislip  Piume Diretti  2104490  SM        26
# 1                 Gel e Cere Capelli  Piume Diretti  2104490  SM        26
# 2                 Gel e Cere Capelli  Piume Diretti  2104490  SM        26
# 3                 Gel e Cere Capelli  Piume Diretti  2104490  SM        26
# 4                 Gel e Cere Capelli  Piume Diretti  2104490  SM        26
# ...                              ...            ...      ...  ..       ...
# 2447292                  Sgrassatori            B2C  2152842  UD       999
# 2447293             Detergenti Bagno            B2C  2152842  UD       999
# 2447294          Detergenti Multiuso            B2C  2152842  UD       999
# 2447295  Detersivi Capsule Lavatrice            B2C  2152842  UD       999
# 2447296  Detersivi Liquido Lavatrice            B2C  2152843  PT       999
#
# [2447297 rows x 19 columns]

# %%
df_vol = df.groupby('Articolo')[['Volume pezzo']].median().reset_index()
df_vol
# Out:
#       Articolo  Volume pezzo
# 0       100002      0.060000
# 1       100003      0.060000
# 2       100004      0.060000
# 3       100005      0.060000
# 4       100006      0.060000
# ...        ...           ...
# 18655    99972      0.059375
# 18656    99973      0.270000
# 18657    99974      3.312000
# 18658    99975      0.084000
# 18659    99976      0.135000
#
# [18660 rows x 2 columns]

# %%
df_stock = pd.read_excel(r'C:\Users\Matteo.Gabellini\OneDrive - Alma Mater Studiorum Università di Bologna\DOTTORATO\1.RICERCA\0.CONFERENCE PAPER\6.ICIL\1.WAREHOUSE ALLOCATION\0.DATA\Giacenza media articoli 2024.xlsx')
df_stock['ARTICOLO'] = df_stock['ARTICOLO'].astype(str)
df_stock = df_stock.groupby('ARTICOLO')[['GIACENZA MEDIA']].mean().reset_index()
df_stock
# Out:
#       ARTICOLO  GIACENZA MEDIA
# 0       100002          1057.6
# 1       100003           735.4
# 2       100004          1072.4
# 3       100005          1170.0
# 4       100006          1232.2
# ...        ...             ...
# 20919    99972            19.2
# 20920    99973            26.5
# 20921    99974            13.9
# 20922    99975             7.0
# 20923    99976            22.0
#
# [20924 rows x 2 columns]

# %%
# Perform the join based on 'Articolo'
df_stock_vol = df_stock.merge(df_vol[['Articolo','Volume pezzo']], how='left', left_on='ARTICOLO', right_on='Articolo')

# Drop duplicate column 'ARTICOLO' after merge
df_stock_vol.drop(columns=['Articolo'], inplace=True)

#Compute stock in volum
df_stock_vol['Giacenza Pezzi Volume [m3]'] = df_stock_vol['Volume pezzo'] / 1000
df_stock_vol['Giacenza Pezzi Volume [m3]'] = df_stock_vol['GIACENZA MEDIA'] * df_stock_vol['Giacenza Pezzi Volume [m3]']

#df_stock_vol = df_stock_vol.drop_duplicates()

df_stock_vol
# Out:
#       ARTICOLO  GIACENZA MEDIA  Volume pezzo  Giacenza Pezzi Volume [m3]
# 0       100002          1057.6      0.060000                    0.063456
# 1       100003           735.4      0.060000                    0.044124
# 2       100004          1072.4      0.060000                    0.064344
# 3       100005          1170.0      0.060000                    0.070200
# 4       100006          1232.2      0.060000                    0.073932
# ...        ...             ...           ...                         ...
# 20919    99972            19.2      0.059375                    0.001140
# 20920    99973            26.5      0.270000                    0.007155
# 20921    99974            13.9      3.312000                    0.046037
# 20922    99975             7.0      0.084000                    0.000588
# 20923    99976            22.0      0.135000                    0.002970
#
# [20924 rows x 4 columns]

# %%
df_stock_vol['Giacenza Pezzi Volume [m3]'].sum()
# Out:
# 9121.832503351417

# %%
# Perform a left join to maintain the original number of rows in df
df = df.merge(df_stock_vol[['ARTICOLO', 'Giacenza Pezzi Volume [m3]']], how='left', left_on='Articolo', right_on='ARTICOLO')

df['Volume evaso [m3]'] = df['Pezzi evasi'] * df['Volume pezzo'] / 1000

# Drop the extra 'ARTICOLO' column from df_stock_vol (after the merge)
df.drop(columns=['ARTICOLO'], inplace=True)

# Ensure no additional duplicates were introduced
#df = df.drop_duplicates()

df
# Out:
#          Unnamed: 0  Num. Ordine Mese-Giorno Articolo  \
# 0                 0       738378       04-18    20918
# 1                 1       738379       04-18     3456
# 2                 2       738379       04-18     7199
# 3                 3       738379       04-18    43556
# 4                 4       738379       04-18    50045
# ...             ...          ...         ...      ...
# 2447292     2447292       791134       12-29    92720
# 2447293     2447293       791134       12-29    98819
# 2447294     2447294       791134       12-29   105877
# 2447295     2447295       791134       12-29   107171
# 2447296     2447296       791140       12-30   107904
#
#                                       Descrizione  Pezzi ordinati  \
# 0         CAREFREE COTTON SALVASLIP 44 PZ.DISTESO               6
# 1        STUDIO L.5 INVISI FIX GEL FOR.LIQ.150ml                6
# 2        STUDIO L.8 FIX&FORCE GEL IPERFOR.150 ML.               6
# 3         STUDIO L.9 INDESTRUC.GEL ESTREMO 150 ML               6
# 4        STUDIO L.5 INVISI FIX GEL CR.FOR.VAS.150               6
# ...                                           ...             ...
# 2447292     CHANTECLAIR SGRASS.600 MLx2 PZ.LIMONE               1
# 2447293    VIM GEL BAGNO 5in1 ANTICALCARE 1000 ML               1
# 2447294  CIF CREMA GREEN ACTIVE 500 ML PINK BLOOM               1
# 2447295      OMINO B.DET.IDROCAPS SALVAFIBRE 20pz               1
# 2447296  ACE LAVAT.LIQ.27 LAVx3 PZ MELAeCANNELLA                2
#
#          Pezzi evasi  Pz x CT  Pz x TH  Volume pezzo  ...           Ecr1  \
# 0                  6       24        0      1.288000  ...   Cura Persona
# 1                  6        6        0      0.378000  ...   Cura Persona
# 2                  6        6        0      0.303750  ...   Cura Persona
# 3                  6        6        0      0.720000  ...   Cura Persona
# 4                  6        6        0      0.405000  ...   Cura Persona
# ...              ...      ...      ...           ...  ...            ...
# 2447292            1        6        0      3.271125  ...  Casa e Bucato
# 2447293            1       12        0      1.559250  ...  Casa e Bucato
# 2447294            1       16        0      0.728000  ...  Casa e Bucato
# 2447295            1        8        0      2.025000  ...  Casa e Bucato
# 2447296            2        1        0     10.620000  ...  Casa e Bucato
#
#                       Ecr2                   Ecr3  \
# 0        Igienico Sanitari             Assorbenti
# 1                  Capelli        Styling Capelli
# 2                  Capelli        Styling Capelli
# 3                  Capelli        Styling Capelli
# 4                  Capelli        Styling Capelli
# ...                    ...                    ...
# 2447292          Superfici   Detergenti Superfici
# 2447293              Bagno  Detergenti Bagno e WC
# 2447294          Superfici   Detergenti Superfici
# 2447295             Bucato       Detersivi Bucato
# 2447296             Bucato       Detersivi Bucato
#
#                                 Ecr4         Canale  Cliente  PV Percorso  \
# 0           Salvaslip e Proteggislip  Piume Diretti  2104490  SM       26
# 1                 Gel e Cere Capelli  Piume Diretti  2104490  SM       26
# 2                 Gel e Cere Capelli  Piume Diretti  2104490  SM       26
# 3                 Gel e Cere Capelli  Piume Diretti  2104490  SM       26
# 4                 Gel e Cere Capelli  Piume Diretti  2104490  SM       26
# ...                              ...            ...      ...  ..      ...
# 2447292                  Sgrassatori            B2C  2152842  UD      999
# 2447293             Detergenti Bagno            B2C  2152842  UD      999
# 2447294          Detergenti Multiuso            B2C  2152842  UD      999
# 2447295  Detersivi Capsule Lavatrice            B2C  2152842  UD      999
# 2447296  Detersivi Liquido Lavatrice            B2C  2152843  PT      999
#
#          Giacenza Pezzi Volume [m3]  Volume evaso [m3]
# 0                          3.474766           0.007728
# 1                          0.206955           0.002268
# 2                          0.140424           0.001823
# 3                          0.419256           0.004320
# 4                          0.148149           0.002430
# ...                             ...                ...
# 2447292                    2.330022           0.003271
# 2447293                    0.943970           0.001559
# 2447294                    0.743142           0.000728
# 2447295                    0.532170           0.002025
# 2447296                    7.441434           0.021240
#
# [2447297 rows x 21 columns]

# %%
# assuming your DataFrame is called df_all (or df)
cols_to_check = ["Ecr1", "Ecr2", "Ecr3", "Ecr4"]
df = df.dropna(subset=cols_to_check, how="any").reset_index(drop=True)
df
# Out:
#          Unnamed: 0  Num. Ordine Mese-Giorno Articolo  \
# 0                 0       738378       04-18    20918
# 1                 1       738379       04-18     3456
# 2                 2       738379       04-18     7199
# 3                 3       738379       04-18    43556
# 4                 4       738379       04-18    50045
# ...             ...          ...         ...      ...
# 2298719     2447292       791134       12-29    92720
# 2298720     2447293       791134       12-29    98819
# 2298721     2447294       791134       12-29   105877
# 2298722     2447295       791134       12-29   107171
# 2298723     2447296       791140       12-30   107904
#
#                                       Descrizione  Pezzi ordinati  \
# 0         CAREFREE COTTON SALVASLIP 44 PZ.DISTESO               6
# 1        STUDIO L.5 INVISI FIX GEL FOR.LIQ.150ml                6
# 2        STUDIO L.8 FIX&FORCE GEL IPERFOR.150 ML.               6
# 3         STUDIO L.9 INDESTRUC.GEL ESTREMO 150 ML               6
# 4        STUDIO L.5 INVISI FIX GEL CR.FOR.VAS.150               6
# ...                                           ...             ...
# 2298719     CHANTECLAIR SGRASS.600 MLx2 PZ.LIMONE               1
# 2298720    VIM GEL BAGNO 5in1 ANTICALCARE 1000 ML               1
# 2298721  CIF CREMA GREEN ACTIVE 500 ML PINK BLOOM               1
# 2298722      OMINO B.DET.IDROCAPS SALVAFIBRE 20pz               1
# 2298723  ACE LAVAT.LIQ.27 LAVx3 PZ MELAeCANNELLA                2
#
#          Pezzi evasi  Pz x CT  Pz x TH  Volume pezzo  ...           Ecr1  \
# 0                  6       24        0      1.288000  ...   Cura Persona
# 1                  6        6        0      0.378000  ...   Cura Persona
# 2                  6        6        0      0.303750  ...   Cura Persona
# 3                  6        6        0      0.720000  ...   Cura Persona
# 4                  6        6        0      0.405000  ...   Cura Persona
# ...              ...      ...      ...           ...  ...            ...
# 2298719            1        6        0      3.271125  ...  Casa e Bucato
# 2298720            1       12        0      1.559250  ...  Casa e Bucato
# 2298721            1       16        0      0.728000  ...  Casa e Bucato
# 2298722            1        8        0      2.025000  ...  Casa e Bucato
# 2298723            2        1        0     10.620000  ...  Casa e Bucato
#
#                       Ecr2                   Ecr3  \
# 0        Igienico Sanitari             Assorbenti
# 1                  Capelli        Styling Capelli
# 2                  Capelli        Styling Capelli
# 3                  Capelli        Styling Capelli
# 4                  Capelli        Styling Capelli
# ...                    ...                    ...
# 2298719          Superfici   Detergenti Superfici
# 2298720              Bagno  Detergenti Bagno e WC
# 2298721          Superfici   Detergenti Superfici
# 2298722             Bucato       Detersivi Bucato
# 2298723             Bucato       Detersivi Bucato
#
#                                 Ecr4         Canale  Cliente  PV Percorso  \
# 0           Salvaslip e Proteggislip  Piume Diretti  2104490  SM       26
# 1                 Gel e Cere Capelli  Piume Diretti  2104490  SM       26
# 2                 Gel e Cere Capelli  Piume Diretti  2104490  SM       26
# 3                 Gel e Cere Capelli  Piume Diretti  2104490  SM       26
# 4                 Gel e Cere Capelli  Piume Diretti  2104490  SM       26
# ...                              ...            ...      ...  ..      ...
# 2298719                  Sgrassatori            B2C  2152842  UD      999
# 2298720             Detergenti Bagno            B2C  2152842  UD      999
# 2298721          Detergenti Multiuso            B2C  2152842  UD      999
# 2298722  Detersivi Capsule Lavatrice            B2C  2152842  UD      999
# 2298723  Detersivi Liquido Lavatrice            B2C  2152843  PT      999
#
#          Giacenza Pezzi Volume [m3]  Volume evaso [m3]
# 0                          3.474766           0.007728
# 1                          0.206955           0.002268
# 2                          0.140424           0.001823
# 3                          0.419256           0.004320
# 4                          0.148149           0.002430
# ...                             ...                ...
# 2298719                    2.330022           0.003271
# 2298720                    0.943970           0.001559
# 2298721                    0.743142           0.000728
# 2298722                    0.532170           0.002025
# 2298723                    7.441434           0.021240
#
# [2298724 rows x 21 columns]

# %%
df.drop_duplicates(subset = 'Articolo').groupby('Ecr1')['Giacenza Pezzi Volume [m3]'].sum().sum()
# Out:
# 6840.649135358257

# %% [markdown]
# # GREEDY ORDER

# %%
# 3. Execute the full pipeline

# Assume df and df_stock_vol are already loaded in the environment
R, order_ids, sku_ids = build_R(df)

# Compute SKU volumes (m3) from df_stock_vol
vol_series = df_stock_vol.set_index('ARTICOLO')['Giacenza Pezzi Volume [m3]']
median_vol = vol_series.median()
vol_series_filled = vol_series.fillna(median_vol)
sku_volumes = np.array([vol_series_filled.get(sku, median_vol) for sku in sku_ids], dtype=float)

# Define DC capacities (m3)
#capacity_A = 19800 * 0.37 #25000
#capacity_B =  12720 * 0.37 #6800

capacity_A = df.drop_duplicates(subset = 'Articolo').groupby('Ecr1')['Giacenza Pezzi Volume [m3]'].sum().sum()*0.65
capacity_B = df.drop_duplicates(subset = 'Articolo').groupby('Ecr1')['Giacenza Pezzi Volume [m3]'].sum().sum()*0.45

k_volume = np.array([capacity_A, capacity_B])

# Run heuristic with debug on
allocation, remaining_volume = greedy_seeds_volume(R, k_volume, sku_volumes, debug=True)
print("\nFinal remaining volumes (m3):", remaining_volume)

# 4. Map indices back to Articolo codes
alloc_map = []
for d, skus in enumerate(allocation):
    for s in skus:
        alloc_map.append({
            'Warehouse': f'DC_{d+1}', 
            'Articolo': sku_ids[s]
        })
df_allocation = pd.DataFrame(alloc_map)
# Out:
# Top 5 SKUs by sales: ['111' '2003' '78176' '99379' '44777']
# DCs sorted by capacity: [0 1]
# Seed DC_1 with SKU 111
# Seed DC_2 with SKU 101309 (least coappears)
#
# Assigning remaining SKUs by average coappearance
# SKU 2003 -> DC_1 (avg coappear 1141.0)
# SKU 78176 -> DC_1 (avg coappear 760.0)
# SKU 99379 -> DC_1 (avg coappear 797.3)
# SKU 44777 -> DC_1 (avg coappear 580.2)
# SKU 99827 -> DC_1 (avg coappear 498.2)
# SKU 1624 -> DC_1 (avg coappear 495.5)
# SKU 103548 -> DC_1 (avg coappear 520.1)
# SKU 101261 -> DC_1 (avg coappear 419.9)
# SKU 112 -> DC_1 (avg coappear 552.6)
# SKU 6392 -> DC_1 (avg coappear 535.7)
# SKU 99452 -> DC_1 (avg coappear 413.2)
# SKU 1090 -> DC_1 (avg coappear 421.7)
# SKU 101260 -> DC_1 (avg coappear 414.8)
# SKU 7656 -> DC_1 (avg coappear 418.7)
# SKU 99384 -> DC_1 (avg coappear 315.7)
# SKU 41942 -> DC_1 (avg coappear 348.1)
# SKU 58575 -> DC_1 (avg coappear 445.8)
# SKU 7466 -> DC_1 (avg coappear 379.9)
# SKU 72030 -> DC_1 (avg coappear 301.9)
# SKU 21714 -> DC_1 (avg coappear 360.8)
# SKU 47251 -> DC_1 (avg coappear 240.0)
# SKU 83429 -> DC_1 (avg coappear 202.0)
# SKU 40704 -> DC_1 (avg coappear 289.3)
# SKU 102462 -> DC_1 (avg coappear 323.8)
# SKU 16305 -> DC_1 (avg coappear 303.5)
# SKU 204 -> DC_1 (avg coappear 308.5)
# SKU 100849 -> DC_1 (avg coappear 259.1)
# SKU 94320 -> DC_1 (avg coappear 312.6)
# SKU 79944 -> DC_1 (avg coappear 295.2)
# SKU 71149 -> DC_1 (avg coappear 288.5)
# SKU 11690 -> DC_1 (avg coappear 298.0)
# SKU 692 -> DC_1 (avg coappear 277.1)
# SKU 91128 -> DC_1 (avg coappear 244.5)
# SKU 2125 -> DC_1 (avg coappear 246.4)
# SKU 103549 -> DC_1 (avg coappear 291.4)
# SKU 53128 -> DC_1 (avg coappear 239.9)
# SKU 97874 -> DC_1 (avg coappear 200.1)
# SKU 94678 -> DC_1 (avg coappear 229.3)
# SKU 41323 -> DC_1 (avg coappear 214.4)
# SKU 85372 -> DC_1 (avg coappear 220.7)
# SKU 49850 -> DC_1 (avg coappear 227.3)
# SKU 100850 -> DC_1 (avg coappear 213.5)
# SKU 96873 -> DC_1 (avg coappear 221.6)
# SKU 96475 -> DC_1 (avg coappear 217.5)
# SKU 4937 -> DC_1 (avg coappear 272.4)
# SKU 99380 -> DC_1 (avg coappear 246.6)
# SKU 608 -> DC_1 (avg coappear 233.4)
# SKU 88468 -> DC_1 (avg coappear 235.3)
# SKU 78186 -> DC_1 (avg coappear 167.8)
# SKU 2061 -> DC_1 (avg coappear 204.5)
# SKU 2137 -> DC_1 (avg coappear 153.9)
# SKU 99385 -> DC_1 (avg coappear 195.8)
# SKU 71623 -> DC_1 (avg coappear 146.0)
# SKU 96868 -> DC_1 (avg coappear 221.9)
# SKU 33098 -> DC_1 (avg coappear 182.8)
# SKU 4981 -> DC_1 (avg coappear 142.7)
# SKU 4936 -> DC_1 (avg coappear 227.1)
# SKU 102470 -> DC_1 (avg coappear 212.8)
# SKU 39911 -> DC_1 (avg coappear 229.3)
# SKU 70647 -> DC_1 (avg coappear 192.2)
# SKU 13974 -> DC_1 (avg coappear 222.4)
# SKU 94733 -> DC_1 (avg coappear 175.5)
# SKU 5633 -> DC_1 (avg coappear 170.7)
# SKU 93835 -> DC_1 (avg coappear 159.9)
# SKU 99381 -> DC_1 (avg coappear 178.2)
# SKU 15118 -> DC_1 (avg coappear 178.9)
# SKU 75260 -> DC_1 (avg coappear 147.3)
# SKU 41321 -> DC_1 (avg coappear 162.0)
# SKU 88941 -> DC_1 (avg coappear 157.0)
# SKU 8428 -> DC_1 (avg coappear 183.6)
# SKU 93615 -> DC_1 (avg coappear 139.7)
# SKU 94730 -> DC_1 (avg coappear 133.1)
# SKU 8729 -> DC_1 (avg coappear 172.9)
# SKU 96863 -> DC_1 (avg coappear 169.2)
# SKU 96806 -> DC_1 (avg coappear 127.4)
# SKU 33183 -> DC_1 (avg coappear 168.5)
# SKU 50704 -> DC_1 (avg coappear 190.6)
# SKU 39954 -> DC_1 (avg coappear 121.2)
# SKU 22188 -> DC_1 (avg coappear 163.5)
# SKU 5675 -> DC_1 (avg coappear 160.7)
# SKU 6032 -> DC_1 (avg coappear 131.4)
# SKU 49463 -> DC_1 (avg coappear 138.7)
# SKU 3463 -> DC_1 (avg coappear 141.4)
# SKU 97978 -> DC_1 (avg coappear 146.4)
# SKU 97862 -> DC_1 (avg coappear 117.8)
# SKU 99386 -> DC_1 (avg coappear 131.4)
# SKU 49851 -> DC_1 (avg coappear 156.5)
# SKU 34439 -> DC_1 (avg coappear 121.0)
# SKU 79252 -> DC_1 (avg coappear 167.6)
# SKU 100851 -> DC_1 (avg coappear 156.7)
# SKU 93842 -> DC_1 (avg coappear 124.8)
# SKU 68885 -> DC_1 (avg coappear 156.8)
# SKU 96877 -> DC_1 (avg coappear 134.5)
# SKU 95782 -> DC_1 (avg coappear 128.0)
# SKU 94175 -> DC_1 (avg coappear 154.6)
# SKU 9057 -> DC_1 (avg coappear 169.4)
# SKU 94514 -> DC_1 (avg coappear 166.9)
# SKU 86003 -> DC_1 (avg coappear 88.7)
# SKU 87452 -> DC_1 (avg coappear 97.1)
# SKU 88938 -> DC_1 (avg coappear 170.3)
# SKU 334 -> DC_1 (avg coappear 168.4)
# SKU 91129 -> DC_1 (avg coappear 146.0)
# SKU 102467 -> DC_1 (avg coappear 143.5)
# SKU 76204 -> DC_1 (avg coappear 150.2)
# SKU 60867 -> DC_1 (avg coappear 121.4)
# SKU 80368 -> DC_1 (avg coappear 173.4)
# SKU 5238 -> DC_1 (avg coappear 116.6)
# SKU 3549 -> DC_1 (avg coappear 132.3)
# SKU 101121 -> DC_1 (avg coappear 114.4)
# SKU 94731 -> DC_1 (avg coappear 118.2)
# SKU 5667 -> DC_1 (avg coappear 104.8)
# SKU 72466 -> DC_1 (avg coappear 130.9)
# SKU 97263 -> DC_1 (avg coappear 121.0)
# SKU 81512 -> DC_1 (avg coappear 123.0)
# SKU 1123 -> DC_1 (avg coappear 105.3)
# SKU 56157 -> DC_1 (avg coappear 108.8)
# SKU 96772 -> DC_1 (avg coappear 124.4)
# SKU 32448 -> DC_1 (avg coappear 91.1)
# SKU 98902 -> DC_1 (avg coappear 131.7)
# SKU 61037 -> DC_1 (avg coappear 142.6)
# SKU 4419 -> DC_1 (avg coappear 108.3)
# SKU 53842 -> DC_1 (avg coappear 141.8)
# SKU 42491 -> DC_1 (avg coappear 122.2)
# SKU 94666 -> DC_1 (avg coappear 118.6)
# SKU 41322 -> DC_1 (avg coappear 126.4)
# SKU 93824 -> DC_1 (avg coappear 94.2)
# SKU 65589 -> DC_1 (avg coappear 116.0)
# SKU 42521 -> DC_1 (avg coappear 119.2)
# SKU 102436 -> DC_1 (avg coappear 118.9)
# SKU 73455 -> DC_1 (avg coappear 120.4)
# SKU 2702 -> DC_1 (avg coappear 118.5)
# SKU 963 -> DC_1 (avg coappear 81.9)
# SKU 21890 -> DC_1 (avg coappear 113.3)
# SKU 49852 -> DC_1 (avg coappear 130.6)
# SKU 94877 -> DC_1 (avg coappear 112.6)
# SKU 88932 -> DC_1 (avg coappear 133.3)
# SKU 11597 -> DC_1 (avg coappear 109.1)
# SKU 3618 -> DC_1 (avg coappear 119.7)
# SKU 39158 -> DC_1 (avg coappear 115.2)
# SKU 99378 -> DC_1 (avg coappear 127.1)
# SKU 70835 -> DC_1 (avg coappear 122.3)
# SKU 97875 -> DC_1 (avg coappear 110.7)
# SKU 99453 -> DC_1 (avg coappear 124.6)
# SKU 38358 -> DC_1 (avg coappear 108.2)
# SKU 47028 -> DC_1 (avg coappear 78.7)
# SKU 100816 -> DC_1 (avg coappear 99.4)
# SKU 8402 -> DC_1 (avg coappear 125.5)
# SKU 96878 -> DC_1 (avg coappear 106.8)
# SKU 99382 -> DC_1 (avg coappear 114.3)
# SKU 102694 -> DC_1 (avg coappear 117.1)
# SKU 84522 -> DC_1 (avg coappear 88.4)
# SKU 94748 -> DC_1 (avg coappear 75.9)
# SKU 93393 -> DC_1 (avg coappear 104.2)
# SKU 79250 -> DC_1 (avg coappear 120.4)
# SKU 76457 -> DC_1 (avg coappear 119.5)
# SKU 99824 -> DC_1 (avg coappear 105.9)
# SKU 2062 -> DC_1 (avg coappear 100.6)
# SKU 93843 -> DC_1 (avg coappear 98.3)
# SKU 88935 -> DC_1 (avg coappear 125.7)
# SKU 42494 -> DC_1 (avg coappear 116.1)
# SKU 97264 -> DC_1 (avg coappear 102.0)
# SKU 639 -> DC_1 (avg coappear 93.2)
# SKU 8909 -> DC_1 (avg coappear 115.4)
# SKU 86449 -> DC_1 (avg coappear 126.9)
# SKU 102923 -> DC_1 (avg coappear 119.2)
# SKU 21 -> DC_1 (avg coappear 107.3)
# SKU 86423 -> DC_1 (avg coappear 119.9)
# SKU 42496 -> DC_1 (avg coappear 114.2)
# SKU 102924 -> DC_1 (avg coappear 127.6)
# SKU 96923 -> DC_1 (avg coappear 115.7)
# SKU 20918 -> DC_1 (avg coappear 94.7)
# SKU 96809 -> DC_1 (avg coappear 92.8)
# SKU 42523 -> DC_1 (avg coappear 112.3)
# SKU 51589 -> DC_1 (avg coappear 107.9)
# SKU 53781 -> DC_1 (avg coappear 92.5)
# SKU 90388 -> DC_1 (avg coappear 129.9)
# SKU 1255 -> DC_1 (avg coappear 112.9)
# SKU 52608 -> DC_1 (avg coappear 39.1)
# SKU 78454 -> DC_1 (avg coappear 73.1)
# SKU 6395 -> DC_1 (avg coappear 96.0)
# SKU 89005 -> DC_1 (avg coappear 88.4)
# SKU 96678 -> DC_1 (avg coappear 86.1)
# SKU 928 -> DC_1 (avg coappear 85.1)
# SKU 80367 -> DC_1 (avg coappear 118.9)
# SKU 2032 -> DC_1 (avg coappear 77.7)
# SKU 32175 -> DC_1 (avg coappear 105.8)
# SKU 13614 -> DC_1 (avg coappear 83.0)
# SKU 80364 -> DC_1 (avg coappear 113.4)
# SKU 98905 -> DC_1 (avg coappear 101.5)
# SKU 61192 -> DC_1 (avg coappear 105.3)
# SKU 22722 -> DC_1 (avg coappear 106.6)
# SKU 47554 -> DC_1 (avg coappear 96.5)
# SKU 99224 -> DC_1 (avg coappear 107.4)
# SKU 101702 -> DC_1 (avg coappear 109.1)
# SKU 96929 -> DC_1 (avg coappear 94.5)
# SKU 57960 -> DC_1 (avg coappear 71.3)
# SKU 89406 -> DC_1 (avg coappear 67.7)
# SKU 69308 -> DC_1 (avg coappear 79.1)
# SKU 35088 -> DC_1 (avg coappear 74.5)
# SKU 6389 -> DC_1 (avg coappear 88.7)
# SKU 4627 -> DC_1 (avg coappear 85.8)
# SKU 55255 -> DC_1 (avg coappear 90.8)
# SKU 87068 -> DC_1 (avg coappear 70.2)
# SKU 43416 -> DC_1 (avg coappear 71.5)
# SKU 38798 -> DC_1 (avg coappear 94.7)
# SKU 35249 -> DC_1 (avg coappear 85.5)
# SKU 73449 -> DC_1 (avg coappear 86.8)
# SKU 87838 -> DC_1 (avg coappear 85.6)
# SKU 5582 -> DC_1 (avg coappear 81.1)
# SKU 97820 -> DC_1 (avg coappear 77.6)
# SKU 1436 -> DC_1 (avg coappear 82.4)
# SKU 92698 -> DC_1 (avg coappear 69.4)
# SKU 70545 -> DC_1 (avg coappear 81.6)
# SKU 103546 -> DC_1 (avg coappear 92.0)
# SKU 100658 -> DC_1 (avg coappear 90.0)
# SKU 27924 -> DC_1 (avg coappear 100.5)
# SKU 86210 -> DC_1 (avg coappear 101.0)
# SKU 4488 -> DC_1 (avg coappear 92.0)
# SKU 103545 -> DC_1 (avg coappear 94.6)
# SKU 47204 -> DC_1 (avg coappear 107.8)
# SKU 97759 -> DC_1 (avg coappear 82.8)
# SKU 29359 -> DC_1 (avg coappear 93.1)
# SKU 56592 -> DC_1 (avg coappear 68.0)
# SKU 55513 -> DC_1 (avg coappear 98.3)
# SKU 98906 -> DC_1 (avg coappear 91.6)
# SKU 102464 -> DC_1 (avg coappear 94.9)
# SKU 99065 -> DC_1 (avg coappear 87.3)
# SKU 96680 -> DC_1 (avg coappear 80.5)
# SKU 1659 -> DC_1 (avg coappear 64.1)
# SKU 27138 -> DC_1 (avg coappear 98.4)
# SKU 96875 -> DC_1 (avg coappear 85.3)
# SKU 48561 -> DC_1 (avg coappear 67.9)
# SKU 93392 -> DC_1 (avg coappear 84.0)
# SKU 88442 -> DC_1 (avg coappear 78.8)
# SKU 69301 -> DC_1 (avg coappear 75.8)
# SKU 96574 -> DC_1 (avg coappear 85.8)
# SKU 71624 -> DC_1 (avg coappear 77.2)
# SKU 1577 -> DC_1 (avg coappear 89.9)
# SKU 40 -> DC_1 (avg coappear 77.0)
# SKU 75259 -> DC_1 (avg coappear 73.5)
# SKU 62202 -> DC_1 (avg coappear 100.0)
# SKU 88003 -> DC_1 (avg coappear 60.3)
# SKU 26709 -> DC_1 (avg coappear 85.8)
# SKU 101700 -> DC_1 (avg coappear 89.1)
# SKU 71420 -> DC_1 (avg coappear 88.1)
# SKU 71688 -> DC_1 (avg coappear 87.2)
# SKU 96830 -> DC_1 (avg coappear 82.1)
# SKU 2057 -> DC_1 (avg coappear 76.0)
# SKU 661 -> DC_1 (avg coappear 82.9)
# SKU 87424 -> DC_1 (avg coappear 73.8)
# SKU 16306 -> DC_1 (avg coappear 80.1)
# SKU 56594 -> DC_1 (avg coappear 67.1)
# SKU 80787 -> DC_1 (avg coappear 76.3)
# SKU 96869 -> DC_1 (avg coappear 89.1)
# SKU 96872 -> DC_1 (avg coappear 91.1)
# SKU 546 -> DC_1 (avg coappear 68.5)
# SKU 6333 -> DC_1 (avg coappear 70.1)
# SKU 20996 -> DC_1 (avg coappear 76.2)
# SKU 75893 -> DC_1 (avg coappear 74.1)
# SKU 61492 -> DC_1 (avg coappear 78.4)
# SKU 93849 -> DC_1 (avg coappear 71.8)
# SKU 103540 -> DC_1 (avg coappear 76.4)
# SKU 80786 -> DC_1 (avg coappear 75.9)
# SKU 103946 -> DC_1 (avg coappear 82.9)
# SKU 102474 -> DC_1 (avg coappear 97.1)
# SKU 101431 -> DC_1 (avg coappear 81.1)
# SKU 71419 -> DC_1 (avg coappear 78.1)
# SKU 86984 -> DC_1 (avg coappear 70.2)
# SKU 60871 -> DC_1 (avg coappear 63.1)
# SKU 96365 -> DC_1 (avg coappear 92.2)
# SKU 97889 -> DC_1 (avg coappear 58.7)
# SKU 100171 -> DC_1 (avg coappear 71.8)
# SKU 42524 -> DC_1 (avg coappear 85.1)
# SKU 97821 -> DC_1 (avg coappear 66.6)
# SKU 89118 -> DC_1 (avg coappear 64.5)
# SKU 102682 -> DC_1 (avg coappear 79.4)
# SKU 45970 -> DC_1 (avg coappear 54.2)
# SKU 81522 -> DC_1 (avg coappear 96.5)
# SKU 94735 -> DC_1 (avg coappear 64.7)
# SKU 99561 -> DC_1 (avg coappear 87.7)
# SKU 99178 -> DC_1 (avg coappear 77.9)
# SKU 34438 -> DC_1 (avg coappear 77.6)
# SKU 91489 -> DC_1 (avg coappear 39.2)
# SKU 102461 -> DC_1 (avg coappear 79.8)
# SKU 88221 -> DC_1 (avg coappear 80.0)
# SKU 49232 -> DC_1 (avg coappear 85.0)
# SKU 91492 -> DC_1 (avg coappear 40.5)
# SKU 94404 -> DC_1 (avg coappear 67.3)
# SKU 51361 -> DC_1 (avg coappear 67.4)
# SKU 95840 -> DC_1 (avg coappear 85.2)
# SKU 103907 -> DC_1 (avg coappear 49.0)
# SKU 98816 -> DC_1 (avg coappear 61.5)
# SKU 95628 -> DC_1 (avg coappear 66.7)
# SKU 4668 -> DC_1 (avg coappear 80.8)
# SKU 5666 -> DC_1 (avg coappear 75.0)
# SKU 99562 -> DC_1 (avg coappear 88.4)
# SKU 43165 -> DC_1 (avg coappear 82.0)
# SKU 55500 -> DC_1 (avg coappear 60.3)
# SKU 99454 -> DC_1 (avg coappear 79.1)
# SKU 83072 -> DC_1 (avg coappear 75.8)
# SKU 99383 -> DC_1 (avg coappear 79.1)
# SKU 5525 -> DC_1 (avg coappear 69.6)
# SKU 103547 -> DC_1 (avg coappear 77.3)
# SKU 102437 -> DC_1 (avg coappear 69.2)
# SKU 55623 -> DC_1 (avg coappear 87.9)
# SKU 52642 -> DC_1 (avg coappear 77.2)
# SKU 99670 -> DC_1 (avg coappear 63.7)
# SKU 7363 -> DC_1 (avg coappear 72.4)
# SKU 38213 -> DC_1 (avg coappear 58.8)
# SKU 1089 -> DC_1 (avg coappear 71.9)
# SKU 7224 -> DC_1 (avg coappear 59.4)
# SKU 56155 -> DC_1 (avg coappear 49.5)
# SKU 41067 -> DC_1 (avg coappear 64.2)
# SKU 68648 -> DC_1 (avg coappear 51.6)
# SKU 31926 -> DC_1 (avg coappear 72.3)
# SKU 3426 -> DC_1 (avg coappear 45.9)
# SKU 76949 -> DC_1 (avg coappear 65.1)
# SKU 42527 -> DC_1 (avg coappear 70.9)
# SKU 43166 -> DC_1 (avg coappear 80.2)
# SKU 351 -> DC_1 (avg coappear 71.8)
# SKU 24552 -> DC_1 (avg coappear 76.5)
# SKU 102686 -> DC_1 (avg coappear 74.1)
# SKU 904 -> DC_1 (avg coappear 60.2)
# SKU 2060 -> DC_1 (avg coappear 64.2)
# SKU 3421 -> DC_1 (avg coappear 46.4)
# SKU 97899 -> DC_1 (avg coappear 67.1)
# SKU 96893 -> DC_1 (avg coappear 61.6)
# SKU 6146 -> DC_1 (avg coappear 58.8)
# SKU 26946 -> DC_1 (avg coappear 54.0)
# SKU 102764 -> DC_1 (avg coappear 56.3)
# SKU 101701 -> DC_1 (avg coappear 80.9)
# SKU 56593 -> DC_1 (avg coappear 53.1)
# SKU 83066 -> DC_1 (avg coappear 72.3)
# SKU 96898 -> DC_1 (avg coappear 62.7)
# SKU 671 -> DC_1 (avg coappear 67.0)
# SKU 71286 -> DC_1 (avg coappear 61.2)
# SKU 74965 -> DC_1 (avg coappear 46.1)
# SKU 87835 -> DC_1 (avg coappear 58.5)
# SKU 60868 -> DC_1 (avg coappear 59.0)
# SKU 20381 -> DC_1 (avg coappear 62.9)
# SKU 96805 -> DC_1 (avg coappear 49.5)
# SKU 39159 -> DC_1 (avg coappear 77.6)
# SKU 83792 -> DC_1 (avg coappear 40.6)
# SKU 39878 -> DC_1 (avg coappear 73.8)
# SKU 94224 -> DC_1 (avg coappear 69.5)
# SKU 81510 -> DC_1 (avg coappear 67.2)
# SKU 101699 -> DC_1 (avg coappear 67.9)
# SKU 94172 -> DC_1 (avg coappear 64.4)
# SKU 81511 -> DC_1 (avg coappear 67.4)
# SKU 78188 -> DC_1 (avg coappear 53.3)
# SKU 55702 -> DC_1 (avg coappear 54.9)
# SKU 100892 -> DC_1 (avg coappear 64.7)
# SKU 101737 -> DC_1 (avg coappear 61.0)
# SKU 104357 -> DC_1 (avg coappear 48.5)
# SKU 97568 -> DC_1 (avg coappear 70.4)
# SKU 89409 -> DC_1 (avg coappear 60.0)
# SKU 3755 -> DC_1 (avg coappear 55.6)
# SKU 72705 -> DC_1 (avg coappear 71.1)
# SKU 102465 -> DC_1 (avg coappear 63.6)
# SKU 96917 -> DC_1 (avg coappear 67.3)
# SKU 55515 -> DC_1 (avg coappear 72.6)
# SKU 50657 -> DC_1 (avg coappear 54.9)
# SKU 27908 -> DC_1 (avg coappear 51.9)
# SKU 60589 -> DC_1 (avg coappear 58.8)
# SKU 57540 -> DC_1 (avg coappear 51.3)
# SKU 1030 -> DC_1 (avg coappear 52.5)
# SKU 65333 -> DC_1 (avg coappear 74.4)
# SKU 55499 -> DC_1 (avg coappear 60.5)
# SKU 23638 -> DC_1 (avg coappear 53.7)
# SKU 47375 -> DC_1 (avg coappear 48.6)
# SKU 46145 -> DC_1 (avg coappear 65.4)
# SKU 99456 -> DC_1 (avg coappear 50.7)
# SKU 104180 -> DC_2 (avg coappear 112.0)
# SKU 32191 -> DC_1 (avg coappear 64.0)
# SKU 56659 -> DC_1 (avg coappear 56.6)
# SKU 87090 -> DC_1 (avg coappear 60.3)
# SKU 61303 -> DC_1 (avg coappear 77.2)
# SKU 103544 -> DC_1 (avg coappear 69.7)
# SKU 22553 -> DC_1 (avg coappear 50.3)
# SKU 5409 -> DC_1 (avg coappear 60.9)
# SKU 83027 -> DC_1 (avg coappear 60.7)
# SKU 55633 -> DC_1 (avg coappear 72.9)
# SKU 96774 -> DC_1 (avg coappear 67.2)
# SKU 84513 -> DC_1 (avg coappear 61.2)
# SKU 94728 -> DC_1 (avg coappear 51.7)
# SKU 54561 -> DC_1 (avg coappear 63.9)
# SKU 97834 -> DC_1 (avg coappear 51.0)
# SKU 5705 -> DC_1 (avg coappear 58.7)
# SKU 96880 -> DC_1 (avg coappear 60.5)
# SKU 65300 -> DC_1 (avg coappear 54.3)
# SKU 49398 -> DC_1 (avg coappear 62.2)
# SKU 42522 -> DC_1 (avg coappear 61.7)
# SKU 101256 -> DC_1 (avg coappear 44.9)
# SKU 79143 -> DC_1 (avg coappear 47.9)
# SKU 1195 -> DC_1 (avg coappear 60.2)
# SKU 93834 -> DC_1 (avg coappear 52.7)
# SKU 7036 -> DC_1 (avg coappear 62.6)
# SKU 93816 -> DC_1 (avg coappear 53.2)
# SKU 61040 -> DC_1 (avg coappear 62.0)
# SKU 7398 -> DC_1 (avg coappear 48.7)
# SKU 1804 -> DC_1 (avg coappear 70.3)
# SKU 87998 -> DC_1 (avg coappear 50.3)
# SKU 88004 -> DC_1 (avg coappear 46.1)
# SKU 10023 -> DC_1 (avg coappear 53.0)
# SKU 83073 -> DC_1 (avg coappear 66.5)
# SKU 58224 -> DC_1 (avg coappear 49.4)
# SKU 102468 -> DC_1 (avg coappear 61.0)
# SKU 96874 -> DC_1 (avg coappear 64.2)
# SKU 88224 -> DC_1 (avg coappear 57.7)
# SKU 96871 -> DC_1 (avg coappear 63.1)
# SKU 46149 -> DC_1 (avg coappear 65.7)
# SKU 43556 -> DC_1 (avg coappear 67.8)
# SKU 26668 -> DC_1 (avg coappear 46.8)
# SKU 93839 -> DC_1 (avg coappear 48.3)
# SKU 103209 -> DC_1 (avg coappear 55.6)
# SKU 882 -> DC_1 (avg coappear 51.9)
# SKU 41319 -> DC_1 (avg coappear 54.4)
# SKU 48118 -> DC_1 (avg coappear 65.9)
# SKU 81024 -> DC_1 (avg coappear 54.8)
# SKU 69306 -> DC_1 (avg coappear 47.9)
# SKU 59900 -> DC_1 (avg coappear 54.9)
# SKU 19697 -> DC_1 (avg coappear 53.4)
# SKU 94829 -> DC_1 (avg coappear 35.8)
# SKU 97068 -> DC_1 (avg coappear 51.7)
# SKU 10633 -> DC_1 (avg coappear 54.6)
# SKU 96773 -> DC_1 (avg coappear 65.8)
# SKU 93362 -> DC_1 (avg coappear 47.4)
# SKU 53428 -> DC_1 (avg coappear 58.6)
# SKU 84511 -> DC_1 (avg coappear 56.3)
# SKU 76034 -> DC_1 (avg coappear 53.3)
# SKU 84887 -> DC_1 (avg coappear 55.2)
# SKU 96922 -> DC_1 (avg coappear 62.0)
# SKU 42463 -> DC_1 (avg coappear 65.0)
# SKU 105228 -> DC_1 (avg coappear 51.2)
# SKU 96897 -> DC_1 (avg coappear 51.9)
# SKU 55514 -> DC_1 (avg coappear 66.8)
# SKU 94871 -> DC_1 (avg coappear 52.0)
# SKU 83095 -> DC_1 (avg coappear 57.3)
# SKU 60890 -> DC_1 (avg coappear 47.7)
# SKU 64321 -> DC_1 (avg coappear 45.8)
# SKU 38916 -> DC_1 (avg coappear 65.2)
# SKU 4830 -> DC_1 (avg coappear 54.6)
# SKU 79141 -> DC_1 (avg coappear 46.3)
# SKU 86627 -> DC_1 (avg coappear 57.0)
# SKU 31927 -> DC_1 (avg coappear 46.5)
# SKU 35508 -> DC_1 (avg coappear 56.7)
# SKU 78222 -> DC_1 (avg coappear 62.0)
# SKU 55632 -> DC_1 (avg coappear 66.8)
# SKU 102683 -> DC_1 (avg coappear 58.7)
# SKU 50815 -> DC_1 (avg coappear 48.2)
# SKU 100852 -> DC_1 (avg coappear 53.6)
# SKU 44962 -> DC_1 (avg coappear 38.6)
# SKU 89410 -> DC_1 (avg coappear 44.6)
# SKU 42464 -> DC_1 (avg coappear 58.7)
# SKU 72461 -> DC_1 (avg coappear 48.4)
# SKU 19278 -> DC_1 (avg coappear 51.8)
# SKU 93828 -> DC_1 (avg coappear 52.0)
# SKU 99223 -> DC_1 (avg coappear 59.4)
# SKU 59976 -> DC_1 (avg coappear 37.0)
# SKU 7945 -> DC_1 (avg coappear 63.8)
# SKU 97266 -> DC_1 (avg coappear 52.5)
# SKU 96895 -> DC_1 (avg coappear 48.6)
# SKU 59758 -> DC_1 (avg coappear 61.9)
# SKU 53546 -> DC_1 (avg coappear 52.2)
# SKU 103948 -> DC_1 (avg coappear 57.3)
# SKU 93819 -> DC_1 (avg coappear 55.2)
# SKU 68531 -> DC_1 (avg coappear 52.9)
# SKU 94793 -> DC_1 (avg coappear 58.4)
# SKU 84567 -> DC_1 (avg coappear 49.4)
# SKU 61023 -> DC_1 (avg coappear 58.0)
# SKU 95635 -> DC_1 (avg coappear 55.9)
# SKU 42468 -> DC_1 (avg coappear 57.6)
# SKU 55630 -> DC_1 (avg coappear 63.1)
# SKU 54419 -> DC_1 (avg coappear 50.9)
# SKU 857 -> DC_1 (avg coappear 50.5)
# SKU 96140 -> DC_1 (avg coappear 53.7)
# SKU 6864 -> DC_1 (avg coappear 54.7)
# SKU 71479 -> DC_1 (avg coappear 38.9)
# SKU 71346 -> DC_1 (avg coappear 46.1)
# SKU 95697 -> DC_1 (avg coappear 36.6)
# SKU 87822 -> DC_1 (avg coappear 55.6)
# SKU 79142 -> DC_1 (avg coappear 43.9)
# SKU 88679 -> DC_1 (avg coappear 45.0)
# SKU 88803 -> DC_1 (avg coappear 42.5)
# SKU 96883 -> DC_1 (avg coappear 54.3)
# SKU 83069 -> DC_1 (avg coappear 56.5)
# SKU 98908 -> DC_1 (avg coappear 53.2)
# SKU 97265 -> DC_1 (avg coappear 59.5)
# SKU 72460 -> DC_1 (avg coappear 47.1)
# SKU 46373 -> DC_1 (avg coappear 39.5)
# SKU 99563 -> DC_1 (avg coappear 42.1)
# SKU 99459 -> DC_1 (avg coappear 52.0)
# SKU 27168 -> DC_1 (avg coappear 49.4)
# SKU 77700 -> DC_1 (avg coappear 58.4)
# SKU 93810 -> DC_1 (avg coappear 53.7)
# SKU 91487 -> DC_1 (avg coappear 29.0)
# SKU 7608 -> DC_1 (avg coappear 47.9)
# SKU 30353 -> DC_1 (avg coappear 51.8)
# SKU 4400 -> DC_1 (avg coappear 45.2)
# SKU 84893 -> DC_1 (avg coappear 47.9)
# SKU 38471 -> DC_1 (avg coappear 42.7)
# SKU 62928 -> DC_1 (avg coappear 43.2)
# SKU 56916 -> DC_1 (avg coappear 41.0)
# SKU 1495 -> DC_1 (avg coappear 48.3)
# SKU 93280 -> DC_1 (avg coappear 48.9)
# SKU 104278 -> DC_1 (avg coappear 32.9)
# SKU 5250 -> DC_1 (avg coappear 44.8)
# SKU 100671 -> DC_1 (avg coappear 50.2)
# SKU 65335 -> DC_1 (avg coappear 56.4)
# SKU 94192 -> DC_1 (avg coappear 48.9)
# SKU 15700 -> DC_1 (avg coappear 51.5)
# SKU 100773 -> DC_1 (avg coappear 40.6)
# SKU 96500 -> DC_1 (avg coappear 43.7)
# SKU 97754 -> DC_1 (avg coappear 45.9)
# SKU 96876 -> DC_1 (avg coappear 48.4)
# SKU 75193 -> DC_1 (avg coappear 44.9)
# SKU 27054 -> DC_1 (avg coappear 37.1)
# SKU 97863 -> DC_1 (avg coappear 49.7)
# SKU 93595 -> DC_1 (avg coappear 51.3)
# SKU 15683 -> DC_1 (avg coappear 53.2)
# SKU 72495 -> DC_1 (avg coappear 50.2)
# SKU 11595 -> DC_1 (avg coappear 38.7)
# SKU 39941 -> DC_1 (avg coappear 53.4)
# SKU 68651 -> DC_1 (avg coappear 36.4)
# SKU 102991 -> DC_1 (avg coappear 41.1)
# SKU 21661 -> DC_1 (avg coappear 28.2)
# SKU 3409 -> DC_1 (avg coappear 50.7)
# SKU 99825 -> DC_1 (avg coappear 50.4)
# SKU 93952 -> DC_1 (avg coappear 43.5)
# SKU 43263 -> DC_1 (avg coappear 47.6)
# SKU 93827 -> DC_1 (avg coappear 45.7)
# SKU 102685 -> DC_1 (avg coappear 56.1)
# SKU 100664 -> DC_1 (avg coappear 46.4)
# SKU 32449 -> DC_1 (avg coappear 43.5)
# SKU 1306 -> DC_1 (avg coappear 36.7)
# SKU 41320 -> DC_1 (avg coappear 39.9)
# SKU 86983 -> DC_1 (avg coappear 39.1)
# SKU 35606 -> DC_1 (avg coappear 46.8)
# SKU 103750 -> DC_1 (avg coappear 46.7)
# SKU 81026 -> DC_1 (avg coappear 48.2)
# SKU 95783 -> DC_1 (avg coappear 33.9)
# SKU 88220 -> DC_1 (avg coappear 51.6)
# SKU 79784 -> DC_1 (avg coappear 53.2)
# SKU 9865 -> DC_1 (avg coappear 41.9)
# SKU 79251 -> DC_1 (avg coappear 42.0)
# SKU 103013 -> DC_1 (avg coappear 43.8)
# SKU 47998 -> DC_1 (avg coappear 42.2)
# SKU 93651 -> DC_1 (avg coappear 46.7)
# SKU 31271 -> DC_1 (avg coappear 56.8)
# SKU 84002 -> DC_1 (avg coappear 50.7)
# SKU 70141 -> DC_1 (avg coappear 44.6)
# SKU 60665 -> DC_1 (avg coappear 46.5)
# SKU 73448 -> DC_1 (avg coappear 51.5)
# SKU 512 -> DC_1 (avg coappear 44.0)
# SKU 35498 -> DC_1 (avg coappear 56.7)
# SKU 73456 -> DC_1 (avg coappear 43.4)
# SKU 6619 -> DC_1 (avg coappear 42.2)
# SKU 65301 -> DC_1 (avg coappear 44.5)
# SKU 100668 -> DC_1 (avg coappear 45.1)
# SKU 90455 -> DC_1 (avg coappear 50.6)
# SKU 42492 -> DC_1 (avg coappear 49.1)
# SKU 97818 -> DC_1 (avg coappear 38.0)
# SKU 11800 -> DC_1 (avg coappear 45.4)
# SKU 90010 -> DC_1 (avg coappear 51.7)
# SKU 97878 -> DC_1 (avg coappear 47.8)
# SKU 75414 -> DC_1 (avg coappear 38.6)
# SKU 42530 -> DC_1 (avg coappear 50.2)
# SKU 87836 -> DC_1 (avg coappear 41.1)
# SKU 37604 -> DC_1 (avg coappear 47.1)
# SKU 86232 -> DC_1 (avg coappear 51.1)
# SKU 53547 -> DC_1 (avg coappear 46.8)
# SKU 58236 -> DC_1 (avg coappear 37.3)
# SKU 7577 -> DC_1 (avg coappear 54.6)
# SKU 32694 -> DC_1 (avg coappear 40.0)
# SKU 39438 -> DC_1 (avg coappear 34.3)
# SKU 79144 -> DC_1 (avg coappear 35.9)
# SKU 103881 -> DC_1 (avg coappear 42.5)
# SKU 75262 -> DC_1 (avg coappear 50.9)
# SKU 1498 -> DC_1 (avg coappear 44.8)
# SKU 97897 -> DC_1 (avg coappear 41.9)
# SKU 101940 -> DC_1 (avg coappear 33.1)
# SKU 8872 -> DC_1 (avg coappear 44.5)
# SKU 87996 -> DC_1 (avg coappear 37.8)
# SKU 76 -> DC_1 (avg coappear 41.8)
# SKU 100667 -> DC_1 (avg coappear 43.0)
# SKU 1488 -> DC_1 (avg coappear 36.0)
# SKU 87495 -> DC_1 (avg coappear 31.5)
# SKU 99088 -> DC_1 (avg coappear 37.5)
# SKU 492 -> DC_1 (avg coappear 51.5)
# SKU 51694 -> DC_1 (avg coappear 40.0)
# SKU 87087 -> DC_1 (avg coappear 39.1)
# SKU 96932 -> DC_1 (avg coappear 43.2)
# SKU 79447 -> DC_1 (avg coappear 44.2)
# SKU 64290 -> DC_1 (avg coappear 33.1)
# SKU 79345 -> DC_1 (avg coappear 49.2)
# SKU 97876 -> DC_1 (avg coappear 41.2)
# SKU 79510 -> DC_1 (avg coappear 43.7)
# SKU 1075 -> DC_1 (avg coappear 46.8)
# SKU 20998 -> DC_1 (avg coappear 40.8)
# SKU 57578 -> DC_1 (avg coappear 34.5)
# SKU 99037 -> DC_1 (avg coappear 43.1)
# SKU 47379 -> DC_1 (avg coappear 47.0)
# SKU 89004 -> DC_1 (avg coappear 33.6)
# SKU 981 -> DC_1 (avg coappear 41.6)
# SKU 85115 -> DC_1 (avg coappear 38.5)
# SKU 17073 -> DC_1 (avg coappear 38.3)
# SKU 94732 -> DC_1 (avg coappear 42.5)
# SKU 83076 -> DC_1 (avg coappear 44.7)
# SKU 35858 -> DC_1 (avg coappear 52.2)
# SKU 96582 -> DC_1 (avg coappear 48.8)
# SKU 84569 -> DC_1 (avg coappear 39.9)
# SKU 70964 -> DC_1 (avg coappear 30.2)
# SKU 97890 -> DC_1 (avg coappear 35.2)
# SKU 78175 -> DC_1 (avg coappear 27.3)
# SKU 97452 -> DC_1 (avg coappear 35.9)
# SKU 73464 -> DC_1 (avg coappear 35.1)
# SKU 97459 -> DC_1 (avg coappear 40.1)
# SKU 73321 -> DC_1 (avg coappear 49.3)
# SKU 92623 -> DC_1 (avg coappear 47.1)
# SKU 94193 -> DC_1 (avg coappear 42.4)
# SKU 60866 -> DC_1 (avg coappear 26.2)
# SKU 59580 -> DC_1 (avg coappear 37.9)
# SKU 84888 -> DC_1 (avg coappear 43.6)
# SKU 5335 -> DC_1 (avg coappear 40.4)
# SKU 71834 -> DC_1 (avg coappear 38.4)
# SKU 103910 -> DC_1 (avg coappear 31.6)
# SKU 52721 -> DC_1 (avg coappear 40.2)
# SKU 8592 -> DC_1 (avg coappear 43.1)
# SKU 83809 -> DC_1 (avg coappear 49.0)
# SKU 94667 -> DC_1 (avg coappear 43.8)
# SKU 73059 -> DC_1 (avg coappear 48.6)
# SKU 94283 -> DC_1 (avg coappear 44.7)
# SKU 52819 -> DC_1 (avg coappear 42.1)
# SKU 84003 -> DC_1 (avg coappear 44.5)
# SKU 4619 -> DC_1 (avg coappear 43.8)
# SKU 68646 -> DC_1 (avg coappear 31.1)
# SKU 760 -> DC_1 (avg coappear 22.2)
# SKU 93820 -> DC_1 (avg coappear 42.6)
# SKU 98907 -> DC_1 (avg coappear 48.2)
# SKU 94729 -> DC_1 (avg coappear 34.5)
# SKU 104170 -> DC_2 (avg coappear 361.0)
# SKU 59805 -> DC_1 (avg coappear 41.0)
# SKU 49856 -> DC_1 (avg coappear 39.8)
# SKU 68650 -> DC_1 (avg coappear 23.0)
# SKU 1129 -> DC_1 (avg coappear 36.7)
# SKU 72354 -> DC_1 (avg coappear 34.6)
# SKU 53627 -> DC_1 (avg coappear 37.1)
# SKU 831 -> DC_1 (avg coappear 34.2)
# SKU 2948 -> DC_1 (avg coappear 45.0)
# SKU 12427 -> DC_1 (avg coappear 43.6)
# SKU 55625 -> DC_1 (avg coappear 48.1)
# SKU 97665 -> DC_1 (avg coappear 40.2)
# SKU 71893 -> DC_1 (avg coappear 40.6)
# SKU 93616 -> DC_1 (avg coappear 35.0)
# SKU 96924 -> DC_1 (avg coappear 43.6)
# SKU 102034 -> DC_1 (avg coappear 36.1)
# SKU 15082 -> DC_1 (avg coappear 51.8)
# SKU 60590 -> DC_1 (avg coappear 28.4)
# SKU 97450 -> DC_1 (avg coappear 27.9)
# SKU 668 -> DC_1 (avg coappear 35.6)
# SKU 15974 -> DC_1 (avg coappear 36.4)
# SKU 73452 -> DC_1 (avg coappear 37.7)
# SKU 100944 -> DC_1 (avg coappear 37.9)
# SKU 99033 -> DC_1 (avg coappear 36.4)
# SKU 32839 -> DC_1 (avg coappear 41.6)
# SKU 32695 -> DC_1 (avg coappear 37.4)
# SKU 94870 -> DC_1 (avg coappear 39.9)
# SKU 55693 -> DC_1 (avg coappear 40.2)
# SKU 6988 -> DC_1 (avg coappear 29.3)
# SKU 56156 -> DC_1 (avg coappear 30.6)
# SKU 42526 -> DC_1 (avg coappear 39.5)
# SKU 44219 -> DC_1 (avg coappear 31.9)
# SKU 4262 -> DC_1 (avg coappear 40.0)
# SKU 1206 -> DC_1 (avg coappear 42.4)
# SKU 4901 -> DC_1 (avg coappear 21.9)
# SKU 97760 -> DC_1 (avg coappear 36.1)
# SKU 72177 -> DC_1 (avg coappear 42.5)
# SKU 6384 -> DC_1 (avg coappear 28.0)
# SKU 94873 -> DC_1 (avg coappear 35.5)
# SKU 93975 -> DC_1 (avg coappear 47.2)
# SKU 96580 -> DC_1 (avg coappear 40.2)
# SKU 77703 -> DC_1 (avg coappear 22.8)
# SKU 92589 -> DC_1 (avg coappear 36.5)
# SKU 94181 -> DC_1 (avg coappear 39.8)
# SKU 103947 -> DC_1 (avg coappear 42.5)
# SKU 100893 -> DC_1 (avg coappear 43.3)
# SKU 75642 -> DC_1 (avg coappear 46.6)
# SKU 27139 -> DC_1 (avg coappear 50.5)
# SKU 4565 -> DC_1 (avg coappear 32.9)
# SKU 100288 -> DC_1 (avg coappear 22.0)
# SKU 97836 -> DC_1 (avg coappear 33.9)
# SKU 72607 -> DC_1 (avg coappear 39.2)
# SKU 78160 -> DC_1 (avg coappear 32.0)
# SKU 61832 -> DC_1 (avg coappear 47.6)
# SKU 42451 -> DC_1 (avg coappear 39.4)
# SKU 55415 -> DC_1 (avg coappear 34.0)
# SKU 99669 -> DC_1 (avg coappear 33.7)
# SKU 99607 -> DC_1 (avg coappear 38.0)
# SKU 99066 -> DC_1 (avg coappear 48.6)
# SKU 5181 -> DC_1 (avg coappear 29.9)
# SKU 8095 -> DC_1 (avg coappear 40.1)
# SKU 71698 -> DC_1 (avg coappear 31.6)
# SKU 93281 -> DC_1 (avg coappear 36.3)
# SKU 97906 -> DC_1 (avg coappear 32.9)
# SKU 4254 -> DC_1 (avg coappear 26.6)
# SKU 104358 -> DC_1 (avg coappear 28.6)
# SKU 90459 -> DC_1 (avg coappear 41.3)
# SKU 4749 -> DC_1 (avg coappear 33.7)
# SKU 8739 -> DC_1 (avg coappear 41.5)
# SKU 96927 -> DC_1 (avg coappear 35.9)
# SKU 97905 -> DC_1 (avg coappear 32.0)
# SKU 8850 -> DC_1 (avg coappear 37.2)
# SKU 96899 -> DC_1 (avg coappear 36.7)
# SKU 44218 -> DC_1 (avg coappear 29.4)
# SKU 23637 -> DC_1 (avg coappear 33.9)
# SKU 87491 -> DC_1 (avg coappear 33.4)
# SKU 86155 -> DC_1 (avg coappear 34.6)
# SKU 19111 -> DC_1 (avg coappear 29.5)
# SKU 97067 -> DC_1 (avg coappear 30.8)
# SKU 93600 -> DC_1 (avg coappear 41.2)
# SKU 102855 -> DC_1 (avg coappear 43.1)
# SKU 87489 -> DC_1 (avg coappear 26.2)
# SKU 82714 -> DC_1 (avg coappear 35.4)
# SKU 73997 -> DC_1 (avg coappear 21.8)
# SKU 81513 -> DC_1 (avg coappear 39.2)
# SKU 8634 -> DC_1 (avg coappear 36.6)
# SKU 99090 -> DC_1 (avg coappear 31.1)
# SKU 96879 -> DC_1 (avg coappear 41.3)
# SKU 53410 -> DC_1 (avg coappear 33.7)
# SKU 6123 -> DC_1 (avg coappear 36.1)
# SKU 65098 -> DC_1 (avg coappear 41.0)
# SKU 98010 -> DC_1 (avg coappear 42.7)
# SKU 104360 -> DC_1 (avg coappear 23.7)
# SKU 5330 -> DC_1 (avg coappear 35.8)
# SKU 96141 -> DC_1 (avg coappear 37.2)
# SKU 54420 -> DC_1 (avg coappear 32.7)
# SKU 24577 -> DC_1 (avg coappear 44.8)
# SKU 60891 -> DC_1 (avg coappear 34.5)
# SKU 96497 -> DC_1 (avg coappear 29.3)
# SKU 99388 -> DC_1 (avg coappear 40.3)
# SKU 93610 -> DC_1 (avg coappear 30.5)
# SKU 100993 -> DC_1 (avg coappear 37.5)
# SKU 98814 -> DC_1 (avg coappear 35.8)
# SKU 251 -> DC_1 (avg coappear 34.0)
# SKU 100177 -> DC_1 (avg coappear 32.4)
# SKU 5074 -> DC_1 (avg coappear 28.6)
# SKU 101308 -> DC_2 (avg coappear 193.0)
# SKU 24430 -> DC_1 (avg coappear 40.4)
# SKU 94670 -> DC_1 (avg coappear 32.8)
# SKU 15117 -> DC_1 (avg coappear 40.9)
# SKU 49054 -> DC_1 (avg coappear 26.7)
# SKU 8176 -> DC_1 (avg coappear 35.9)
# SKU 1910 -> DC_1 (avg coappear 35.5)
# SKU 81025 -> DC_1 (avg coappear 36.9)
# SKU 88512 -> DC_1 (avg coappear 33.5)
# SKU 97494 -> DC_1 (avg coappear 32.1)
# SKU 96930 -> DC_1 (avg coappear 31.8)
# SKU 99564 -> DC_1 (avg coappear 31.7)
# SKU 96900 -> DC_1 (avg coappear 33.8)
# SKU 104844 -> DC_1 (avg coappear 35.8)
# SKU 99389 -> DC_1 (avg coappear 38.2)
# SKU 1677 -> DC_1 (avg coappear 42.3)
# SKU 59977 -> DC_1 (avg coappear 20.8)
# SKU 102463 -> DC_1 (avg coappear 35.6)
# SKU 96366 -> DC_1 (avg coappear 38.4)
# SKU 96882 -> DC_1 (avg coappear 33.5)
# SKU 88910 -> DC_1 (avg coappear 39.0)
# SKU 88005 -> DC_1 (avg coappear 27.1)
# SKU 1155 -> DC_1 (avg coappear 34.4)
# SKU 73451 -> DC_1 (avg coappear 33.0)
# SKU 83025 -> DC_1 (avg coappear 33.1)
# SKU 53350 -> DC_1 (avg coappear 29.9)
# SKU 96 -> DC_1 (avg coappear 32.0)
# SKU 94668 -> DC_1 (avg coappear 36.1)
# SKU 42935 -> DC_1 (avg coappear 33.3)
# SKU 6184 -> DC_1 (avg coappear 30.8)
# SKU 100669 -> DC_1 (avg coappear 36.4)
# SKU 694 -> DC_1 (avg coappear 34.3)
# SKU 79783 -> DC_1 (avg coappear 37.5)
# SKU 102132 -> DC_1 (avg coappear 28.4)
# SKU 87586 -> DC_1 (avg coappear 27.6)
# SKU 75391 -> DC_1 (avg coappear 41.0)
# SKU 104359 -> DC_1 (avg coappear 25.8)
# SKU 72290 -> DC_1 (avg coappear 35.9)
# SKU 87840 -> DC_1 (avg coappear 35.1)
# SKU 96896 -> DC_1 (avg coappear 31.6)
# SKU 92518 -> DC_1 (avg coappear 31.3)
# SKU 37601 -> DC_1 (avg coappear 22.5)
# SKU 90449 -> DC_1 (avg coappear 37.3)
# SKU 95482 -> DC_1 (avg coappear 29.4)
# SKU 4702 -> DC_1 (avg coappear 29.3)
# SKU 4747 -> DC_1 (avg coappear 27.1)
# SKU 95842 -> DC_1 (avg coappear 40.0)
# SKU 95841 -> DC_1 (avg coappear 41.7)
# SKU 100819 -> DC_1 (avg coappear 25.2)
# SKU 96891 -> DC_1 (avg coappear 33.3)
# SKU 71094 -> DC_1 (avg coappear 32.0)
# SKU 61026 -> DC_1 (avg coappear 29.5)
# SKU 87578 -> DC_1 (avg coappear 32.2)
# SKU 47110 -> DC_1 (avg coappear 30.1)
# SKU 97851 -> DC_1 (avg coappear 29.4)
# SKU 3152 -> DC_1 (avg coappear 31.9)
# SKU 71113 -> DC_1 (avg coappear 35.5)
# SKU 34587 -> DC_1 (avg coappear 29.1)
# SKU 21726 -> DC_1 (avg coappear 33.8)
# SKU 89408 -> DC_1 (avg coappear 28.3)
# SKU 411 -> DC_1 (avg coappear 24.5)
# SKU 97881 -> DC_1 (avg coappear 32.3)
# SKU 86739 -> DC_1 (avg coappear 31.9)
# SKU 88933 -> DC_1 (avg coappear 39.6)
# SKU 101315 -> DC_2 (avg coappear 303.2)
# SKU 102036 -> DC_1 (avg coappear 26.9)
# SKU 94194 -> DC_1 (avg coappear 34.2)
# SKU 104780 -> DC_1 (avg coappear 29.5)
# SKU 32840 -> DC_1 (avg coappear 36.2)
# SKU 87590 -> DC_1 (avg coappear 26.9)
# SKU 43407 -> DC_1 (avg coappear 31.3)
# SKU 97755 -> DC_1 (avg coappear 27.9)
# SKU 77702 -> DC_1 (avg coappear 19.7)
# SKU 69428 -> DC_1 (avg coappear 29.6)
# SKU 2268 -> DC_1 (avg coappear 30.4)
# SKU 21852 -> DC_1 (avg coappear 36.8)
# SKU 38741 -> DC_1 (avg coappear 34.1)
# SKU 94225 -> DC_1 (avg coappear 36.4)
# SKU 91132 -> DC_1 (avg coappear 35.0)
# SKU 8398 -> DC_1 (avg coappear 37.2)
# SKU 100183 -> DC_1 (avg coappear 25.6)
# SKU 71478 -> DC_1 (avg coappear 46.2)
# SKU 96579 -> DC_1 (avg coappear 34.0)
# SKU 77956 -> DC_1 (avg coappear 40.3)
# SKU 51403 -> DC_1 (avg coappear 31.3)
# SKU 60664 -> DC_1 (avg coappear 31.9)
# SKU 6159 -> DC_1 (avg coappear 29.7)
# SKU 41663 -> DC_1 (avg coappear 32.9)
# SKU 100948 -> DC_1 (avg coappear 30.5)
# SKU 563 -> DC_1 (avg coappear 28.2)
# SKU 38515 -> DC_1 (avg coappear 36.5)
# SKU 96681 -> DC_1 (avg coappear 27.1)
# SKU 102473 -> DC_1 (avg coappear 30.7)
# SKU 78296 -> DC_1 (avg coappear 36.0)
# SKU 96915 -> DC_1 (avg coappear 33.6)
# SKU 83074 -> DC_1 (avg coappear 36.2)
# SKU 1559 -> DC_1 (avg coappear 27.5)
# SKU 103751 -> DC_1 (avg coappear 30.5)
# SKU 14987 -> DC_1 (avg coappear 31.1)
# SKU 89407 -> DC_1 (avg coappear 25.4)
# SKU 99225 -> DC_1 (avg coappear 38.0)
# SKU 94472 -> DC_1 (avg coappear 30.5)
# SKU 97287 -> DC_1 (avg coappear 29.2)
# SKU 40346 -> DC_1 (avg coappear 37.7)
# SKU 94875 -> DC_1 (avg coappear 31.3)
# SKU 84312 -> DC_1 (avg coappear 38.8)
# SKU 7305 -> DC_1 (avg coappear 30.8)
# SKU 56616 -> DC_1 (avg coappear 24.2)
# SKU 101262 -> DC_1 (avg coappear 19.5)
# SKU 45956 -> DC_1 (avg coappear 33.1)
# SKU 31536 -> DC_1 (avg coappear 34.7)
# SKU 94178 -> DC_1 (avg coappear 29.7)
# SKU 97900 -> DC_1 (avg coappear 29.9)
# SKU 88929 -> DC_1 (avg coappear 33.2)
# SKU 72281 -> DC_1 (avg coappear 35.6)
# SKU 15244 -> DC_1 (avg coappear 31.5)
# SKU 820 -> DC_1 (avg coappear 29.2)
# SKU 70755 -> DC_1 (avg coappear 34.2)
# SKU 10273 -> DC_1 (avg coappear 25.6)
# SKU 72841 -> DC_1 (avg coappear 30.0)
# SKU 103542 -> DC_1 (avg coappear 23.3)
# SKU 55631 -> DC_1 (avg coappear 35.6)
# SKU 65694 -> DC_1 (avg coappear 33.7)
# SKU 73811 -> DC_1 (avg coappear 30.9)
# SKU 100817 -> DC_1 (avg coappear 30.6)
# SKU 53411 -> DC_1 (avg coappear 30.7)
# SKU 94734 -> DC_1 (avg coappear 30.5)
# SKU 84563 -> DC_1 (avg coappear 36.2)
# SKU 86644 -> DC_1 (avg coappear 26.9)
# SKU 47378 -> DC_1 (avg coappear 29.8)
# SKU 102134 -> DC_1 (avg coappear 27.1)
# SKU 102858 -> DC_1 (avg coappear 37.1)
# SKU 94869 -> DC_1 (avg coappear 23.0)
# SKU 102859 -> DC_1 (avg coappear 36.8)
# SKU 1872 -> DC_1 (avg coappear 32.0)
# SKU 86445 -> DC_1 (avg coappear 34.4)
# SKU 35497 -> DC_1 (avg coappear 35.7)
# SKU 51686 -> DC_1 (avg coappear 29.6)
# SKU 55501 -> DC_1 (avg coappear 25.7)
# SKU 6516 -> DC_1 (avg coappear 25.2)
# SKU 1747 -> DC_1 (avg coappear 32.7)
# SKU 88907 -> DC_1 (avg coappear 26.7)
# SKU 22721 -> DC_1 (avg coappear 38.8)
# SKU 104835 -> DC_1 (avg coappear 28.7)
# SKU 88120 -> DC_1 (avg coappear 24.3)
# SKU 76071 -> DC_1 (avg coappear 27.4)
# SKU 9539 -> DC_1 (avg coappear 22.2)
# SKU 102126 -> DC_1 (avg coappear 18.8)
# SKU 15265 -> DC_1 (avg coappear 31.3)
# SKU 85135 -> DC_1 (avg coappear 24.0)
# SKU 94418 -> DC_2 (avg coappear 28.4)
# SKU 94727 -> DC_1 (avg coappear 27.4)
# SKU 1705 -> DC_1 (avg coappear 30.6)
# SKU 70965 -> DC_1 (avg coappear 25.2)
# SKU 72706 -> DC_1 (avg coappear 29.5)
# SKU 83064 -> DC_1 (avg coappear 33.2)
# SKU 6394 -> DC_1 (avg coappear 29.5)
# SKU 3455 -> DC_1 (avg coappear 33.4)
# SKU 103911 -> DC_1 (avg coappear 23.2)
# SKU 68649 -> DC_1 (avg coappear 21.2)
# SKU 75305 -> DC_1 (avg coappear 29.2)
# SKU 104241 -> DC_1 (avg coappear 29.6)
# SKU 99155 -> DC_1 (avg coappear 28.8)
# SKU 16857 -> DC_1 (avg coappear 23.9)
# SKU 10054 -> DC_1 (avg coappear 38.2)
# SKU 75591 -> DC_1 (avg coappear 29.0)
# SKU 80369 -> DC_1 (avg coappear 25.5)
# SKU 100175 -> DC_1 (avg coappear 26.9)
# SKU 5339 -> DC_1 (avg coappear 31.1)
# SKU 103950 -> DC_1 (avg coappear 33.9)
# SKU 55627 -> DC_1 (avg coappear 37.1)
# SKU 84713 -> DC_1 (avg coappear 30.4)
# SKU 31479 -> DC_1 (avg coappear 29.5)
# SKU 43980 -> DC_1 (avg coappear 27.9)
# SKU 99227 -> DC_1 (avg coappear 34.7)
# SKU 44314 -> DC_1 (avg coappear 27.7)
# SKU 96904 -> DC_1 (avg coappear 27.6)
# SKU 103696 -> DC_1 (avg coappear 29.5)
# SKU 97496 -> DC_1 (avg coappear 18.2)
# SKU 85000 -> DC_1 (avg coappear 30.1)
# SKU 90162 -> DC_1 (avg coappear 30.5)
# SKU 48115 -> DC_1 (avg coappear 33.0)
# SKU 2136 -> DC_1 (avg coappear 25.3)
# SKU 862 -> DC_1 (avg coappear 25.4)
# SKU 79145 -> DC_1 (avg coappear 23.4)
# SKU 5275 -> DC_1 (avg coappear 23.7)
# SKU 83795 -> DC_1 (avg coappear 16.7)
# SKU 77898 -> DC_1 (avg coappear 29.4)
# SKU 73690 -> DC_1 (avg coappear 24.6)
# SKU 102813 -> DC_1 (avg coappear 24.1)
# SKU 96946 -> DC_1 (avg coappear 18.5)
# SKU 4402 -> DC_1 (avg coappear 25.2)
# SKU 102469 -> DC_1 (avg coappear 28.9)
# SKU 91536 -> DC_1 (avg coappear 28.1)
# SKU 97583 -> DC_1 (avg coappear 33.0)
# SKU 102692 -> DC_1 (avg coappear 32.6)
# SKU 104311 -> DC_1 (avg coappear 30.1)
# SKU 42009 -> DC_1 (avg coappear 33.0)
# SKU 96894 -> DC_1 (avg coappear 30.9)
# SKU 102857 -> DC_1 (avg coappear 35.3)
# SKU 53548 -> DC_1 (avg coappear 28.1)
# SKU 5756 -> DC_1 (avg coappear 21.6)
# SKU 50655 -> DC_1 (avg coappear 27.1)
# SKU 49599 -> DC_1 (avg coappear 23.1)
# SKU 50094 -> DC_1 (avg coappear 29.5)
# SKU 49855 -> DC_1 (avg coappear 22.9)
# SKU 32011 -> DC_1 (avg coappear 21.0)
# SKU 23998 -> DC_1 (avg coappear 20.4)
# SKU 85845 -> DC_1 (avg coappear 26.6)
# SKU 60869 -> DC_1 (avg coappear 17.8)
# SKU 2006 -> DC_1 (avg coappear 25.1)
# SKU 35487 -> DC_1 (avg coappear 33.4)
# SKU 72462 -> DC_1 (avg coappear 26.4)
# SKU 38470 -> DC_1 (avg coappear 27.1)
# SKU 55852 -> DC_1 (avg coappear 26.7)
# SKU 72276 -> DC_1 (avg coappear 23.8)
# SKU 46150 -> DC_1 (avg coappear 34.9)
# SKU 95686 -> DC_1 (avg coappear 15.9)
# SKU 69442 -> DC_1 (avg coappear 22.7)
# SKU 49991 -> DC_1 (avg coappear 33.9)
# SKU 3641 -> DC_1 (avg coappear 28.8)
# SKU 97493 -> DC_1 (avg coappear 28.7)
# SKU 96944 -> DC_1 (avg coappear 18.7)
# SKU 58033 -> DC_1 (avg coappear 29.9)
# SKU 72280 -> DC_1 (avg coappear 28.8)
# SKU 59762 -> DC_1 (avg coappear 31.2)
# SKU 87582 -> DC_1 (avg coappear 21.9)
# SKU 8848 -> DC_1 (avg coappear 25.3)
# SKU 71901 -> DC_1 (avg coappear 36.1)
# SKU 99731 -> DC_1 (avg coappear 28.1)
# SKU 91877 -> DC_1 (avg coappear 27.3)
# SKU 101542 -> DC_1 (avg coappear 24.3)
# SKU 92517 -> DC_1 (avg coappear 25.5)
# SKU 48524 -> DC_1 (avg coappear 27.4)
# SKU 85995 -> DC_1 (avg coappear 17.5)
# SKU 97579 -> DC_1 (avg coappear 32.9)
# SKU 96920 -> DC_1 (avg coappear 29.7)
# SKU 95683 -> DC_1 (avg coappear 16.9)
# SKU 97916 -> DC_1 (avg coappear 21.2)
# SKU 56154 -> DC_1 (avg coappear 21.5)
# SKU 1187 -> DC_1 (avg coappear 27.2)
# SKU 99158 -> DC_1 (avg coappear 26.1)
# SKU 84692 -> DC_1 (avg coappear 24.7)
# SKU 88471 -> DC_1 (avg coappear 24.1)
# SKU 50658 -> DC_1 (avg coappear 28.8)
# SKU 92590 -> DC_1 (avg coappear 27.5)
# SKU 100659 -> DC_1 (avg coappear 29.1)
# SKU 99668 -> DC_1 (avg coappear 23.7)
# SKU 49605 -> DC_1 (avg coappear 36.3)
# SKU 19148 -> DC_1 (avg coappear 22.3)
# SKU 84589 -> DC_1 (avg coappear 28.7)
# SKU 49859 -> DC_1 (avg coappear 22.4)
# SKU 102856 -> DC_1 (avg coappear 32.8)
# SKU 36122 -> DC_1 (avg coappear 21.9)
# SKU 100172 -> DC_1 (avg coappear 25.0)
# SKU 95636 -> DC_1 (avg coappear 27.8)
# SKU 95684 -> DC_1 (avg coappear 15.8)
# SKU 62177 -> DC_1 (avg coappear 25.3)
# SKU 72701 -> DC_1 (avg coappear 27.8)
# SKU 20997 -> DC_1 (avg coappear 30.8)
# SKU 102472 -> DC_1 (avg coappear 27.7)
# SKU 74347 -> DC_1 (avg coappear 31.2)
# SKU 41515 -> DC_1 (avg coappear 29.4)
# SKU 99559 -> DC_1 (avg coappear 28.4)
# SKU 2215 -> DC_1 (avg coappear 26.5)
# SKU 71285 -> DC_1 (avg coappear 21.5)
# SKU 84968 -> DC_1 (avg coappear 32.4)
# SKU 60875 -> DC_1 (avg coappear 21.2)
# SKU 102765 -> DC_1 (avg coappear 19.3)
# SKU 45966 -> DC_1 (avg coappear 25.6)
# SKU 52228 -> DC_1 (avg coappear 29.7)
# SKU 97915 -> DC_1 (avg coappear 20.4)
# SKU 61666 -> DC_1 (avg coappear 29.8)
# SKU 59454 -> DC_1 (avg coappear 33.2)
# SKU 2934 -> DC_1 (avg coappear 23.2)
# SKU 100166 -> DC_1 (avg coappear 26.7)
# SKU 44799 -> DC_1 (avg coappear 31.3)
# SKU 72153 -> DC_1 (avg coappear 19.7)
# SKU 78589 -> DC_1 (avg coappear 26.2)
# SKU 90970 -> DC_1 (avg coappear 32.4)
# SKU 77897 -> DC_1 (avg coappear 27.8)
# SKU 88906 -> DC_1 (avg coappear 23.8)
# SKU 850 -> DC_1 (avg coappear 28.8)
# SKU 100287 -> DC_1 (avg coappear 16.7)
# SKU 95755 -> DC_1 (avg coappear 20.3)
# SKU 98687 -> DC_1 (avg coappear 30.7)
# SKU 91130 -> DC_1 (avg coappear 29.4)
# SKU 7435 -> DC_1 (avg coappear 24.1)
# SKU 68935 -> DC_1 (avg coappear 24.4)
# SKU 58201 -> DC_1 (avg coappear 31.6)
# SKU 32614 -> DC_1 (avg coappear 25.9)
# SKU 1473 -> DC_1 (avg coappear 28.8)
# SKU 103541 -> DC_1 (avg coappear 26.1)
# SKU 94182 -> DC_1 (avg coappear 25.8)
# SKU 83079 -> DC_1 (avg coappear 29.6)
# SKU 96933 -> DC_1 (avg coappear 25.3)
# SKU 88805 -> DC_1 (avg coappear 21.5)
# SKU 102690 -> DC_1 (avg coappear 31.1)
# SKU 57541 -> DC_1 (avg coappear 23.8)
# SKU 52552 -> DC_1 (avg coappear 30.0)
# SKU 104000 -> DC_1 (avg coappear 28.6)
# SKU 96807 -> DC_1 (avg coappear 23.1)
# SKU 83835 -> DC_2 (avg coappear 45.2)
# SKU 99240 -> DC_1 (avg coappear 25.0)
# SKU 2201 -> DC_1 (avg coappear 28.1)
# SKU 94496 -> DC_1 (avg coappear 26.2)
# SKU 41659 -> DC_1 (avg coappear 21.8)
# SKU 30790 -> DC_1 (avg coappear 22.8)
# SKU 53845 -> DC_1 (avg coappear 28.3)
# SKU 11747 -> DC_1 (avg coappear 23.2)
# SKU 6623 -> DC_1 (avg coappear 24.8)
# SKU 52156 -> DC_1 (avg coappear 26.9)
# SKU 75306 -> DC_1 (avg coappear 25.9)
# SKU 99085 -> DC_1 (avg coappear 33.8)
# SKU 96949 -> DC_1 (avg coappear 16.7)
# SKU 1754 -> DC_1 (avg coappear 28.5)
# SKU 72508 -> DC_1 (avg coappear 30.0)
# SKU 58237 -> DC_1 (avg coappear 20.1)
# SKU 88687 -> DC_1 (avg coappear 30.7)
# SKU 36702 -> DC_1 (avg coappear 35.2)
# SKU 97848 -> DC_1 (avg coappear 23.0)
# SKU 38281 -> DC_1 (avg coappear 26.0)
# SKU 12030 -> DC_1 (avg coappear 24.2)
# SKU 59061 -> DC_1 (avg coappear 32.4)
# SKU 104768 -> DC_1 (avg coappear 27.3)
# SKU 93359 -> DC_1 (avg coappear 22.4)
# SKU 77704 -> DC_1 (avg coappear 15.2)
# SKU 101738 -> DC_1 (avg coappear 27.1)
# SKU 104702 -> DC_1 (avg coappear 17.3)
# SKU 99068 -> DC_1 (avg coappear 27.6)
# SKU 1884 -> DC_1 (avg coappear 24.5)
# SKU 100150 -> DC_1 (avg coappear 30.8)
# SKU 104147 -> DC_1 (avg coappear 28.8)
# SKU 92964 -> DC_1 (avg coappear 21.6)
# SKU 103177 -> DC_1 (avg coappear 26.9)
# SKU 84800 -> DC_1 (avg coappear 19.5)
# SKU 96921 -> DC_1 (avg coappear 28.2)
# SKU 31419 -> DC_1 (avg coappear 28.2)
# SKU 3686 -> DC_1 (avg coappear 29.1)
# SKU 102695 -> DC_1 (avg coappear 30.0)
# SKU 47272 -> DC_1 (avg coappear 21.5)
# SKU 95480 -> DC_1 (avg coappear 20.1)
# SKU 98089 -> DC_1 (avg coappear 26.8)
# SKU 51840 -> DC_1 (avg coappear 20.5)
# SKU 83794 -> DC_1 (avg coappear 16.6)
# SKU 97492 -> DC_1 (avg coappear 20.1)
# SKU 98915 -> DC_1 (avg coappear 26.3)
# SKU 72463 -> DC_1 (avg coappear 23.5)
# SKU 104567 -> DC_1 (avg coappear 24.6)
# SKU 4700 -> DC_1 (avg coappear 26.1)
# SKU 57615 -> DC_1 (avg coappear 21.0)
# SKU 103909 -> DC_1 (avg coappear 15.6)
# SKU 100285 -> DC_1 (avg coappear 15.4)
# SKU 16787 -> DC_1 (avg coappear 20.3)
# SKU 101707 -> DC_1 (avg coappear 16.8)
# SKU 99193 -> DC_1 (avg coappear 22.4)
# SKU 102814 -> DC_1 (avg coappear 19.0)
# SKU 94195 -> DC_1 (avg coappear 24.2)
# SKU 100872 -> DC_1 (avg coappear 23.1)
# SKU 87837 -> DC_1 (avg coappear 21.9)
# SKU 88733 -> DC_1 (avg coappear 32.1)
# SKU 1555 -> DC_1 (avg coappear 19.6)
# SKU 8870 -> DC_1 (avg coappear 25.9)
# SKU 62111 -> DC_1 (avg coappear 27.7)
# SKU 6390 -> DC_1 (avg coappear 22.0)
# SKU 74362 -> DC_1 (avg coappear 26.3)
# SKU 3622 -> DC_1 (avg coappear 20.1)
# SKU 5309 -> DC_1 (avg coappear 17.3)
# SKU 75366 -> DC_1 (avg coappear 15.9)
# SKU 99049 -> DC_1 (avg coappear 28.1)
# SKU 94643 -> DC_1 (avg coappear 23.0)
# SKU 101750 -> DC_1 (avg coappear 30.5)
# SKU 4164 -> DC_1 (avg coappear 23.3)
# SKU 103063 -> DC_1 (avg coappear 15.1)
# SKU 99039 -> DC_1 (avg coappear 23.2)
# SKU 72353 -> DC_1 (avg coappear 21.1)
# SKU 102173 -> DC_1 (avg coappear 33.1)
# SKU 63967 -> DC_1 (avg coappear 26.7)
# SKU 93983 -> DC_1 (avg coappear 25.2)
# SKU 79634 -> DC_1 (avg coappear 21.6)
# SKU 92588 -> DC_1 (avg coappear 27.4)
# SKU 102992 -> DC_1 (avg coappear 23.8)
# SKU 22806 -> DC_1 (avg coappear 27.6)
# SKU 89092 -> DC_1 (avg coappear 16.2)
# SKU 83068 -> DC_1 (avg coappear 27.3)
# SKU 62109 -> DC_1 (avg coappear 24.3)
# SKU 80540 -> DC_1 (avg coappear 21.0)
# SKU 97161 -> DC_1 (avg coappear 29.3)
# SKU 3156 -> DC_1 (avg coappear 20.7)
# SKU 103949 -> DC_1 (avg coappear 28.4)
# SKU 84313 -> DC_1 (avg coappear 28.9)
# SKU 94671 -> DC_1 (avg coappear 27.0)
# SKU 100775 -> DC_1 (avg coappear 23.4)
# SKU 97866 -> DC_1 (avg coappear 20.9)
# SKU 720 -> DC_1 (avg coappear 23.8)
# SKU 102612 -> DC_1 (avg coappear 21.7)
# SKU 962 -> DC_1 (avg coappear 18.1)
# SKU 97455 -> DC_1 (avg coappear 16.5)
# SKU 83864 -> DC_1 (avg coappear 23.0)
# SKU 103699 -> DC_1 (avg coappear 24.4)
# SKU 83791 -> DC_1 (avg coappear 18.7)
# SKU 78288 -> DC_1 (avg coappear 19.8)
# SKU 42906 -> DC_1 (avg coappear 21.3)
# SKU 34435 -> DC_1 (avg coappear 21.3)
# SKU 96861 -> DC_1 (avg coappear 27.8)
# SKU 103993 -> DC_1 (avg coappear 26.7)
# SKU 16398 -> DC_1 (avg coappear 31.7)
# SKU 4887 -> DC_1 (avg coappear 19.0)
# SKU 82897 -> DC_1 (avg coappear 23.7)
# SKU 102824 -> DC_1 (avg coappear 27.6)
# SKU 99051 -> DC_1 (avg coappear 24.5)
# SKU 95725 -> DC_1 (avg coappear 14.7)
# SKU 94282 -> DC_1 (avg coappear 17.1)
# SKU 77894 -> DC_1 (avg coappear 23.2)
# SKU 99455 -> DC_1 (avg coappear 25.2)
# SKU 101727 -> DC_1 (avg coappear 25.5)
# SKU 100853 -> DC_1 (avg coappear 21.9)
# SKU 60249 -> DC_1 (avg coappear 19.5)
# SKU 1132 -> DC_1 (avg coappear 25.5)
# SKU 77237 -> DC_1 (avg coappear 24.4)
# SKU 250 -> DC_1 (avg coappear 20.1)
# SKU 100013 -> DC_1 (avg coappear 18.6)
# SKU 71625 -> DC_1 (avg coappear 21.1)
# SKU 87587 -> DC_1 (avg coappear 16.9)
# SKU 18367 -> DC_1 (avg coappear 22.0)
# SKU 72601 -> DC_1 (avg coappear 20.7)
# SKU 97753 -> DC_1 (avg coappear 24.7)
# SKU 97901 -> DC_1 (avg coappear 21.7)
# SKU 30354 -> DC_1 (avg coappear 20.5)
# SKU 82622 -> DC_1 (avg coappear 12.7)
# SKU 10746 -> DC_1 (avg coappear 18.5)
# SKU 74657 -> DC_1 (avg coappear 25.2)
# SKU 35039 -> DC_1 (avg coappear 14.0)
# SKU 56374 -> DC_1 (avg coappear 21.3)
# SKU 28240 -> DC_1 (avg coappear 31.8)
# SKU 99566 -> DC_1 (avg coappear 19.6)
# SKU 96864 -> DC_1 (avg coappear 25.8)
# SKU 6124 -> DC_1 (avg coappear 15.4)
# SKU 86004 -> DC_1 (avg coappear 19.9)
# SKU 102696 -> DC_1 (avg coappear 26.2)
# SKU 38914 -> DC_1 (avg coappear 26.2)
# SKU 873 -> DC_1 (avg coappear 22.8)
# SKU 101069 -> DC_1 (avg coappear 12.3)
# SKU 4362 -> DC_1 (avg coappear 15.1)
# SKU 72840 -> DC_1 (avg coappear 23.4)
# SKU 100894 -> DC_1 (avg coappear 24.8)
# SKU 8773 -> DC_1 (avg coappear 20.9)
# SKU 87997 -> DC_1 (avg coappear 16.9)
# SKU 3363 -> DC_1 (avg coappear 21.9)
# SKU 91237 -> DC_1 (avg coappear 28.0)
# SKU 88222 -> DC_1 (avg coappear 20.3)
# SKU 55188 -> DC_1 (avg coappear 22.4)
# SKU 97497 -> DC_1 (avg coappear 20.2)
# SKU 22637 -> DC_1 (avg coappear 27.9)
# SKU 49907 -> DC_1 (avg coappear 21.9)
# SKU 1767 -> DC_1 (avg coappear 19.7)
# SKU 84587 -> DC_1 (avg coappear 22.0)
# SKU 57579 -> DC_1 (avg coappear 18.7)
# SKU 97898 -> DC_1 (avg coappear 25.3)
# SKU 93840 -> DC_1 (avg coappear 20.0)
# SKU 96928 -> DC_1 (avg coappear 21.9)
# SKU 96870 -> DC_1 (avg coappear 26.3)
# SKU 45953 -> DC_1 (avg coappear 19.8)
# SKU 62525 -> DC_1 (avg coappear 21.3)
# SKU 60883 -> DC_1 (avg coappear 25.0)
# SKU 43684 -> DC_1 (avg coappear 19.1)
# SKU 9342 -> DC_1 (avg coappear 21.0)
# SKU 87588 -> DC_1 (avg coappear 16.9)
# SKU 6132 -> DC_1 (avg coappear 25.1)
# SKU 70365 -> DC_1 (avg coappear 19.0)
# SKU 64011 -> DC_1 (avg coappear 26.4)
# SKU 15394 -> DC_1 (avg coappear 17.6)
# SKU 1761 -> DC_1 (avg coappear 22.7)
# SKU 94196 -> DC_1 (avg coappear 21.8)
# SKU 102225 -> DC_1 (avg coappear 14.0)
# SKU 55454 -> DC_1 (avg coappear 23.4)
# SKU 35488 -> DC_1 (avg coappear 26.6)
# SKU 95724 -> DC_1 (avg coappear 14.6)
# SKU 53412 -> DC_1 (avg coappear 24.3)
# SKU 262 -> DC_1 (avg coappear 18.2)
# SKU 83089 -> DC_1 (avg coappear 23.3)
# SKU 57577 -> DC_1 (avg coappear 21.2)
# SKU 94672 -> DC_1 (avg coappear 24.0)
# SKU 89117 -> DC_1 (avg coappear 16.1)
# SKU 87580 -> DC_1 (avg coappear 15.5)
# SKU 96887 -> DC_1 (avg coappear 23.4)
# SKU 77900 -> DC_1 (avg coappear 23.4)
# SKU 4701 -> DC_1 (avg coappear 22.8)
# SKU 79077 -> DC_1 (avg coappear 19.1)
# SKU 62926 -> DC_1 (avg coappear 15.8)
# SKU 99618 -> DC_1 (avg coappear 23.8)
# SKU 2724 -> DC_1 (avg coappear 20.6)
# SKU 88928 -> DC_1 (avg coappear 22.0)
# SKU 99558 -> DC_1 (avg coappear 21.2)
# SKU 35886 -> DC_1 (avg coappear 25.2)
# SKU 28619 -> DC_1 (avg coappear 15.9)
# SKU 68875 -> DC_1 (avg coappear 26.4)
# SKU 104294 -> DC_1 (avg coappear 21.0)
# SKU 1727 -> DC_1 (avg coappear 22.9)
# SKU 96918 -> DC_1 (avg coappear 21.8)
# SKU 103258 -> DC_1 (avg coappear 6.7)
# SKU 100173 -> DC_1 (avg coappear 19.0)
# SKU 71835 -> DC_1 (avg coappear 22.8)
# SKU 85854 -> DC_1 (avg coappear 10.3)
# SKU 4189 -> DC_1 (avg coappear 24.5)
# SKU 3289 -> DC_1 (avg coappear 19.1)
# SKU 34420 -> DC_1 (avg coappear 20.1)
# SKU 99560 -> DC_1 (avg coappear 20.8)
# SKU 104836 -> DC_1 (avg coappear 20.9)
# ...
# SKU 99877 -> DC_2 (avg coappear 0.0)
# SKU 100651 -> DC_2 (avg coappear 0.0)
# SKU 107727 -> DC_2 (avg coappear 0.0)
# SKU 93273 -> DC_2 (avg coappear 0.0)
# SKU 98050 -> DC_2 (avg coappear 0.0)
# SKU 105634 -> DC_2 (avg coappear 0.0)
# SKU 100703 -> DC_2 (avg coappear 0.0)
# SKU 92059 -> DC_2 (avg coappear 0.0)
# SKU 97709 -> DC_2 (avg coappear 0.0)
# SKU 97740 -> DC_2 (avg coappear 0.0)
# SKU 105635 -> DC_2 (avg coappear 0.0)
# SKU 99975 -> DC_2 (avg coappear 0.0)
# SKU 92489 -> DC_2 (avg coappear 0.0)
# SKU 100292 -> DC_2 (avg coappear 0.0)
# SKU 102649 -> DC_2 (avg coappear 0.0)
# SKU 102747 -> DC_2 (avg coappear 0.0)
# SKU 101218 -> DC_2 (avg coappear 0.0)
# SKU 101217 -> DC_2 (avg coappear 0.0)
# SKU 96457 -> DC_2 (avg coappear 0.0)
# SKU 105636 -> DC_2 (avg coappear 0.0)
# SKU 100059 -> DC_2 (avg coappear 0.0)
# SKU 91862 -> DC_2 (avg coappear 0.0)
# SKU 95170 -> DC_2 (avg coappear 0.0)
# SKU 90789 -> DC_2 (avg coappear 0.0)
# SKU 97044 -> DC_2 (avg coappear 0.0)
# SKU 96745 -> DC_1 (avg coappear 0.0)
# SKU 102636 -> DC_2 (avg coappear 0.0)
# SKU 98807 -> DC_2 (avg coappear 0.0)
# SKU 102634 -> DC_2 (avg coappear 0.0)
# SKU 95937 -> DC_2 (avg coappear 0.0)
# SKU 90575 -> DC_2 (avg coappear 0.0)
# SKU 101025 -> DC_2 (avg coappear 0.0)
# SKU 101956 -> DC_2 (avg coappear 0.0)
# SKU 100329 -> DC_2 (avg coappear 0.0)
# SKU 97716 -> DC_2 (avg coappear 0.0)
# SKU 60572 -> DC_2 (avg coappear 0.0)
# SKU 99856 -> DC_2 (avg coappear 0.0)
# SKU 64997 -> DC_2 (avg coappear 0.0)
# SKU 103572 -> DC_2 (avg coappear 0.0)
# SKU 98164 -> DC_2 (avg coappear 0.0)
# SKU 107698 -> DC_2 (avg coappear 0.0)
# SKU 107065 -> DC_2 (avg coappear 0.0)
# SKU 105659 -> DC_2 (avg coappear 0.0)
# SKU 98161 -> DC_2 (avg coappear 0.0)
# SKU 94470 -> DC_2 (avg coappear 0.0)
# SKU 105661 -> DC_2 (avg coappear 0.0)
# SKU 105665 -> DC_2 (avg coappear 0.0)
# SKU 107496 -> DC_2 (avg coappear 0.0)
# SKU 102650 -> DC_2 (avg coappear 0.0)
# SKU 105664 -> DC_2 (avg coappear 0.0)
# SKU 101250 -> DC_2 (avg coappear 0.0)
# SKU 105591 -> DC_2 (avg coappear 0.0)
# SKU 105654 -> DC_2 (avg coappear 0.0)
# SKU 101247 -> DC_2 (avg coappear 0.0)
# SKU 66813 -> DC_2 (avg coappear 0.0)
# SKU 91861 -> DC_2 (avg coappear 0.0)
# SKU 102193 -> DC_2 (avg coappear 0.0)
# SKU 84878 -> DC_2 (avg coappear 0.0)
# SKU 107709 -> DC_2 (avg coappear 0.0)
# SKU 91399 -> DC_2 (avg coappear 0.0)
# SKU 107713 -> DC_2 (avg coappear 0.0)
# SKU 107806 -> DC_2 (avg coappear 0.0)
# SKU 101465 -> DC_2 (avg coappear 0.0)
# SKU 79683 -> DC_2 (avg coappear 0.0)
# SKU 90781 -> DC_2 (avg coappear 0.0)
# SKU 108443 -> DC_2 (avg coappear 0.0)
# SKU 107807 -> DC_2 (avg coappear 0.0)
# SKU 91660 -> DC_2 (avg coappear 0.0)
# SKU 104698 -> DC_2 (avg coappear 0.0)
# SKU 102645 -> DC_2 (avg coappear 0.0)
# SKU 105401 -> DC_2 (avg coappear 0.0)
# SKU 94624 -> DC_2 (avg coappear 0.0)
# SKU 17456 -> DC_2 (avg coappear 0.0)
# SKU 98629 -> DC_2 (avg coappear 0.0)
# SKU 97096 -> DC_2 (avg coappear 0.0)
# SKU 82988 -> DC_2 (avg coappear 0.0)
# SKU 100058 -> DC_2 (avg coappear 0.0)
# SKU 92069 -> DC_2 (avg coappear 0.0)
# SKU 97039 -> DC_2 (avg coappear 0.0)
# SKU 101249 -> DC_2 (avg coappear 0.0)
# SKU 96244 -> DC_2 (avg coappear 0.0)
# SKU 95936 -> DC_2 (avg coappear 0.0)
# SKU 102633 -> DC_2 (avg coappear 0.0)
# SKU 95323 -> DC_2 (avg coappear 0.0)
# SKU 102197 -> DC_2 (avg coappear 0.0)
# SKU 102202 -> DC_2 (avg coappear 0.0)
# SKU 102207 -> DC_2 (avg coappear 0.0)
# SKU 101252 -> DC_2 (avg coappear 0.0)
# SKU 102203 -> DC_2 (avg coappear 0.0)
# SKU 91731 -> DC_2 (avg coappear 0.0)
# SKU 91805 -> DC_2 (avg coappear 0.0)
# SKU 88302 -> DC_2 (avg coappear 0.0)
# SKU 94555 -> DC_2 (avg coappear 0.0)
# SKU 99730 -> DC_2 (avg coappear 0.0)
# SKU 83570 -> DC_2 (avg coappear 0.0)
# SKU 83572 -> DC_2 (avg coappear 0.0)
# SKU 102208 -> DC_2 (avg coappear 0.0)
# SKU 102214 -> DC_2 (avg coappear 0.0)
# SKU 98289 -> DC_2 (avg coappear 0.0)
# SKU 103913 -> DC_2 (avg coappear 0.0)
# SKU 103566 -> DC_2 (avg coappear 0.0)
# SKU 75927 -> DC_2 (avg coappear 0.0)
# SKU 106664 -> DC_2 (avg coappear 0.0)
# SKU 107991 -> DC_2 (avg coappear 0.0)
# SKU 102198 -> DC_2 (avg coappear 0.0)
# SKU 107676 -> DC_2 (avg coappear 0.0)
# SKU 100052 -> DC_2 (avg coappear 0.0)
# SKU 89464 -> DC_2 (avg coappear 0.0)
# SKU 102209 -> DC_2 (avg coappear 0.0)
# SKU 107754 -> DC_2 (avg coappear 0.0)
# SKU 107063 -> DC_2 (avg coappear 0.0)
# SKU 80895 -> DC_2 (avg coappear 0.0)
# SKU 107162 -> DC_2 (avg coappear 0.0)
# SKU 86052 -> DC_2 (avg coappear 0.0)
# SKU 91615 -> DC_2 (avg coappear 0.0)
# SKU 99934 -> DC_2 (avg coappear 0.0)
# SKU 101290 -> DC_2 (avg coappear 0.0)
# SKU 100049 -> DC_2 (avg coappear 0.0)
# SKU 93731 -> DC_2 (avg coappear 0.0)
# SKU 100030 -> DC_2 (avg coappear 0.0)
# SKU 80872 -> DC_2 (avg coappear 0.0)
# SKU 106696 -> DC_2 (avg coappear 0.0)
# SKU 102679 -> DC_2 (avg coappear 0.0)
# SKU 83573 -> DC_2 (avg coappear 0.0)
# SKU 98441 -> DC_2 (avg coappear 0.0)
# SKU 83574 -> DC_2 (avg coappear 0.0)
# SKU 101244 -> DC_2 (avg coappear 0.0)
# SKU 97736 -> DC_2 (avg coappear 0.0)
# SKU 75921 -> DC_2 (avg coappear 0.0)
# SKU 93968 -> DC_2 (avg coappear 0.0)
# SKU 87132 -> DC_2 (avg coappear 0.0)
# SKU 102531 -> DC_2 (avg coappear 0.0)
# SKU 81879 -> DC_2 (avg coappear 0.0)
# SKU 101238 -> DC_2 (avg coappear 0.0)
# SKU 97708 -> DC_2 (avg coappear 0.0)
# SKU 96010 -> DC_2 (avg coappear 0.0)
# SKU 96011 -> DC_2 (avg coappear 0.0)
# SKU 107964 -> DC_2 (avg coappear 0.0)
# SKU 93458 -> DC_2 (avg coappear 0.0)
# SKU 97528 -> DC_2 (avg coappear 0.0)
# SKU 95367 -> DC_2 (avg coappear 0.0)
# SKU 108357 -> DC_2 (avg coappear 0.0)
# SKU 91689 -> DC_2 (avg coappear 0.0)
# SKU 97373 -> DC_2 (avg coappear 0.0)
# SKU 104313 -> DC_2 (avg coappear 0.0)
# SKU 90965 -> DC_2 (avg coappear 0.0)
# SKU 102180 -> DC_2 (avg coappear 0.0)
# SKU 97631 -> DC_2 (avg coappear 0.0)
# SKU 105732 -> DC_2 (avg coappear 0.0)
# SKU 97335 -> DC_2 (avg coappear 0.0)
# SKU 100992 -> DC_2 (avg coappear 0.0)
# SKU 107962 -> DC_2 (avg coappear 0.0)
# SKU 107961 -> DC_2 (avg coappear 0.0)
# SKU 91395 -> DC_2 (avg coappear 0.0)
# SKU 108027 -> DC_2 (avg coappear 0.0)
# SKU 100526 -> DC_2 (avg coappear 0.0)
# SKU 91613 -> DC_2 (avg coappear 0.0)
# SKU 108026 -> DC_2 (avg coappear 0.0)
# SKU 106962 -> DC_2 (avg coappear 0.0)
# SKU 108290 -> DC_2 (avg coappear 0.0)
# SKU 102413 -> DC_2 (avg coappear 0.0)
# SKU 96135 -> DC_2 (avg coappear 0.0)
# SKU 101243 -> DC_2 (avg coappear 0.0)
# SKU 108110 -> DC_2 (avg coappear 0.0)
# SKU 108202 -> DC_2 (avg coappear 0.0)
# SKU 103561 -> DC_2 (avg coappear 0.0)
# SKU 67785 -> DC_2 (avg coappear 0.0)
# SKU 107916 -> DC_2 (avg coappear 0.0)
# SKU 96025 -> DC_2 (avg coappear 0.0)
# SKU 99008 -> DC_2 (avg coappear 0.0)
# SKU 103559 -> DC_2 (avg coappear 0.0)
# SKU 95379 -> DC_2 (avg coappear 0.0)
# SKU 107700 -> DC_2 (avg coappear 0.0)
# SKU 91657 -> DC_2 (avg coappear 0.0)
# SKU 103921 -> DC_2 (avg coappear 0.0)
# SKU 107960 -> DC_2 (avg coappear 0.0)
# SKU 95775 -> DC_2 (avg coappear 0.0)
# SKU 107696 -> DC_2 (avg coappear 0.0)
# SKU 91397 -> DC_2 (avg coappear 0.0)
# SKU 66160 -> DC_2 (avg coappear 0.0)
# SKU 89249 -> DC_2 (avg coappear 0.0)
# SKU 88087 -> DC_2 (avg coappear 0.0)
# SKU 95600 -> DC_2 (avg coappear 0.0)
# SKU 103763 -> DC_2 (avg coappear 0.0)
# SKU 77804 -> DC_2 (avg coappear 0.0)
# SKU 103918 -> DC_2 (avg coappear 0.0)
# SKU 99935 -> DC_2 (avg coappear 0.0)
# SKU 99927 -> DC_2 (avg coappear 0.0)
# SKU 98111 -> DC_2 (avg coappear 0.0)
# SKU 95221 -> DC_2 (avg coappear 0.0)
# SKU 101028 -> DC_2 (avg coappear 0.0)
# SKU 96400 -> DC_2 (avg coappear 0.0)
# SKU 95232 -> DC_2 (avg coappear 0.0)
# SKU 100646 -> DC_2 (avg coappear 0.0)
# SKU 89079 -> DC_2 (avg coappear 0.0)
# SKU 102652 -> DC_2 (avg coappear 0.0)
# SKU 102648 -> DC_2 (avg coappear 0.0)
# SKU 102646 -> DC_2 (avg coappear 0.0)
# SKU 102644 -> DC_2 (avg coappear 0.0)
# SKU 102642 -> DC_2 (avg coappear 0.0)
# SKU 102639 -> DC_2 (avg coappear 0.0)
# SKU 102638 -> DC_2 (avg coappear 0.0)
# SKU 106863 -> DC_2 (avg coappear 0.0)
# SKU 106756 -> DC_2 (avg coappear 0.0)
# SKU 96405 -> DC_2 (avg coappear 0.0)
# SKU 72915 -> DC_2 (avg coappear 0.0)
# SKU 99367 -> DC_2 (avg coappear 0.0)
# SKU 105031 -> DC_2 (avg coappear 0.0)
# SKU 92187 -> DC_2 (avg coappear 0.0)
# SKU 97038 -> DC_2 (avg coappear 0.0)
# SKU 95418 -> DC_2 (avg coappear 0.0)
# SKU 78790 -> DC_2 (avg coappear 0.0)
# SKU 104131 -> DC_2 (avg coappear 0.0)
# SKU 99697 -> DC_2 (avg coappear 0.0)
# SKU 99699 -> DC_2 (avg coappear 0.0)
# SKU 99705 -> DC_2 (avg coappear 0.0)
# SKU 99707 -> DC_2 (avg coappear 0.0)
# SKU 99708 -> DC_2 (avg coappear 0.0)
# SKU 99709 -> DC_2 (avg coappear 0.0)
# SKU 99711 -> DC_2 (avg coappear 0.0)
# SKU 97336 -> DC_2 (avg coappear 0.0)
# SKU 99688 -> DC_2 (avg coappear 0.0)
# SKU 92458 -> DC_2 (avg coappear 0.0)
# SKU 95450 -> DC_2 (avg coappear 0.0)
# SKU 86061 -> DC_2 (avg coappear 0.0)
# SKU 104277 -> DC_2 (avg coappear 0.0)
# SKU 95329 -> DC_2 (avg coappear 0.0)
# SKU 98041 -> DC_2 (avg coappear 0.0)
# SKU 101443 -> DC_2 (avg coappear 0.0)
# SKU 90183 -> DC_2 (avg coappear 0.0)
# SKU 107714 -> DC_2 (avg coappear 0.0)
# SKU 98096 -> DC_2 (avg coappear 0.0)
# SKU 107136 -> DC_2 (avg coappear 0.0)
# SKU 98242 -> DC_2 (avg coappear 0.0)
# SKU 95359 -> DC_2 (avg coappear 0.0)
# SKU 101194 -> DC_2 (avg coappear 0.0)
# SKU 101201 -> DC_2 (avg coappear 0.0)
# SKU 102632 -> DC_2 (avg coappear 0.0)
# SKU 88306 -> DC_2 (avg coappear 0.0)
# SKU 102624 -> DC_2 (avg coappear 0.0)
# SKU 85408 -> DC_2 (avg coappear 0.0)
# SKU 103047 -> DC_2 (avg coappear 0.0)
# SKU 88656 -> DC_2 (avg coappear 0.0)
# SKU 88657 -> DC_2 (avg coappear 0.0)
# SKU 93030 -> DC_2 (avg coappear 0.0)
# SKU 105833 -> DC_2 (avg coappear 0.0)
# SKU 105831 -> DC_2 (avg coappear 0.0)
# SKU 88812 -> DC_2 (avg coappear 0.0)
# SKU 95165 -> DC_2 (avg coappear 0.0)
# SKU 95050 -> DC_2 (avg coappear 0.0)
# SKU 104916 -> DC_2 (avg coappear 0.0)
# SKU 99882 -> DC_2 (avg coappear 0.0)
# SKU 101951 -> DC_2 (avg coappear 0.0)
# SKU 71427 -> DC_2 (avg coappear 0.0)
# SKU 89904 -> DC_2 (avg coappear 0.0)
# SKU 100393 -> DC_2 (avg coappear 0.0)
# SKU 107161 -> DC_2 (avg coappear 0.0)
# SKU 98934 -> DC_2 (avg coappear 0.0)
# SKU 101223 -> DC_2 (avg coappear 0.0)
# SKU 102741 -> DC_2 (avg coappear 0.0)
# SKU 105019 -> DC_2 (avg coappear 0.0)
# SKU 96455 -> DC_2 (avg coappear 0.0)
# SKU 96450 -> DC_2 (avg coappear 0.0)
# SKU 103039 -> DC_2 (avg coappear 0.0)
# SKU 103932 -> DC_2 (avg coappear 0.0)
# SKU 106318 -> DC_1 (avg coappear 0.0)
# SKU 106316 -> DC_1 (avg coappear 0.0)
# SKU 102276 -> DC_2 (avg coappear 0.0)
# SKU 103048 -> DC_2 (avg coappear 0.0)
# SKU 108046 -> DC_2 (avg coappear 0.0)
# SKU 103049 -> DC_2 (avg coappear 0.0)
# SKU 83752 -> DC_2 (avg coappear 0.0)
# SKU 85407 -> DC_2 (avg coappear 0.0)
# SKU 85406 -> DC_2 (avg coappear 0.0)
# SKU 106623 -> DC_2 (avg coappear 0.0)
# SKU 96418 -> DC_2 (avg coappear 0.0)
# SKU 80857 -> DC_2 (avg coappear 0.0)
# SKU 66340 -> DC_2 (avg coappear 0.0)
# SKU 96561 -> DC_2 (avg coappear 0.0)
# SKU 94389 -> DC_2 (avg coappear 0.0)
# SKU 87772 -> DC_2 (avg coappear 0.0)
# SKU 85465 -> DC_2 (avg coappear 0.0)
# SKU 10962 -> DC_2 (avg coappear 0.0)
# SKU 73309 -> DC_2 (avg coappear 0.0)
# SKU 100294 -> DC_2 (avg coappear 0.0)
# SKU 92693 -> DC_2 (avg coappear 0.0)
# SKU 103165 -> DC_2 (avg coappear 0.0)
# SKU 86110 -> DC_2 (avg coappear 0.0)
# SKU 104868 -> DC_2 (avg coappear 0.0)
# SKU 89016 -> DC_2 (avg coappear 0.0)
# SKU 89002 -> DC_2 (avg coappear 0.0)
# SKU 80883 -> DC_2 (avg coappear 0.0)
# SKU 86091 -> DC_2 (avg coappear 0.0)
# SKU 77094 -> DC_2 (avg coappear 0.0)
# SKU 95503 -> DC_2 (avg coappear 0.0)
# SKU 105345 -> DC_2 (avg coappear 0.0)
# SKU 98075 -> DC_2 (avg coappear 0.0)
# SKU 103052 -> DC_2 (avg coappear 0.0)
# SKU 103051 -> DC_2 (avg coappear 0.0)
# SKU 103050 -> DC_2 (avg coappear 0.0)
# SKU 107695 -> DC_2 (avg coappear 0.0)
# SKU 95225 -> DC_2 (avg coappear 0.0)
# SKU 108329 -> DC_2 (avg coappear 0.0)
# SKU 95885 -> DC_2 (avg coappear 0.0)
# SKU 95886 -> DC_2 (avg coappear 0.0)
# SKU 86392 -> DC_2 (avg coappear 0.0)
# SKU 102286 -> DC_2 (avg coappear 0.0)
# SKU 98439 -> DC_2 (avg coappear 0.0)
# SKU 68258 -> DC_2 (avg coappear 0.0)
# SKU 100839 -> DC_2 (avg coappear 0.0)
# SKU 95887 -> DC_2 (avg coappear 0.0)
# SKU 45653 -> DC_2 (avg coappear 0.0)
# SKU 95890 -> DC_2 (avg coappear 0.0)
# SKU 95893 -> DC_2 (avg coappear 0.0)
# SKU 95898 -> DC_2 (avg coappear 0.0)
# SKU 95873 -> DC_2 (avg coappear 0.0)
# SKU 106104 -> DC_2 (avg coappear 0.0)
# SKU 95904 -> DC_2 (avg coappear 0.0)
# SKU 95906 -> DC_2 (avg coappear 0.0)
# SKU 79121 -> DC_2 (avg coappear 0.0)
# SKU 79120 -> DC_2 (avg coappear 0.0)
# SKU 101221 -> DC_2 (avg coappear 0.0)
# SKU 95830 -> DC_2 (avg coappear 0.0)
# SKU 103920 -> DC_2 (avg coappear 0.0)
# SKU 91396 -> DC_2 (avg coappear 0.0)
# SKU 91398 -> DC_2 (avg coappear 0.0)
# SKU 91865 -> DC_2 (avg coappear 0.0)
# SKU 92068 -> DC_2 (avg coappear 0.0)
# SKU 92243 -> DC_2 (avg coappear 0.0)
# SKU 91123 -> DC_2 (avg coappear 0.0)
# SKU 67014 -> DC_2 (avg coappear 0.0)
# SKU 88101 -> DC_2 (avg coappear 0.0)
# SKU 95868 -> DC_2 (avg coappear 0.0)
# SKU 108446 -> DC_2 (avg coappear 0.0)
# SKU 107164 -> DC_2 (avg coappear 0.0)
# SKU 76754 -> DC_2 (avg coappear 0.0)
# SKU 104035 -> DC_2 (avg coappear 0.0)
# SKU 104038 -> DC_2 (avg coappear 0.0)
# SKU 80893 -> DC_2 (avg coappear 0.0)
# SKU 101953 -> DC_2 (avg coappear 0.0)
# SKU 106038 -> DC_2 (avg coappear 0.0)
# SKU 99009 -> DC_2 (avg coappear 0.0)
# SKU 104480 -> DC_2 (avg coappear 0.0)
# SKU 74260 -> DC_2 (avg coappear 0.0)
# SKU 96558 -> DC_2 (avg coappear 0.0)
# SKU 97986 -> DC_2 (avg coappear 0.0)
# SKU 85889 -> DC_2 (avg coappear 0.0)
# SKU 85890 -> DC_2 (avg coappear 0.0)
# SKU 95824 -> DC_2 (avg coappear 0.0)
# SKU 85893 -> DC_2 (avg coappear 0.0)
# SKU 103262 -> DC_2 (avg coappear 0.0)
# SKU 88301 -> DC_2 (avg coappear 0.0)
# SKU 86025 -> DC_2 (avg coappear 0.0)
# SKU 95862 -> DC_2 (avg coappear 0.0)
# SKU 92740 -> DC_2 (avg coappear 0.0)
# SKU 101319 -> DC_2 (avg coappear 0.0)
# SKU 97479 -> DC_2 (avg coappear 0.0)
# SKU 87003 -> DC_2 (avg coappear 0.0)
# SKU 95501 -> DC_2 (avg coappear 0.0)
# SKU 96798 -> DC_2 (avg coappear 0.0)
# SKU 92060 -> DC_2 (avg coappear 0.0)
# SKU 92062 -> DC_2 (avg coappear 0.0)
# SKU 91764 -> DC_2 (avg coappear 0.0)
# SKU 92135 -> DC_2 (avg coappear 0.0)
# SKU 72979 -> DC_2 (avg coappear 0.0)
# SKU 108323 -> DC_2 (avg coappear 0.0)
# SKU 72982 -> DC_2 (avg coappear 0.0)
# SKU 107738 -> DC_2 (avg coappear 0.0)
# SKU 102429 -> DC_2 (avg coappear 0.0)
# SKU 102428 -> DC_2 (avg coappear 0.0)
# SKU 98557 -> DC_2 (avg coappear 0.0)
# SKU 64254 -> DC_2 (avg coappear 0.0)
# SKU 107138 -> DC_2 (avg coappear 0.0)
# SKU 107139 -> DC_2 (avg coappear 0.0)
# SKU 107140 -> DC_2 (avg coappear 0.0)
# SKU 107869 -> DC_2 (avg coappear 0.0)
# SKU 102431 -> DC_2 (avg coappear 0.0)
# SKU 107912 -> DC_2 (avg coappear 0.0)
# SKU 107677 -> DC_2 (avg coappear 0.0)
# SKU 2523 -> DC_2 (avg coappear 0.0)
# SKU 100017 -> DC_2 (avg coappear 0.0)
# SKU 107766 -> DC_2 (avg coappear 0.0)
# SKU 95280 -> DC_2 (avg coappear 0.0)
# SKU 67726 -> DC_2 (avg coappear 0.0)
# SKU 67692 -> DC_2 (avg coappear 0.0)
# SKU 107705 -> DC_2 (avg coappear 0.0)
# SKU 97026 -> DC_2 (avg coappear 0.0)
# SKU 97031 -> DC_2 (avg coappear 0.0)
# SKU 87194 -> DC_2 (avg coappear 0.0)
# SKU 100875 -> DC_2 (avg coappear 0.0)
# SKU 101468 -> DC_2 (avg coappear 0.0)
# SKU 69221 -> DC_2 (avg coappear 0.0)
# SKU 88311 -> DC_2 (avg coappear 0.0)
# SKU 108347 -> DC_2 (avg coappear 0.0)
# SKU 98610 -> DC_2 (avg coappear 0.0)
# SKU 92137 -> DC_2 (avg coappear 0.0)
# SKU 102944 -> DC_2 (avg coappear 0.0)
# SKU 102947 -> DC_2 (avg coappear 0.0)
# SKU 84864 -> DC_2 (avg coappear 0.0)
# SKU 101204 -> DC_2 (avg coappear 0.0)
# SKU 92194 -> DC_2 (avg coappear 0.0)
# SKU 80751 -> DC_2 (avg coappear 0.0)
# SKU 92204 -> DC_2 (avg coappear 0.0)
# SKU 101366 -> DC_2 (avg coappear 0.0)
# SKU 99932 -> DC_2 (avg coappear 0.0)
# SKU 99887 -> DC_2 (avg coappear 0.0)
# SKU 99889 -> DC_2 (avg coappear 0.0)
# SKU 99892 -> DC_2 (avg coappear 0.0)
# SKU 99899 -> DC_2 (avg coappear 0.0)
# SKU 99900 -> DC_2 (avg coappear 0.0)
# SKU 99901 -> DC_2 (avg coappear 0.0)
# SKU 104880 -> DC_2 (avg coappear 0.0)
# SKU 99904 -> DC_2 (avg coappear 0.0)
# SKU 67924 -> DC_2 (avg coappear 0.0)
# SKU 58414 -> DC_2 (avg coappear 0.0)
# SKU 67190 -> DC_2 (avg coappear 0.0)
# SKU 66276 -> DC_2 (avg coappear 0.0)
# SKU 99352 -> DC_2 (avg coappear 0.0)
# SKU 93972 -> DC_2 (avg coappear 0.0)
# SKU 101174 -> DC_2 (avg coappear 0.0)
# SKU 98617 -> DC_2 (avg coappear 0.0)
# SKU 101202 -> DC_2 (avg coappear 0.0)
# SKU 98611 -> DC_2 (avg coappear 0.0)
# SKU 107376 -> DC_1 (avg coappear 0.0)
#
# Filling remaining capacity
# No further allocations possible.
#
# Final remaining volumes (m3): [2.38084014e-06 6.78677145e+02]

# %%
df_allocation
# Out:
#       Warehouse Articolo
# 0          DC_1    20918
# 1          DC_1    98876
# 2          DC_1     7199
# 3          DC_1    43556
# 4          DC_1    50045
# ...         ...      ...
# 16416      DC_2    55161
# 16417      DC_2   106664
# 16418      DC_2    75927
# 16419      DC_2   103566
# 16420      DC_2   107496
#
# [16421 rows x 2 columns]

# %% [markdown]
# # STATISTICS

# %%
df = pd.merge(df, df_allocation, on='Articolo', how='left')
df['Warehouse'] = df['Warehouse'].replace({'DC_1': 'A', 'DC_2': 'B'})
df
# Out:
#          Unnamed: 0  Num. Ordine Mese-Giorno Articolo  \
# 0                 0       738378       04-18    20918
# 1                 1       738379       04-18     3456
# 2                 2       738379       04-18     7199
# 3                 3       738379       04-18    43556
# 4                 4       738379       04-18    50045
# ...             ...          ...         ...      ...
# 2298719     2447292       791134       12-29    92720
# 2298720     2447293       791134       12-29    98819
# 2298721     2447294       791134       12-29   105877
# 2298722     2447295       791134       12-29   107171
# 2298723     2447296       791140       12-30   107904
#
#                                       Descrizione  Pezzi ordinati  \
# 0         CAREFREE COTTON SALVASLIP 44 PZ.DISTESO               6
# 1        STUDIO L.5 INVISI FIX GEL FOR.LIQ.150ml                6
# 2        STUDIO L.8 FIX&FORCE GEL IPERFOR.150 ML.               6
# 3         STUDIO L.9 INDESTRUC.GEL ESTREMO 150 ML               6
# 4        STUDIO L.5 INVISI FIX GEL CR.FOR.VAS.150               6
# ...                                           ...             ...
# 2298719     CHANTECLAIR SGRASS.600 MLx2 PZ.LIMONE               1
# 2298720    VIM GEL BAGNO 5in1 ANTICALCARE 1000 ML               1
# 2298721  CIF CREMA GREEN ACTIVE 500 ML PINK BLOOM               1
# 2298722      OMINO B.DET.IDROCAPS SALVAFIBRE 20pz               1
# 2298723  ACE LAVAT.LIQ.27 LAVx3 PZ MELAeCANNELLA                2
#
#          Pezzi evasi  Pz x CT  Pz x TH  Volume pezzo  ...               Ecr2  \
# 0                  6       24        0      1.288000  ...  Igienico Sanitari
# 1                  6        6        0      0.378000  ...            Capelli
# 2                  6        6        0      0.303750  ...            Capelli
# 3                  6        6        0      0.720000  ...            Capelli
# 4                  6        6        0      0.405000  ...            Capelli
# ...              ...      ...      ...           ...  ...                ...
# 2298719            1        6        0      3.271125  ...          Superfici
# 2298720            1       12        0      1.559250  ...              Bagno
# 2298721            1       16        0      0.728000  ...          Superfici
# 2298722            1        8        0      2.025000  ...             Bucato
# 2298723            2        1        0     10.620000  ...             Bucato
#
#                           Ecr3                         Ecr4         Canale  \
# 0                   Assorbenti     Salvaslip e Proteggislip  Piume Diretti
# 1              Styling Capelli           Gel e Cere Capelli  Piume Diretti
# 2              Styling Capelli           Gel e Cere Capelli  Piume Diretti
# 3              Styling Capelli           Gel e Cere Capelli  Piume Diretti
# 4              Styling Capelli           Gel e Cere Capelli  Piume Diretti
# ...                        ...                          ...            ...
# 2298719   Detergenti Superfici                  Sgrassatori            B2C
# 2298720  Detergenti Bagno e WC             Detergenti Bagno            B2C
# 2298721   Detergenti Superfici          Detergenti Multiuso            B2C
# 2298722       Detersivi Bucato  Detersivi Capsule Lavatrice            B2C
# 2298723       Detersivi Bucato  Detersivi Liquido Lavatrice            B2C
#
#          Cliente  PV  Percorso Giacenza Pezzi Volume [m3]  Volume evaso [m3]  \
# 0        2104490  SM        26                   3.474766           0.007728
# 1        2104490  SM        26                   0.206955           0.002268
# 2        2104490  SM        26                   0.140424           0.001823
# 3        2104490  SM        26                   0.419256           0.004320
# 4        2104490  SM        26                   0.148149           0.002430
# ...          ...  ..       ...                        ...                ...
# 2298719  2152842  UD       999                   2.330022           0.003271
# 2298720  2152842  UD       999                   0.943970           0.001559
# 2298721  2152842  UD       999                   0.743142           0.000728
# 2298722  2152842  UD       999                   0.532170           0.002025
# 2298723  2152843  PT       999                   7.441434           0.021240
#
#          Warehouse
# 0                A
# 1                A
# 2                A
# 3                A
# 4                A
# ...            ...
# 2298719          B
# 2298720          B
# 2298721          B
# 2298722          B
# 2298723          B
#
# [2298724 rows x 22 columns]

# %%
df_results = pd.DataFrame.from_dict(
    {
        'Magazzino A': [],
        'Magazzino B':[],
        
        'Codici in A':[],
        'Codici in B':[],
        
        'Stock [m3] in A':[],
        'Stock [m3] in B':[],
        
        '% Ordini completati in AB':[],
        '% Ordini completati in A':[], 
        '% Ordini completati in B':[],

        'Vol[m3] Ordini completati in A':[], 
        'Vol[m3] Ordini completati in B':[],
        'Vol[m3] Ordini completati in AB':[],
        'Vol[m3] Ordini completati in AB (A)':[],
        'Vol[m3] Ordini completati in AB (B)':[],
        
        '% Rotte completate in AB' :[],
        '% Rotte completate in A' :[],
        '% Rotte completate in B' :[],

        'Vol[m3] Rotte completati in A' :[],
        'Vol[m3] Rotte completati in B' :[],
        'Vol[m3] Rotte completati in AB' :[],
        'Vol[m3] Rotte completati in AB (A)' :[],
        'Vol[m3] Rotte completati in AB (B)' :[],

    }
)
df_results
# Out:
# Empty DataFrame
# Columns: [Magazzino A, Magazzino B, Codici in A, Codici in B, Stock [m3] in A, Stock [m3] in B, % Ordini completati in AB, % Ordini completati in A, % Ordini completati in B, Vol[m3] Ordini completati in A, Vol[m3] Ordini completati in B, Vol[m3] Ordini completati in AB, Vol[m3] Ordini completati in AB (A), Vol[m3] Ordini completati in AB (B), % Rotte completate in AB, % Rotte completate in A, % Rotte completate in B, Vol[m3] Rotte completati in A, Vol[m3] Rotte completati in B, Vol[m3] Rotte completati in AB, Vol[m3] Rotte completati in AB (A), Vol[m3] Rotte completati in AB (B)]
# Index: []
#
# [0 rows x 22 columns]

# %%
assignment_A = df.groupby('Warehouse')['Articolo'].unique().get('A', 0)
assignment_B = df.groupby('Warehouse')['Articolo'].unique().get('B', 0)

code_A = df.groupby('Warehouse')['Articolo'].nunique().get('A', 0)
code_B = df.groupby('Warehouse')['Articolo'].nunique().get('B', 0)
# print('Article division', article_division)

#Order analysis
order_grouped_df = df.groupby(['Mese-Giorno','Num. Ordine']).agg({
    'Warehouse': lambda x: list(x.unique()),  # Stores unique warehouses as lists
    'Volume evaso [m3]': 'sum'  # Sums up volume
}).reset_index()

order_movment_A = len(order_grouped_df[order_grouped_df['Warehouse'].astype(str).str.contains(r"'A'") & ~order_grouped_df['Warehouse'].astype(str).str.contains(r"'B'")]) / len(order_grouped_df) * 100
order_movment_B = len(order_grouped_df[order_grouped_df['Warehouse'].astype(str).str.contains(r"'B'") & ~order_grouped_df['Warehouse'].astype(str).str.contains(r"'A'")]) / len(order_grouped_df) * 100
order_movment_AB = len(order_grouped_df[order_grouped_df['Warehouse'].astype(str).str.contains(r"'A'") & order_grouped_df['Warehouse'].astype(str).str.contains(r"'B'")]) / len(order_grouped_df) * 100

order_vol_A = order_grouped_df[order_grouped_df['Warehouse'].astype(str).str.contains(r"'A'") & ~order_grouped_df['Warehouse'].astype(str).str.contains(r"'B'")]['Volume evaso [m3]'].sum() 
order_vol_B = order_grouped_df[order_grouped_df['Warehouse'].astype(str).str.contains(r"'B'") & ~order_grouped_df['Warehouse'].astype(str).str.contains(r"'A'")]['Volume evaso [m3]'].sum() 
order_vol_AB = order_grouped_df[order_grouped_df['Warehouse'].astype(str).str.contains(r"'A'") & order_grouped_df['Warehouse'].astype(str).str.contains(r"'B'")]['Volume evaso [m3]'].sum()

AB_order_list = list(order_grouped_df[order_grouped_df['Warehouse'].astype(str).str.contains(r"'A'") & order_grouped_df['Warehouse'].astype(str).str.contains(r"'B'")]['Num. Ordine'])
df_AB_order_volume = df.groupby(['Num. Ordine','Warehouse'])[['Volume evaso [m3]']].sum().reset_index()
df_AB_order_volume = df_AB_order_volume[df_AB_order_volume['Num. Ordine'].isin(AB_order_list)].groupby('Warehouse')['Volume evaso [m3]'].sum()

#Route analysis
route_grouped_df = df.groupby(['Mese-Giorno','Percorso']).agg({
    'Warehouse': lambda x: list(x.unique()),  # Stores unique warehouses as lists
    'Volume evaso [m3]': 'sum'  # Sums up volume
}).reset_index()

route_movment_A = len(route_grouped_df[route_grouped_df['Warehouse'].astype(str).str.contains(r"'A'") & ~route_grouped_df['Warehouse'].astype(str).str.contains(r"'B'")]) / len(route_grouped_df) * 100
route_movment_B = len(route_grouped_df[route_grouped_df['Warehouse'].astype(str).str.contains(r"'B'") & ~route_grouped_df['Warehouse'].astype(str).str.contains(r"'A'")]) / len(route_grouped_df) * 100
route_movment_AB = len(route_grouped_df[route_grouped_df['Warehouse'].astype(str).str.contains(r"'A'") & route_grouped_df['Warehouse'].astype(str).str.contains(r"'B'")]) / len(route_grouped_df) * 100

route_vol_A = route_grouped_df[route_grouped_df['Warehouse'].astype(str).str.contains(r"'A'") & ~route_grouped_df['Warehouse'].astype(str).str.contains(r"'B'")]['Volume evaso [m3]'].sum() 
route_vol_B = route_grouped_df[route_grouped_df['Warehouse'].astype(str).str.contains(r"'B'") & ~route_grouped_df['Warehouse'].astype(str).str.contains(r"'A'")]['Volume evaso [m3]'].sum() 
route_vol_AB = route_grouped_df[route_grouped_df['Warehouse'].astype(str).str.contains(r"'A'") & route_grouped_df['Warehouse'].astype(str).str.contains(r"'B'")]['Volume evaso [m3]'].sum()

# Step 1: Extract valid routes containing both 'A' and 'B' in 'Warehouse'
AB_order_list = route_grouped_df[
    route_grouped_df['Warehouse'].astype(str).str.contains(r'A') & 
    route_grouped_df['Warehouse'].astype(str).str.contains(r'B')
][['Mese-Giorno', 'Percorso']].apply(tuple, axis=1).tolist()

# Step 2: Compute total volume for each route
df_AB_route_volume = df.groupby(['Mese-Giorno', 'Percorso', 'Warehouse'])[['Volume evaso [m3]']].sum().reset_index()

# Step 3: Filter only the relevant routes and sum by Warehouse
df_AB_route_volume = df_AB_route_volume[
    df_AB_route_volume[['Mese-Giorno', 'Percorso']].apply(tuple, axis=1).isin(AB_order_list)
].groupby('Warehouse')['Volume evaso [m3]'].sum()


weighted_stock = df.groupby(['Articolo','Warehouse',])['Giacenza Pezzi Volume [m3]'].mean() * (df.groupby(['Articolo','Warehouse',])['Pezzi evasi'].sum() / df.groupby(['Articolo'])['Pezzi evasi'].sum())
stock_A = weighted_stock.groupby('Warehouse').sum().get('A', 0)
stock_B = weighted_stock.groupby('Warehouse').sum().get('B', 0)

df_results = pd.DataFrame.from_dict(
    {
        'Magazzino A': [assignment_A],
        'Magazzino B': [assignment_B],
        
        'Codici in A':[code_A],
        'Codici in B':[code_B],
        
        'Stock [m3] in A':[stock_A],
        'Stock [m3] in B':[stock_B],
        
        '% Ordini completati in AB':[order_movment_AB],
        '% Ordini completati in A':[order_movment_A],
        '% Ordini completati in B':[order_movment_B],

        '% Rotte completate in AB':[route_movment_AB],
        '% Rotte completate in A':[route_movment_A],
        '% Rotte completate in B':[route_movment_B],

        'Vol[m3] Ordini completati in A':[order_vol_A],
        'Vol[m3] Ordini completati in B':[order_vol_B],
        'Vol[m3] Ordini completati in AB':[order_vol_AB],
        'Vol[m3] Ordini completati in AB (A)':[df_AB_order_volume.get('A', 0)],
        'Vol[m3] Ordini completati in AB (B)':[df_AB_order_volume.get('B', 0)],


        'Vol[m3] Rotte completati in A':[route_vol_A],
        'Vol[m3] Rotte completati in B':[route_vol_B],
        'Vol[m3] Rotte completati in AB':[route_vol_AB],
        'Vol[m3] Rotte completati in AB (A)' :[df_AB_route_volume.get('A', 0)],
        'Vol[m3] Rotte completati in AB (B)' :[df_AB_route_volume.get('B', 0)],

        
    }
)

# %%
df_results
# Out:
#                                          Magazzino A  \
# 0  [20918, 3456, 7199, 43556, 50045, 74657, 85476...
#
#                                          Magazzino B  Codici in A  \
# 0  [27576, 27577, 96607, 96145, 104170, 104180, 9...         2576
#
#    Codici in B  Stock [m3] in A  Stock [m3] in B  % Ordini completati in AB  \
# 0        13845      4446.421936      2393.576954                  66.102283
#
#    % Ordini completati in A  % Ordini completati in B  \
# 0                 15.002222                 18.895494
#
#    % Rotte completate in AB  ...  Vol[m3] Ordini completati in A  \
# 0                 89.496387  ...                     2251.414441
#
#    Vol[m3] Ordini completati in B  Vol[m3] Ordini completati in AB  \
# 0                      461.688005                     34619.964749
#
#    Vol[m3] Ordini completati in AB (A)  Vol[m3] Ordini completati in AB (B)  \
# 0                         27925.235942                          6694.728807
#
#    Vol[m3] Rotte completati in A  Vol[m3] Rotte completati in B  \
# 0                     280.777801                      96.560539
#
#    Vol[m3] Rotte completati in AB  Vol[m3] Rotte completati in AB (A)  \
# 0                    36955.728857                        29895.872583
#
#    Vol[m3] Rotte completati in AB (B)
# 0                         7059.856274
#
# [1 rows x 22 columns]

# %%
df_results.to_excel(r'C:\Users\Matteo.Gabellini\OneDrive - Alma Mater Studiorum Università di Bologna\DOTTORATO\1.RICERCA\0.CONFERENCE PAPER\6.ICIL\1.WAREHOUSE ALLOCATION\3.RESULTS\CATELAN_3.xlsx')
